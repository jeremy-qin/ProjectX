# %% [markdown]
# Covid 19 CT scan Image classification with VGG19 pretrained model.
#
# Datasets: 2 public datasets stored in the folders CT_DATA (CT_COVID and CT_NonCovid) and SARS-COV-2-DATA.
# https://www.kaggle.com/plameneduardo/sarscov2-ctscan-dataset
#
# https://github.com/UCSD-AI4H/COVID-CT
#
# DATA-Split folder : initially used to split data from CT-DATA, but will not be used here in the final.

# %%
from builtins import range, input

from tensorflow.keras.layers import Input, Lambda, Dense, Flatten, AveragePooling2D, Dropout
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from sklearn.metrics import confusion_matrix, roc_curve
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

import os
import cv2
from glob import glob

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from tensorflow.keras.utils import to_categorical

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
cov_path = "/content/drive/MyDrive/Colab Notebooks/CTCov/CT_Data/CT_COVID/"
norm_path = "/content/drive/MyDrive/Colab Notebooks/CTCov/CT_Data/CT_NonCOVID/"

# %%
IMAGE_SIZE=[224,224]
epochs = 300
batch_size=32
#define paths
covid_path = '/content/drive/MyDrive/Colab Notebooks/CTCov/SARS-COV-2-Data/COVID'
noncovid_path = '/content/drive/MyDrive/Colab Notebooks/CTCov/SARS-COV-2-Data/NON-COVID'

# Use glob to grab images from path .jpg or jpeg
cov_files = glob(cov_path + '/*')
norm_files = glob(norm_path + '/*')

covid_files = glob(covid_path + '/*')
noncovid_files = glob(noncovid_path + '/*')

# %%
# Fetch Images and Class Labels from Files
cov_labels = []
norm_labels = []

cov_images=[]
norm_images=[]

for i in range(len(cov_files)):
  image = cv2.imread(cov_files[i]) # read file 
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # arrange format as per keras
  image = cv2.resize(image,(224,224)) # resize as per model
  cov_images.append(image) # append image
  cov_labels.append('CT_COVID') #append class label
  
for i in range(len(norm_files)):
  image = cv2.imread(norm_files[i])
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
  image = cv2.resize(image,(224,224))
  norm_images.append(image)
  norm_labels.append('CT_NonCOVID')

# %%
plt.imshow(cov_images[10])

# %%
# Fetch Images and Class Labels from Files
covid_labels = []
noncovid_labels = []

covid_images=[]
noncovid_images=[]

for i in range(len(covid_files)):
  image = cv2.imread(covid_files[i]) # read file 
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # arrange format as per keras
  image = cv2.resize(image,(224,224)) # resize as per model
  covid_images.append(image) # append image
  covid_labels.append('CT_COVID') #append class label
  
for i in range(len(noncovid_files)):
  image = cv2.imread(noncovid_files[i])
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
  image = cv2.resize(image,(224,224))
  noncovid_images.append(image)
  noncovid_labels.append('CT_NonCOVID')

# %%
plt.imshow(covid_images[10])

# %%
noncovid_labels[10]
# Out:
# 'CT_NonCOVID'

# %%
cov_img_all = np.concatenate((covid_images, cov_images), axis=0)
norm_img_all = np.concatenate((noncovid_images, norm_images),axis=0)

# %%
covid_labels = np.concatenate((covid_labels, cov_labels), axis=0)
noncovid_labels = np.concatenate((noncovid_labels, norm_labels),axis=0)

# %%
len(cov_img_all)
# Out:
# 1598

# %% [markdown]
# # Median Blur

# %%
blurred_cov = [cv2.medianBlur(img, 5) for img in cov_img_all]

# %%
blurred_norm = [cv2.medianBlur(img, 5) for img in norm_img_all]

# %%
plt.imshow(blurred_cov[100])

# %%
plt.imshow(cov_img_all[100])

# %%
covid_images = np.array(blurred_cov)/255
noncovid_images = np.array(blurred_norm)/255

# %%
# Split into training and testing sets for both types of images
covid_x_train, covid_x_test, covid_y_train, covid_y_test = train_test_split(
    covid_images, covid_labels, test_size=0.2)
noncovid_x_train, noncovid_x_test, noncovid_y_train, noncovid_y_test = train_test_split(
    noncovid_images, noncovid_labels, test_size=0.2)

# Merge sets for both types of images
X_train = np.concatenate((noncovid_x_train, covid_x_train), axis=0)
X_test = np.concatenate((noncovid_x_test, covid_x_test), axis=0)
y_train = np.concatenate((noncovid_y_train, covid_y_train), axis=0)
y_test = np.concatenate((noncovid_y_test, covid_y_test), axis=0)

# Make labels into categories - either 0 or 1, for our model
y_train = LabelBinarizer().fit_transform(y_train)
y_train = to_categorical(y_train)

y_test = LabelBinarizer().fit_transform(y_test)
y_test = to_categorical(y_test)

# %%
# # look at some images
# def plot_images(images, title):
#     nrows, ncols = 5, 8
#     figsize = [10, 6]

#     fig, ax = plt.subplots(nrows=nrows, ncols=ncols, figsize=figsize, facecolor=(1, 1, 1))

#     for i, axi in enumerate(ax.flat):
#         axi.imshow(images[i])
#         axi.set_axis_off()

#     plt.suptitle(title, fontsize=24)
#     plt.tight_layout(pad=0.2, rect=[0, 0, 1, 0.9])
#     plt.show()
# plot_images(covid_images, 'Positive COVID-19 CT Scan')
# plot_images(noncovid_images, 'Negative COVID-19 CT Scan')

# %%
# plot_images(X_train, 'X_train')
# plot_images(X_test, 'X_test')
# # y_train and y_test contain class lables 0 and 1 representing COVID and NonCOVID for X_train and X_test

# %%
from sklearn.model_selection import KFold

kfold = KFold(n_splits=3, shuffle=True)
inputs = np.concatenate((X_train, X_test), axis=0)
targets = np.concatenate((y_train, y_test), axis=0)

# %% [markdown]
# # VGG model

# %%
from tensorflow.keras.applications import VGG19

# Building Model
acc_per_fold = []
loss_per_fold = []
fold_no = 1


for train, test in kfold.split(inputs, targets):

  vggModel = VGG19(weights="imagenet", include_top=False,
      input_tensor=Input(shape=(224, 224, 3)))
  
  outputs = vggModel.output
  outputs = Flatten(name="flatten")(outputs)
  outputs = Dropout(0.5)(outputs)
  outputs = Dense(2, activation="softmax")(outputs)

  model = Model(inputs=vggModel.input, outputs=outputs)

  for layer in vggModel.layers:
      layer.trainable = False

  model.compile(
          loss='categorical_crossentropy', 
          optimizer='adam', 
          metrics=['accuracy']
  )

  train_aug = ImageDataGenerator(
      rotation_range=20,
      width_shift_range=0.2,
      height_shift_range=0.2,
      horizontal_flip=True
  )

  # Generate a print
  print('------------------------------------------------------------------------')
  print(f'Training for fold {fold_no} ...')
  model.fit(train_aug.flow(inputs[train], targets[train], batch_size=batch_size),
                    verbose=1,
                    epochs=100)
  
  # Generate generalization metrics
  scores = model.evaluate(inputs[test], targets[test], verbose=0)
  print(f'Score for fold {fold_no}: {model.metrics_names[0]} of {scores[0]}; {model.metrics_names[1]} of {scores[1]*100}%')
  acc_per_fold.append(scores[1] * 100)
  loss_per_fold.append(scores[0])

  # Increase fold number
  fold_no = fold_no + 1

# == Provide average scores ==
print('------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(acc_per_fold)):
  print('------------------------------------------------------------------------')
  print(f'> Fold {i+1} - Loss: {loss_per_fold[i]} - Accuracy: {acc_per_fold[i]}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(acc_per_fold)} (+- {np.std(acc_per_fold)})')
print(f'> Loss: {np.mean(loss_per_fold)}')
print('------------------------------------------------------------------------')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 0s 0us/step
# 80150528/80134624 [==============================] - 0s 0us/step
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Epoch 1/100
# 68/68 [==============================] - 31s 292ms/step - loss: 0.7612 - accuracy: 0.6356
# Epoch 2/100
# 68/68 [==============================] - 20s 291ms/step - loss: 0.7209 - accuracy: 0.6631
# Epoch 3/100
# 68/68 [==============================] - 20s 293ms/step - loss: 0.6248 - accuracy: 0.7120
# Epoch 4/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.7356 - accuracy: 0.6882
# Epoch 5/100
# 68/68 [==============================] - 20s 290ms/step - loss: 0.6290 - accuracy: 0.7259
# Epoch 6/100
# 68/68 [==============================] - 20s 290ms/step - loss: 0.6462 - accuracy: 0.7306
# Epoch 7/100
# 68/68 [==============================] - 20s 291ms/step - loss: 0.6416 - accuracy: 0.7241
# Epoch 8/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.6124 - accuracy: 0.7408
# Epoch 9/100
# 68/68 [==============================] - 20s 289ms/step - loss: 0.6639 - accuracy: 0.7348
# Epoch 10/100
# 68/68 [==============================] - 20s 293ms/step - loss: 0.7134 - accuracy: 0.7194
# Epoch 11/100
# 68/68 [==============================] - 20s 293ms/step - loss: 0.6682 - accuracy: 0.7222
# Epoch 12/100
# 68/68 [==============================] - 20s 293ms/step - loss: 0.7276 - accuracy: 0.7255
# Epoch 13/100
# 68/68 [==============================] - 20s 291ms/step - loss: 0.5974 - accuracy: 0.7585
# Epoch 14/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.6522 - accuracy: 0.7483
# Epoch 15/100
# 68/68 [==============================] - 20s 289ms/step - loss: 0.6981 - accuracy: 0.7389
# Epoch 16/100
# 68/68 [==============================] - 20s 293ms/step - loss: 0.6232 - accuracy: 0.7520
# Epoch 17/100
# 68/68 [==============================] - 20s 293ms/step - loss: 0.5902 - accuracy: 0.7645
# Epoch 18/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.6349 - accuracy: 0.7566
# Epoch 19/100
# 68/68 [==============================] - 20s 300ms/step - loss: 0.6178 - accuracy: 0.7557
# Epoch 20/100
# 68/68 [==============================] - 20s 300ms/step - loss: 0.6340 - accuracy: 0.7492
# Epoch 21/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.6063 - accuracy: 0.7706
# Epoch 22/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.6307 - accuracy: 0.7641
# Epoch 23/100
# 68/68 [==============================] - 20s 300ms/step - loss: 0.6186 - accuracy: 0.7608
# Epoch 24/100
# 68/68 [==============================] - 20s 300ms/step - loss: 0.6833 - accuracy: 0.7557
# Epoch 25/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.7789 - accuracy: 0.7389
# Epoch 26/100
# 68/68 [==============================] - 21s 301ms/step - loss: 0.7492 - accuracy: 0.7422
# Epoch 27/100
# 68/68 [==============================] - 20s 300ms/step - loss: 0.6448 - accuracy: 0.7622
# Epoch 28/100
# 68/68 [==============================] - 20s 300ms/step - loss: 0.6458 - accuracy: 0.7599
# Epoch 29/100
# 68/68 [==============================] - 21s 302ms/step - loss: 0.6699 - accuracy: 0.7524
# Epoch 30/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.6044 - accuracy: 0.7743
# Epoch 31/100
# 68/68 [==============================] - 20s 300ms/step - loss: 0.6082 - accuracy: 0.7692
# Epoch 32/100
# 68/68 [==============================] - 20s 300ms/step - loss: 0.7284 - accuracy: 0.7534
# Epoch 33/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.6347 - accuracy: 0.7571
# Epoch 34/100
# 68/68 [==============================] - 20s 300ms/step - loss: 0.5931 - accuracy: 0.7715
# Epoch 35/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.6416 - accuracy: 0.7622
# Epoch 36/100
# 68/68 [==============================] - 21s 301ms/step - loss: 0.6281 - accuracy: 0.7655
# Epoch 37/100
# 68/68 [==============================] - 20s 301ms/step - loss: 0.6281 - accuracy: 0.7664
# Epoch 38/100
# 68/68 [==============================] - 20s 292ms/step - loss: 0.7306 - accuracy: 0.7469
# Epoch 39/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.7740 - accuracy: 0.7427
# Epoch 40/100
# 68/68 [==============================] - 20s 301ms/step - loss: 0.6155 - accuracy: 0.7622
# Epoch 41/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.6959 - accuracy: 0.7594
# Epoch 42/100
# 68/68 [==============================] - 20s 300ms/step - loss: 0.6857 - accuracy: 0.7673
# Epoch 43/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.6937 - accuracy: 0.7571
# Epoch 44/100
# 68/68 [==============================] - 20s 293ms/step - loss: 0.6256 - accuracy: 0.7790
# Epoch 45/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.7206 - accuracy: 0.7464
# Epoch 46/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.6857 - accuracy: 0.7664
# Epoch 47/100
# 68/68 [==============================] - 20s 293ms/step - loss: 0.6815 - accuracy: 0.7669
# Epoch 48/100
# 68/68 [==============================] - 20s 293ms/step - loss: 0.6629 - accuracy: 0.7608
# Epoch 49/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.6857 - accuracy: 0.7673
# Epoch 50/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.7039 - accuracy: 0.7594
# Epoch 51/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.6475 - accuracy: 0.7711
# Epoch 52/100
# 68/68 [==============================] - 20s 293ms/step - loss: 0.6551 - accuracy: 0.7864
# Epoch 53/100
# 68/68 [==============================] - 20s 291ms/step - loss: 0.5827 - accuracy: 0.7822
# Epoch 54/100
# 68/68 [==============================] - 20s 291ms/step - loss: 0.6016 - accuracy: 0.7869
# Epoch 55/100
# 68/68 [==============================] - 20s 293ms/step - loss: 0.6205 - accuracy: 0.7738
# Epoch 56/100
# 68/68 [==============================] - 20s 291ms/step - loss: 0.7017 - accuracy: 0.7599
# Epoch 57/100
# 68/68 [==============================] - 20s 293ms/step - loss: 0.6126 - accuracy: 0.7752
# Epoch 58/100
# 68/68 [==============================] - 20s 291ms/step - loss: 0.6605 - accuracy: 0.7669
# Epoch 59/100
# 68/68 [==============================] - 20s 292ms/step - loss: 0.6117 - accuracy: 0.7878
# Epoch 60/100
# 68/68 [==============================] - 20s 293ms/step - loss: 0.6229 - accuracy: 0.7715
# Epoch 61/100
# 68/68 [==============================] - 20s 291ms/step - loss: 0.6576 - accuracy: 0.7725
# Epoch 62/100
# 68/68 [==============================] - 20s 293ms/step - loss: 0.7112 - accuracy: 0.7557
# Epoch 63/100
# 68/68 [==============================] - 20s 290ms/step - loss: 0.6772 - accuracy: 0.7855
# Epoch 64/100
# 68/68 [==============================] - 20s 292ms/step - loss: 0.5960 - accuracy: 0.7841
# Epoch 65/100
# 68/68 [==============================] - 20s 291ms/step - loss: 0.6442 - accuracy: 0.7790
# Epoch 66/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.6522 - accuracy: 0.7869
# Epoch 67/100
# 68/68 [==============================] - 20s 293ms/step - loss: 0.6050 - accuracy: 0.7892
# Epoch 68/100
# 68/68 [==============================] - 20s 292ms/step - loss: 0.6163 - accuracy: 0.7869
# Epoch 69/100
# 68/68 [==============================] - 20s 292ms/step - loss: 0.6413 - accuracy: 0.7846
# Epoch 70/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.6112 - accuracy: 0.7906
# Epoch 71/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.6643 - accuracy: 0.7664
# Epoch 72/100
# 68/68 [==============================] - 20s 290ms/step - loss: 0.6460 - accuracy: 0.7720
# Epoch 73/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.6833 - accuracy: 0.7631
# Epoch 74/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.6390 - accuracy: 0.7752
# Epoch 75/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.5998 - accuracy: 0.7920
# Epoch 76/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.6828 - accuracy: 0.7655
# Epoch 77/100
# 68/68 [==============================] - 20s 292ms/step - loss: 0.7902 - accuracy: 0.7441
# Epoch 78/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.7608 - accuracy: 0.7622
# Epoch 79/100
# 68/68 [==============================] - 20s 291ms/step - loss: 0.6855 - accuracy: 0.7725
# Epoch 80/100
# 68/68 [==============================] - 20s 293ms/step - loss: 0.7373 - accuracy: 0.7743
# Epoch 81/100
# 68/68 [==============================] - 20s 292ms/step - loss: 0.6607 - accuracy: 0.7776
# Epoch 82/100
# 68/68 [==============================] - 20s 290ms/step - loss: 0.6689 - accuracy: 0.7711
# Epoch 83/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.6342 - accuracy: 0.7869
# Epoch 84/100
# 68/68 [==============================] - 20s 292ms/step - loss: 0.6386 - accuracy: 0.7934
# Epoch 85/100
# 68/68 [==============================] - 20s 293ms/step - loss: 0.6594 - accuracy: 0.7734
# Epoch 86/100
# 68/68 [==============================] - 20s 292ms/step - loss: 0.6089 - accuracy: 0.7957
# Epoch 87/100
# 68/68 [==============================] - 20s 300ms/step - loss: 0.6698 - accuracy: 0.7808
# Epoch 88/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.7149 - accuracy: 0.7566
# Epoch 89/100
# 68/68 [==============================] - 20s 292ms/step - loss: 0.6166 - accuracy: 0.7864
# Epoch 90/100
# 68/68 [==============================] - 20s 292ms/step - loss: 0.6139 - accuracy: 0.7948
# Epoch 91/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.6713 - accuracy: 0.7673
# Epoch 92/100
# 68/68 [==============================] - 20s 293ms/step - loss: 0.6878 - accuracy: 0.7748
# Epoch 93/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.8136 - accuracy: 0.7427
# Epoch 94/100
# 68/68 [==============================] - 20s 293ms/step - loss: 0.7250 - accuracy: 0.7743
# Epoch 95/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.6227 - accuracy: 0.7911
# Epoch 96/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.6379 - accuracy: 0.7846
# Epoch 97/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.8117 - accuracy: 0.7524
# Epoch 98/100
# 68/68 [==============================] - 20s 292ms/step - loss: 0.6322 - accuracy: 0.7859
# Epoch 99/100
# 68/68 [==============================] - 20s 293ms/step - loss: 0.6171 - accuracy: 0.7911
# Epoch 100/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.6775 - accuracy: 0.7771
# Score for fold 1: loss of 0.45269304513931274; accuracy of 84.83721017837524%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Epoch 1/100
# 68/68 [==============================] - 21s 293ms/step - loss: 1.0200 - accuracy: 0.5845
# Epoch 2/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.7691 - accuracy: 0.6468
# Epoch 3/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.6766 - accuracy: 0.6729
# Epoch 4/100
# 68/68 [==============================] - 20s 293ms/step - loss: 0.6218 - accuracy: 0.7017
# Epoch 5/100
# 68/68 [==============================] - 20s 291ms/step - loss: 0.6124 - accuracy: 0.7273
# Epoch 6/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.6589 - accuracy: 0.7180
# Epoch 7/100
# 68/68 [==============================] - 20s 292ms/step - loss: 0.7264 - accuracy: 0.6985
# Epoch 8/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.5789 - accuracy: 0.7431
# Epoch 9/100
# 68/68 [==============================] - 20s 293ms/step - loss: 0.6146 - accuracy: 0.7357
# Epoch 10/100
# 68/68 [==============================] - 20s 293ms/step - loss: 0.6035 - accuracy: 0.7450
# Epoch 11/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.6775 - accuracy: 0.7241
# Epoch 12/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.6090 - accuracy: 0.7552
# Epoch 13/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.5792 - accuracy: 0.7441
# Epoch 14/100
# 68/68 [==============================] - 20s 292ms/step - loss: 0.5982 - accuracy: 0.7497
# Epoch 15/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.6604 - accuracy: 0.7473
# Epoch 16/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.7051 - accuracy: 0.7362
# Epoch 17/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.6643 - accuracy: 0.7389
# Epoch 18/100
# 68/68 [==============================] - 20s 293ms/step - loss: 0.6540 - accuracy: 0.7348
# Epoch 19/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.6316 - accuracy: 0.7483
# Epoch 20/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.6674 - accuracy: 0.7376
# Epoch 21/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.6980 - accuracy: 0.7441
# Epoch 22/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.6878 - accuracy: 0.7413
# Epoch 23/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.6481 - accuracy: 0.7510
# Epoch 24/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.6046 - accuracy: 0.7641
# Epoch 25/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.6482 - accuracy: 0.7483
# Epoch 26/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.6204 - accuracy: 0.7524
# Epoch 27/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.6598 - accuracy: 0.7422
# Epoch 28/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.7530 - accuracy: 0.7259
# Epoch 29/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.6389 - accuracy: 0.7557
# Epoch 30/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.6251 - accuracy: 0.7571
# Epoch 31/100
# 68/68 [==============================] - 20s 292ms/step - loss: 0.6793 - accuracy: 0.7497
# Epoch 32/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.6322 - accuracy: 0.7636
# Epoch 33/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.6101 - accuracy: 0.7701
# Epoch 34/100
# 68/68 [==============================] - 21s 301ms/step - loss: 0.6316 - accuracy: 0.7627
# Epoch 35/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.6741 - accuracy: 0.7548
# Epoch 36/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.6746 - accuracy: 0.7548
# Epoch 37/100
# 68/68 [==============================] - 20s 302ms/step - loss: 0.6919 - accuracy: 0.7585
# Epoch 38/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.7384 - accuracy: 0.7529
# Epoch 39/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.6223 - accuracy: 0.7613
# Epoch 40/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.6957 - accuracy: 0.7599
# Epoch 41/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.6696 - accuracy: 0.7622
# Epoch 42/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.6658 - accuracy: 0.7631
# Epoch 43/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.6306 - accuracy: 0.7576
# Epoch 44/100
# 68/68 [==============================] - 20s 300ms/step - loss: 0.6517 - accuracy: 0.7701
# Epoch 45/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.6333 - accuracy: 0.7655
# Epoch 46/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.6367 - accuracy: 0.7697
# Epoch 47/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.6460 - accuracy: 0.7711
# Epoch 48/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.7286 - accuracy: 0.7515
# Epoch 49/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.7331 - accuracy: 0.7506
# Epoch 50/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.6965 - accuracy: 0.7664
# Epoch 51/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.6277 - accuracy: 0.7664
# Epoch 52/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.7129 - accuracy: 0.7455
# Epoch 53/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.8862 - accuracy: 0.7343
# Epoch 54/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.6829 - accuracy: 0.7701
# Epoch 55/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.6238 - accuracy: 0.7725
# Epoch 56/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.6874 - accuracy: 0.7645
# Epoch 57/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.6647 - accuracy: 0.7683
# Epoch 58/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.6372 - accuracy: 0.7785
# Epoch 59/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.6409 - accuracy: 0.7729
# Epoch 60/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.6657 - accuracy: 0.7771
# Epoch 61/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.7360 - accuracy: 0.7487
# Epoch 62/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.7243 - accuracy: 0.7664
# Epoch 63/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.6904 - accuracy: 0.7762
# Epoch 64/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.8070 - accuracy: 0.7348
# Epoch 65/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.7543 - accuracy: 0.7497
# Epoch 66/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.6167 - accuracy: 0.7799
# Epoch 67/100
# 68/68 [==============================] - 20s 300ms/step - loss: 0.6986 - accuracy: 0.7645
# Epoch 68/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.6718 - accuracy: 0.7641
# Epoch 69/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.6395 - accuracy: 0.7766
# Epoch 70/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.7292 - accuracy: 0.7483
# Epoch 71/100
# 68/68 [==============================] - 21s 301ms/step - loss: 0.6593 - accuracy: 0.7734
# Epoch 72/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.6401 - accuracy: 0.7850
# Epoch 73/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.6387 - accuracy: 0.7627
# Epoch 74/100
# 68/68 [==============================] - 21s 301ms/step - loss: 0.5722 - accuracy: 0.7869
# Epoch 75/100
# 68/68 [==============================] - 20s 293ms/step - loss: 0.6856 - accuracy: 0.7785
# Epoch 76/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.7151 - accuracy: 0.7617
# Epoch 77/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.7248 - accuracy: 0.7664
# Epoch 78/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.6091 - accuracy: 0.7897
# Epoch 79/100
# 68/68 [==============================] - 21s 300ms/step - loss: 0.6975 - accuracy: 0.7701
# Epoch 80/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.7364 - accuracy: 0.7543
# Epoch 81/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.5896 - accuracy: 0.7962
# Epoch 82/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.6372 - accuracy: 0.7841
# Epoch 83/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.7030 - accuracy: 0.7683
# Epoch 84/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.6402 - accuracy: 0.7687
# Epoch 85/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.6481 - accuracy: 0.7790
# Epoch 86/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.6412 - accuracy: 0.7827
# Epoch 87/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.7213 - accuracy: 0.7576
# Epoch 88/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.6907 - accuracy: 0.7659
# Epoch 89/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.6962 - accuracy: 0.7627
# Epoch 90/100
# 68/68 [==============================] - 20s 293ms/step - loss: 0.7111 - accuracy: 0.7604
# Epoch 91/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.6372 - accuracy: 0.7915
# Epoch 92/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.6639 - accuracy: 0.7780
# Epoch 93/100
# 68/68 [==============================] - 20s 300ms/step - loss: 0.6768 - accuracy: 0.7720
# Epoch 94/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.6793 - accuracy: 0.7804
# Epoch 95/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.7188 - accuracy: 0.7673
# Epoch 96/100
# 68/68 [==============================] - 20s 300ms/step - loss: 0.6443 - accuracy: 0.7748
# Epoch 97/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.6749 - accuracy: 0.7743
# Epoch 98/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.6396 - accuracy: 0.7887
# Epoch 99/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.6913 - accuracy: 0.7757
# Epoch 100/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.7113 - accuracy: 0.7785
# Score for fold 2: loss of 0.45791757106781006; accuracy of 82.41860270500183%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Epoch 1/100
# 68/68 [==============================] - 22s 308ms/step - loss: 0.8056 - accuracy: 0.6116
# Epoch 2/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.7376 - accuracy: 0.6605
# Epoch 3/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.7424 - accuracy: 0.6781
# Epoch 4/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.6865 - accuracy: 0.6926
# Epoch 5/100
# 68/68 [==============================] - 20s 300ms/step - loss: 0.7561 - accuracy: 0.6833
# Epoch 6/100
# 68/68 [==============================] - 20s 300ms/step - loss: 0.6664 - accuracy: 0.7047
# Epoch 7/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.6542 - accuracy: 0.7302
# Epoch 8/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.6504 - accuracy: 0.7200
# Epoch 9/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.6079 - accuracy: 0.7316
# Epoch 10/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.6930 - accuracy: 0.7116
# Epoch 11/100
# 68/68 [==============================] - 20s 300ms/step - loss: 0.7174 - accuracy: 0.7042
# Epoch 12/100
# 68/68 [==============================] - 20s 300ms/step - loss: 0.6101 - accuracy: 0.7372
# Epoch 13/100
# 68/68 [==============================] - 20s 300ms/step - loss: 0.6594 - accuracy: 0.7302
# Epoch 14/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.6400 - accuracy: 0.7391
# Epoch 15/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.6063 - accuracy: 0.7451
# Epoch 16/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.8345 - accuracy: 0.7014
# Epoch 17/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.6422 - accuracy: 0.7479
# Epoch 18/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.6976 - accuracy: 0.7358
# Epoch 19/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.6168 - accuracy: 0.7460
# Epoch 20/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.6175 - accuracy: 0.7460
# Epoch 21/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.7053 - accuracy: 0.7307
# Epoch 22/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.7346 - accuracy: 0.7265
# Epoch 23/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.7042 - accuracy: 0.7391
# Epoch 24/100
# 68/68 [==============================] - 21s 303ms/step - loss: 0.6820 - accuracy: 0.7405
# Epoch 25/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.6066 - accuracy: 0.7521
# Epoch 26/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.6268 - accuracy: 0.7456
# Epoch 27/100
# 68/68 [==============================] - 20s 300ms/step - loss: 0.6370 - accuracy: 0.7558
# Epoch 28/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.6266 - accuracy: 0.7530
# Epoch 29/100
# 68/68 [==============================] - 20s 300ms/step - loss: 0.6096 - accuracy: 0.7600
# Epoch 30/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.6784 - accuracy: 0.7521
# Epoch 31/100
# 68/68 [==============================] - 20s 304ms/step - loss: 0.6490 - accuracy: 0.7474
# Epoch 32/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.6788 - accuracy: 0.7502
# Epoch 33/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.6348 - accuracy: 0.7647
# Epoch 34/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.6257 - accuracy: 0.7577
# Epoch 35/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.6824 - accuracy: 0.7437
# Epoch 36/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.6427 - accuracy: 0.7628
# Epoch 37/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.6942 - accuracy: 0.7395
# Epoch 38/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.6114 - accuracy: 0.7600
# Epoch 39/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.6527 - accuracy: 0.7595
# Epoch 40/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.6695 - accuracy: 0.7553
# Epoch 41/100
# 68/68 [==============================] - 20s 293ms/step - loss: 0.6282 - accuracy: 0.7656
# Epoch 42/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.6495 - accuracy: 0.7535
# Epoch 43/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.6215 - accuracy: 0.7674
# Epoch 44/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.6469 - accuracy: 0.7605
# Epoch 45/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.6366 - accuracy: 0.7660
# Epoch 46/100
# 68/68 [==============================] - 21s 301ms/step - loss: 0.6564 - accuracy: 0.7581
# Epoch 47/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.6173 - accuracy: 0.7684
# Epoch 48/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.7648 - accuracy: 0.7312
# Epoch 49/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.6924 - accuracy: 0.7540
# Epoch 50/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.6560 - accuracy: 0.7619
# Epoch 51/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.6147 - accuracy: 0.7702
# Epoch 52/100
# 68/68 [==============================] - 20s 300ms/step - loss: 0.6434 - accuracy: 0.7609
# Epoch 53/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.6449 - accuracy: 0.7693
# Epoch 54/100
# 68/68 [==============================] - 20s 300ms/step - loss: 0.6217 - accuracy: 0.7740
# Epoch 55/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.6113 - accuracy: 0.7600
# Epoch 56/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.6679 - accuracy: 0.7660
# Epoch 57/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.6367 - accuracy: 0.7577
# Epoch 58/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.6428 - accuracy: 0.7763
# Epoch 59/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.6771 - accuracy: 0.7684
# Epoch 60/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.6622 - accuracy: 0.7688
# Epoch 61/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.6340 - accuracy: 0.7740
# Epoch 62/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.6313 - accuracy: 0.7735
# Epoch 63/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.6356 - accuracy: 0.7698
# Epoch 64/100
# 68/68 [==============================] - 21s 301ms/step - loss: 0.7298 - accuracy: 0.7516
# Epoch 65/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.6840 - accuracy: 0.7656
# Epoch 66/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.6396 - accuracy: 0.7753
# Epoch 67/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.8387 - accuracy: 0.7447
# Epoch 68/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.7733 - accuracy: 0.7433
# Epoch 69/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.6602 - accuracy: 0.7647
# Epoch 70/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.6666 - accuracy: 0.7600
# Epoch 71/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.7046 - accuracy: 0.7535
# Epoch 72/100
# 68/68 [==============================] - 20s 300ms/step - loss: 0.6107 - accuracy: 0.7800
# Epoch 73/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.6836 - accuracy: 0.7600
# Epoch 74/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.7309 - accuracy: 0.7623
# Epoch 75/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.6181 - accuracy: 0.7656
# Epoch 76/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.6298 - accuracy: 0.7740
# Epoch 77/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.7163 - accuracy: 0.7688
# Epoch 78/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.6679 - accuracy: 0.7679
# Epoch 79/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.6630 - accuracy: 0.7716
# Epoch 80/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.6253 - accuracy: 0.7865
# Epoch 81/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.6969 - accuracy: 0.7609
# Epoch 82/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.7404 - accuracy: 0.7516
# Epoch 83/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.8229 - accuracy: 0.7465
# Epoch 84/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.6627 - accuracy: 0.7684
# Epoch 85/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.6524 - accuracy: 0.7772
# Epoch 86/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.6210 - accuracy: 0.7837
# Epoch 87/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.6227 - accuracy: 0.7809
# Epoch 88/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.7506 - accuracy: 0.7488
# Epoch 89/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.6604 - accuracy: 0.7744
# Epoch 90/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.6902 - accuracy: 0.7660
# Epoch 91/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.6689 - accuracy: 0.7698
# Epoch 92/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.6887 - accuracy: 0.7651
# Epoch 93/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.6248 - accuracy: 0.7860
# Epoch 94/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.6436 - accuracy: 0.7749
# Epoch 95/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.6222 - accuracy: 0.7888
# Epoch 96/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.7713 - accuracy: 0.7563
# Epoch 97/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.7507 - accuracy: 0.7558
# Epoch 98/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.6624 - accuracy: 0.7740
# Epoch 99/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.7530 - accuracy: 0.7553
# Epoch 100/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.6187 - accuracy: 0.7916
# Score for fold 3: loss of 0.43339383602142334; accuracy of 84.91619825363159%
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.45269304513931274 - Accuracy: 84.83721017837524%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.45791757106781006 - Accuracy: 82.41860270500183%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.43339383602142334 - Accuracy: 84.91619825363159%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 84.05733704566956 (+- 1.1592087699435154)
# > Loss: 0.44800148407618207
# ------------------------------------------------------------------------

# %%
import pandas as pd
metrics = pd.DataFrame(acc_per_fold)
metrics = metrics.rename(columns={0:'accuracy'})
loss_df = pd.DataFrame(loss_per_fold)

# %%
metrics.head()
# Out:
#     accuracy
# 0  84.837210
# 1  82.418603
# 2  84.916198

# %%
metrics_df = metrics.join(loss_df.rename(columns={0:'loss'}))

# %%
metrics_df.head()
# Out:
#     accuracy      loss
# 0  84.837210  0.452693
# 1  82.418603  0.457918
# 2  84.916198  0.433394

# %%
report_csv_file = '/content/drive/MyDrive/Colab Notebooks/CTCov/Fold/VGG19/vgg_med_blur_class_report.csv'
with open(report_csv_file, mode='w') as f:
    metrics_df.to_csv(f)
