# %% [markdown]
# Covid 19 CT scan Image classification with VGG19 pretrained model.
#
# Datasets: 2 public datasets stored in the folders CT_DATA (CT_COVID and CT_NonCovid) and SARS-COV-2-DATA.
# https://www.kaggle.com/plameneduardo/sarscov2-ctscan-dataset
#
# https://github.com/UCSD-AI4H/COVID-CT
#
# DATA-Split folder : initially used to split data from CT-DATA, but will not be used here in the final.

# %%
from builtins import range, input
from tensorflow.keras.metrics import Recall
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten, AveragePooling2D, Dropout
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from sklearn.metrics import confusion_matrix, roc_curve
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

import os
import cv2
from glob import glob

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from tensorflow.keras.utils import to_categorical

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
cov_path = "/content/drive/MyDrive/Colab Notebooks/CTCov/CT_Data/CT_COVID/"
norm_path = "/content/drive/MyDrive/Colab Notebooks/CTCov/CT_Data/CT_NonCOVID/"

# %%
IMAGE_SIZE=[224,224]
epochs = 300
batch_size=32
#define paths
covid_path = '/content/drive/MyDrive/Colab Notebooks/CTCov/SARS-COV-2-Data/COVID'
noncovid_path = '/content/drive/MyDrive/Colab Notebooks/CTCov/SARS-COV-2-Data/NON-COVID'

# Use glob to grab images from path .jpg or jpeg
cov_files = glob(cov_path + '/*')
norm_files = glob(norm_path + '/*')

covid_files = glob(covid_path + '/*')
noncovid_files = glob(noncovid_path + '/*')

# %%
# Fetch Images and Class Labels from Files
cov_labels = []
norm_labels = []

cov_images=[]
norm_images=[]

for i in range(len(cov_files)):
  image = cv2.imread(cov_files[i]) # read file 
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # arrange format as per keras
  image = cv2.resize(image,(224,224)) # resize as per model
  cov_images.append(image) # append image
  cov_labels.append('CT_COVID') #append class label
  
for i in range(len(norm_files)):
  image = cv2.imread(norm_files[i])
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
  image = cv2.resize(image,(224,224))
  norm_images.append(image)
  norm_labels.append('CT_NonCOVID')

# %%
plt.imshow(cov_images[10])

# %%
# Fetch Images and Class Labels from Files
covid_labels = []
noncovid_labels = []

covid_images=[]
noncovid_images=[]

for i in range(len(covid_files)):
  image = cv2.imread(covid_files[i]) # read file 
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # arrange format as per keras
  image = cv2.resize(image,(224,224)) # resize as per model
  covid_images.append(image) # append image
  covid_labels.append('CT_COVID') #append class label
  
for i in range(len(noncovid_files)):
  image = cv2.imread(noncovid_files[i])
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
  image = cv2.resize(image,(224,224))
  noncovid_images.append(image)
  noncovid_labels.append('CT_NonCOVID')

# %%
plt.imshow(covid_images[10])

# %%
noncovid_labels[10]
# Out:
# 'CT_NonCOVID'

# %%
cov_img_all = np.concatenate((covid_images, cov_images), axis=0)
norm_img_all = np.concatenate((noncovid_images, norm_images),axis=0)

# %%
covid_labels = np.concatenate((covid_labels, cov_labels), axis=0)
noncovid_labels = np.concatenate((noncovid_labels, norm_labels),axis=0)

# %%
len(cov_img_all)
# Out:
# 1598

# %%
covid_images = np.array(cov_img_all)/255
noncovid_images = np.array(norm_img_all)/255

# %%
plt.imshow(covid_images[10])

# %%
# Split into training and testing sets for both types of images
covid_x_train, covid_x_test, covid_y_train, covid_y_test = train_test_split(
    covid_images, covid_labels, test_size=0.2)
noncovid_x_train, noncovid_x_test, noncovid_y_train, noncovid_y_test = train_test_split(
    noncovid_images, noncovid_labels, test_size=0.2)

# Merge sets for both types of images
X_train = np.concatenate((noncovid_x_train, covid_x_train), axis=0)
X_test = np.concatenate((noncovid_x_test, covid_x_test), axis=0)
y_train = np.concatenate((noncovid_y_train, covid_y_train), axis=0)
y_test = np.concatenate((noncovid_y_test, covid_y_test), axis=0)

# Make labels into categories - either 0 or 1, for our model
y_train = LabelBinarizer().fit_transform(y_train)
y_train = to_categorical(y_train)

y_test = LabelBinarizer().fit_transform(y_test)
y_test = to_categorical(y_test)

# %%
# look at some images
def plot_images(images, title):
    nrows, ncols = 3, 4
    figsize = [10, 6]

    fig, ax = plt.subplots(nrows=nrows, ncols=ncols, figsize=figsize, facecolor=(1, 1, 1))

    for i, axi in enumerate(ax.flat):
        axi.imshow(images[i])
        axi.set_axis_off()

    plt.suptitle(title, fontsize=24)
    plt.tight_layout(pad=0.2, rect=[0, 0, 1, 0.9])
    plt.show()
plot_images(covid_images, 'Positive COVID-19 CT Scan')
plot_images(noncovid_images, 'Negative COVID-19 CT Scan')

# %%
# plot_images(X_train, 'X_train')
# plot_images(X_test, 'X_test')
# # y_train and y_test contain class lables 0 and 1 representing COVID and NonCOVID for X_train and X_test

# %%
from sklearn.model_selection import KFold

kfold = KFold(n_splits=3, shuffle=True)
inputs = np.concatenate((X_train, X_test), axis=0)
targets = np.concatenate((y_train, y_test), axis=0)

# %% [markdown]
# # VGG model

# %%
from tensorflow.keras.applications import VGG19

# Building Model
acc_per_fold = []
loss_per_fold = []
fold_no = 1


for train, test in kfold.split(inputs, targets):

  vggModel = VGG19(weights="imagenet", include_top=False,
      input_tensor=Input(shape=(224, 224, 3)))
  
  outputs = vggModel.output
  outputs = Flatten(name="flatten")(outputs)
  outputs = Dropout(0.5)(outputs)
  outputs = Dense(2, activation="softmax")(outputs)

  model = Model(inputs=vggModel.input, outputs=outputs)

  for layer in vggModel.layers:
      layer.trainable = False

  model.compile(
          loss='categorical_crossentropy', 
          optimizer='adam', 
          metrics=['accuracy']
  )

  train_aug = ImageDataGenerator(
      rotation_range=20,
      width_shift_range=0.2,
      height_shift_range=0.2,
      horizontal_flip=True
  )

  # Generate a print
  print('------------------------------------------------------------------------')
  print(f'Training for fold {fold_no} ...')
  model.fit(train_aug.flow(inputs[train], targets[train], batch_size=batch_size),
                    verbose=1,
                    epochs=100)
  
  # Generate generalization metrics
  scores = model.evaluate(inputs[test], targets[test], verbose=0)
  print(f'Score for fold {fold_no}: {model.metrics_names[0]} of {scores[0]}; {model.metrics_names[1]} of {scores[1]*100}%')
  acc_per_fold.append(scores[1] * 100)
  loss_per_fold.append(scores[0])

  # Increase fold number
  fold_no = fold_no + 1

# == Provide average scores ==
print('------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(acc_per_fold)):
  print('------------------------------------------------------------------------')
  print(f'> Fold {i+1} - Loss: {loss_per_fold[i]} - Accuracy: {acc_per_fold[i]}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(acc_per_fold)} (+- {np.std(acc_per_fold)})')
print(f'> Loss: {np.mean(loss_per_fold)}')
print('------------------------------------------------------------------------')
# Out:
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Epoch 1/100
# 68/68 [==============================] - 33s 341ms/step - loss: 0.7472 - accuracy: 0.6384
# Epoch 2/100
# 68/68 [==============================] - 23s 337ms/step - loss: 0.7141 - accuracy: 0.6831
# Epoch 3/100
# 68/68 [==============================] - 23s 337ms/step - loss: 0.6383 - accuracy: 0.7245
# Epoch 4/100
# 68/68 [==============================] - 23s 342ms/step - loss: 0.6053 - accuracy: 0.7310
# Epoch 5/100
# 68/68 [==============================] - 23s 337ms/step - loss: 0.6260 - accuracy: 0.7245
# Epoch 6/100
# 68/68 [==============================] - 23s 339ms/step - loss: 0.6282 - accuracy: 0.7422
# Epoch 7/100
# 68/68 [==============================] - 23s 337ms/step - loss: 0.6525 - accuracy: 0.7273
# Epoch 8/100
# 68/68 [==============================] - 23s 338ms/step - loss: 0.6222 - accuracy: 0.7455
# Epoch 9/100
# 68/68 [==============================] - 23s 336ms/step - loss: 0.6212 - accuracy: 0.7450
# Epoch 10/100
# 68/68 [==============================] - 23s 337ms/step - loss: 0.6696 - accuracy: 0.7394
# Epoch 11/100
# 68/68 [==============================] - 23s 336ms/step - loss: 0.6422 - accuracy: 0.7562
# Epoch 12/100
# 68/68 [==============================] - 23s 337ms/step - loss: 0.6292 - accuracy: 0.7510
# Epoch 13/100
# 68/68 [==============================] - 23s 336ms/step - loss: 0.5764 - accuracy: 0.7617
# Epoch 14/100
# 68/68 [==============================] - 23s 340ms/step - loss: 0.6532 - accuracy: 0.7548
# Epoch 15/100
# 68/68 [==============================] - 23s 343ms/step - loss: 0.6375 - accuracy: 0.7590
# Epoch 16/100
# 68/68 [==============================] - 24s 346ms/step - loss: 0.6534 - accuracy: 0.7566
# Epoch 17/100
# 68/68 [==============================] - 24s 355ms/step - loss: 0.6281 - accuracy: 0.7664
# Epoch 18/100
# 68/68 [==============================] - 23s 340ms/step - loss: 0.6329 - accuracy: 0.7594
# Epoch 19/100
# 68/68 [==============================] - 23s 335ms/step - loss: 0.6064 - accuracy: 0.7678
# Epoch 20/100
# 68/68 [==============================] - 23s 338ms/step - loss: 0.6129 - accuracy: 0.7631
# Epoch 21/100
# 68/68 [==============================] - 23s 340ms/step - loss: 0.6501 - accuracy: 0.7590
# Epoch 22/100
# 68/68 [==============================] - 23s 338ms/step - loss: 0.6464 - accuracy: 0.7515
# Epoch 23/100
# 68/68 [==============================] - 24s 349ms/step - loss: 0.5731 - accuracy: 0.7748
# Epoch 24/100
# 68/68 [==============================] - 23s 334ms/step - loss: 0.6163 - accuracy: 0.7697
# Epoch 25/100
# 68/68 [==============================] - 23s 337ms/step - loss: 0.5537 - accuracy: 0.7901
# Epoch 26/100
# 68/68 [==============================] - 23s 336ms/step - loss: 0.6019 - accuracy: 0.7683
# Epoch 27/100
# 68/68 [==============================] - 23s 339ms/step - loss: 0.6496 - accuracy: 0.7669
# Epoch 28/100
# 68/68 [==============================] - 23s 341ms/step - loss: 0.6139 - accuracy: 0.7725
# Epoch 29/100
# 68/68 [==============================] - 23s 336ms/step - loss: 0.6319 - accuracy: 0.7692
# Epoch 30/100
# 68/68 [==============================] - 23s 337ms/step - loss: 0.6146 - accuracy: 0.7641
# Epoch 31/100
# 68/68 [==============================] - 23s 335ms/step - loss: 0.6258 - accuracy: 0.7836
# Epoch 32/100
# 68/68 [==============================] - 23s 338ms/step - loss: 0.6101 - accuracy: 0.7678
# Epoch 33/100
# 68/68 [==============================] - 23s 339ms/step - loss: 0.6194 - accuracy: 0.7771
# Epoch 34/100
# 68/68 [==============================] - 23s 337ms/step - loss: 0.5615 - accuracy: 0.7873
# Epoch 35/100
# 68/68 [==============================] - 23s 335ms/step - loss: 0.5375 - accuracy: 0.8078
# Epoch 36/100
# 68/68 [==============================] - 23s 337ms/step - loss: 0.5917 - accuracy: 0.7790
# Epoch 37/100
# 68/68 [==============================] - 23s 340ms/step - loss: 0.6321 - accuracy: 0.7850
# Epoch 38/100
# 68/68 [==============================] - 23s 343ms/step - loss: 0.6417 - accuracy: 0.7752
# Epoch 39/100
# 68/68 [==============================] - 23s 343ms/step - loss: 0.6395 - accuracy: 0.7715
# Epoch 40/100
# 68/68 [==============================] - 23s 341ms/step - loss: 0.7507 - accuracy: 0.7613
# Epoch 41/100
# 68/68 [==============================] - 23s 339ms/step - loss: 0.6910 - accuracy: 0.7725
# Epoch 42/100
# 68/68 [==============================] - 23s 338ms/step - loss: 0.6441 - accuracy: 0.7799
# Epoch 43/100
# 68/68 [==============================] - 23s 337ms/step - loss: 0.6601 - accuracy: 0.7697
# Epoch 44/100
# 68/68 [==============================] - 23s 336ms/step - loss: 0.6240 - accuracy: 0.7939
# Epoch 45/100
# 68/68 [==============================] - 23s 336ms/step - loss: 0.6017 - accuracy: 0.7841
# Epoch 46/100
# 68/68 [==============================] - 23s 334ms/step - loss: 0.6711 - accuracy: 0.7757
# Epoch 47/100
# 68/68 [==============================] - 23s 339ms/step - loss: 0.6414 - accuracy: 0.7850
# Epoch 48/100
# 68/68 [==============================] - 23s 338ms/step - loss: 0.6506 - accuracy: 0.7734
# Epoch 49/100
# 68/68 [==============================] - 24s 349ms/step - loss: 0.6153 - accuracy: 0.7915
# Epoch 50/100
# 68/68 [==============================] - 24s 346ms/step - loss: 0.6486 - accuracy: 0.7687
# Epoch 51/100
# 68/68 [==============================] - 24s 346ms/step - loss: 0.7516 - accuracy: 0.7613
# Epoch 52/100
# 68/68 [==============================] - 24s 350ms/step - loss: 0.6106 - accuracy: 0.7934
# Epoch 53/100
# 68/68 [==============================] - 24s 349ms/step - loss: 0.6432 - accuracy: 0.7859
# Epoch 54/100
# 68/68 [==============================] - 23s 343ms/step - loss: 0.7187 - accuracy: 0.7622
# Epoch 55/100
# 68/68 [==============================] - 24s 354ms/step - loss: 0.6273 - accuracy: 0.7883
# Epoch 56/100
# 68/68 [==============================] - 24s 353ms/step - loss: 0.7039 - accuracy: 0.7790
# Epoch 57/100
# 68/68 [==============================] - 24s 350ms/step - loss: 0.6402 - accuracy: 0.7883
# Epoch 58/100
# 68/68 [==============================] - 24s 350ms/step - loss: 0.6568 - accuracy: 0.7720
# Epoch 59/100
# 68/68 [==============================] - 24s 351ms/step - loss: 0.5948 - accuracy: 0.7943
# Epoch 60/100
# 68/68 [==============================] - 24s 353ms/step - loss: 0.6494 - accuracy: 0.7743
# Epoch 61/100
# 68/68 [==============================] - 24s 352ms/step - loss: 0.6421 - accuracy: 0.7953
# Epoch 62/100
# 68/68 [==============================] - 24s 351ms/step - loss: 0.6448 - accuracy: 0.7832
# Epoch 63/100
# 68/68 [==============================] - 24s 351ms/step - loss: 0.6039 - accuracy: 0.7925
# Epoch 64/100
# 68/68 [==============================] - 24s 357ms/step - loss: 0.6209 - accuracy: 0.7864
# Epoch 65/100
# 68/68 [==============================] - 24s 350ms/step - loss: 0.6273 - accuracy: 0.7850
# Epoch 66/100
# 68/68 [==============================] - 24s 351ms/step - loss: 0.6528 - accuracy: 0.7878
# Epoch 67/100
# 68/68 [==============================] - 24s 349ms/step - loss: 0.6139 - accuracy: 0.7883
# Epoch 68/100
# 68/68 [==============================] - 24s 352ms/step - loss: 0.6429 - accuracy: 0.7832
# Epoch 69/100
# 68/68 [==============================] - 24s 350ms/step - loss: 0.6668 - accuracy: 0.7808
# Epoch 70/100
# 68/68 [==============================] - 24s 348ms/step - loss: 0.6436 - accuracy: 0.7818
# Epoch 71/100
# 68/68 [==============================] - 24s 347ms/step - loss: 0.6044 - accuracy: 0.7869
# Epoch 72/100
# 68/68 [==============================] - 24s 352ms/step - loss: 0.7523 - accuracy: 0.7711
# Epoch 73/100
# 68/68 [==============================] - 23s 342ms/step - loss: 0.6197 - accuracy: 0.7934
# Epoch 74/100
# 68/68 [==============================] - 23s 335ms/step - loss: 0.6674 - accuracy: 0.7780
# Epoch 75/100
# 68/68 [==============================] - 23s 338ms/step - loss: 0.5923 - accuracy: 0.8120
# Epoch 76/100
# 68/68 [==============================] - 23s 339ms/step - loss: 0.5911 - accuracy: 0.7957
# Epoch 77/100
# 68/68 [==============================] - 23s 340ms/step - loss: 0.7141 - accuracy: 0.7738
# Epoch 78/100
# 68/68 [==============================] - 23s 339ms/step - loss: 0.6535 - accuracy: 0.7901
# Epoch 79/100
# 68/68 [==============================] - 23s 336ms/step - loss: 0.6538 - accuracy: 0.7971
# Epoch 80/100
# 68/68 [==============================] - 23s 339ms/step - loss: 0.6970 - accuracy: 0.7818
# Epoch 81/100
# 68/68 [==============================] - 23s 338ms/step - loss: 0.5736 - accuracy: 0.8036
# Epoch 82/100
# 68/68 [==============================] - 23s 338ms/step - loss: 0.6458 - accuracy: 0.7943
# Epoch 83/100
# 68/68 [==============================] - 23s 336ms/step - loss: 0.6937 - accuracy: 0.7762
# Epoch 84/100
# 68/68 [==============================] - 23s 336ms/step - loss: 0.7085 - accuracy: 0.7939
# Epoch 85/100
# 68/68 [==============================] - 23s 341ms/step - loss: 0.6609 - accuracy: 0.7878
# Epoch 86/100
# 68/68 [==============================] - 23s 337ms/step - loss: 0.7437 - accuracy: 0.7841
# Epoch 87/100
# 68/68 [==============================] - 23s 337ms/step - loss: 0.6644 - accuracy: 0.7822
# Epoch 88/100
# 68/68 [==============================] - 23s 336ms/step - loss: 0.6653 - accuracy: 0.7869
# Epoch 89/100
# 68/68 [==============================] - 23s 339ms/step - loss: 0.6657 - accuracy: 0.7818
# Epoch 90/100
# 68/68 [==============================] - 23s 338ms/step - loss: 0.7558 - accuracy: 0.7743
# Epoch 91/100
# 68/68 [==============================] - 23s 338ms/step - loss: 0.6630 - accuracy: 0.7994
# Epoch 92/100
# 68/68 [==============================] - 23s 338ms/step - loss: 0.5817 - accuracy: 0.8101
# Epoch 93/100
# 68/68 [==============================] - 23s 337ms/step - loss: 0.6673 - accuracy: 0.7832
# Epoch 94/100
# 68/68 [==============================] - 23s 338ms/step - loss: 0.6295 - accuracy: 0.7962
# Epoch 95/100
# 68/68 [==============================] - 23s 336ms/step - loss: 0.7374 - accuracy: 0.7771
# Epoch 96/100
# 68/68 [==============================] - 23s 338ms/step - loss: 0.6605 - accuracy: 0.7827
# Epoch 97/100
# 68/68 [==============================] - 23s 337ms/step - loss: 0.6996 - accuracy: 0.7859
# Epoch 98/100
# 68/68 [==============================] - 23s 338ms/step - loss: 0.7524 - accuracy: 0.7780
# Epoch 99/100
# 68/68 [==============================] - 23s 343ms/step - loss: 0.6806 - accuracy: 0.7925
# Epoch 100/100
# 68/68 [==============================] - 23s 341ms/step - loss: 0.6399 - accuracy: 0.8055
# Score for fold 1: loss of 0.4449298679828644; accuracy of 83.25581550598145%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Epoch 1/100
# 68/68 [==============================] - 25s 348ms/step - loss: 0.8729 - accuracy: 0.6142
# Epoch 2/100
# 68/68 [==============================] - 24s 347ms/step - loss: 0.6624 - accuracy: 0.6733
# Epoch 3/100
# 68/68 [==============================] - 24s 345ms/step - loss: 0.7392 - accuracy: 0.6757
# Epoch 4/100
# 68/68 [==============================] - 24s 346ms/step - loss: 0.7081 - accuracy: 0.7031
# Epoch 5/100
# 68/68 [==============================] - 24s 347ms/step - loss: 0.6170 - accuracy: 0.7301
# Epoch 6/100
# 68/68 [==============================] - 23s 344ms/step - loss: 0.6145 - accuracy: 0.7464
# Epoch 7/100
# 68/68 [==============================] - 23s 341ms/step - loss: 0.5794 - accuracy: 0.7469
# Epoch 8/100
# 68/68 [==============================] - 24s 345ms/step - loss: 0.5995 - accuracy: 0.7334
# Epoch 9/100
# 68/68 [==============================] - 23s 341ms/step - loss: 0.6786 - accuracy: 0.7394
# Epoch 10/100
# 68/68 [==============================] - 23s 338ms/step - loss: 0.6041 - accuracy: 0.7548
# Epoch 11/100
# 68/68 [==============================] - 23s 339ms/step - loss: 0.6053 - accuracy: 0.7431
# Epoch 12/100
# 68/68 [==============================] - 23s 338ms/step - loss: 0.6039 - accuracy: 0.7566
# Epoch 13/100
# 68/68 [==============================] - 23s 337ms/step - loss: 0.6268 - accuracy: 0.7483
# Epoch 14/100
# 68/68 [==============================] - 23s 337ms/step - loss: 0.5415 - accuracy: 0.7850
# Epoch 15/100
# 68/68 [==============================] - 23s 340ms/step - loss: 0.6112 - accuracy: 0.7557
# Epoch 16/100
# 68/68 [==============================] - 23s 342ms/step - loss: 0.5900 - accuracy: 0.7687
# Epoch 17/100
# 68/68 [==============================] - 23s 343ms/step - loss: 0.6231 - accuracy: 0.7543
# Epoch 18/100
# 68/68 [==============================] - 23s 337ms/step - loss: 0.6070 - accuracy: 0.7617
# Epoch 19/100
# 68/68 [==============================] - 23s 339ms/step - loss: 0.6258 - accuracy: 0.7650
# Epoch 20/100
# 68/68 [==============================] - 23s 338ms/step - loss: 0.5565 - accuracy: 0.7771
# Epoch 21/100
# 68/68 [==============================] - 23s 337ms/step - loss: 0.5647 - accuracy: 0.7846
# Epoch 22/100
# 68/68 [==============================] - 22s 330ms/step - loss: 0.5909 - accuracy: 0.7641
# Epoch 23/100
# 68/68 [==============================] - 23s 336ms/step - loss: 0.6825 - accuracy: 0.7399
# Epoch 24/100
# 68/68 [==============================] - 23s 331ms/step - loss: 0.6025 - accuracy: 0.7813
# Epoch 25/100
# 68/68 [==============================] - 23s 339ms/step - loss: 0.6706 - accuracy: 0.7548
# Epoch 26/100
# 68/68 [==============================] - 23s 343ms/step - loss: 0.7078 - accuracy: 0.7562
# Epoch 27/100
# 68/68 [==============================] - 23s 337ms/step - loss: 0.7371 - accuracy: 0.7543
# Epoch 28/100
# 68/68 [==============================] - 23s 340ms/step - loss: 0.5995 - accuracy: 0.7827
# Epoch 29/100
# 68/68 [==============================] - 23s 343ms/step - loss: 0.6443 - accuracy: 0.7762
# Epoch 30/100
# 68/68 [==============================] - 23s 342ms/step - loss: 0.5890 - accuracy: 0.7738
# Epoch 31/100
# 68/68 [==============================] - 23s 341ms/step - loss: 0.6501 - accuracy: 0.7720
# Epoch 32/100
# 68/68 [==============================] - 23s 338ms/step - loss: 0.6839 - accuracy: 0.7599
# Epoch 33/100
# 68/68 [==============================] - 23s 340ms/step - loss: 0.5514 - accuracy: 0.8050
# Epoch 34/100
# 68/68 [==============================] - 23s 341ms/step - loss: 0.7393 - accuracy: 0.7455
# Epoch 35/100
# 68/68 [==============================] - 23s 341ms/step - loss: 0.6494 - accuracy: 0.7785
# Epoch 36/100
# 68/68 [==============================] - 23s 341ms/step - loss: 0.6795 - accuracy: 0.7566
# Epoch 37/100
# 68/68 [==============================] - 23s 340ms/step - loss: 0.6060 - accuracy: 0.7841
# Epoch 38/100
# 68/68 [==============================] - 23s 338ms/step - loss: 0.6354 - accuracy: 0.7859
# Epoch 39/100
# 68/68 [==============================] - 23s 338ms/step - loss: 0.6611 - accuracy: 0.7701
# Epoch 40/100
# 68/68 [==============================] - 23s 342ms/step - loss: 0.6347 - accuracy: 0.7729
# Epoch 41/100
# 68/68 [==============================] - 23s 341ms/step - loss: 0.7660 - accuracy: 0.7473
# Epoch 42/100
# 68/68 [==============================] - 23s 343ms/step - loss: 0.6743 - accuracy: 0.7711
# Epoch 43/100
# 68/68 [==============================] - 23s 340ms/step - loss: 0.5931 - accuracy: 0.7901
# Epoch 44/100
# 68/68 [==============================] - 23s 340ms/step - loss: 0.5973 - accuracy: 0.7846
# Epoch 45/100
# 68/68 [==============================] - 23s 344ms/step - loss: 0.5590 - accuracy: 0.7948
# Epoch 46/100
# 68/68 [==============================] - 23s 335ms/step - loss: 0.5678 - accuracy: 0.7915
# Epoch 47/100
# 68/68 [==============================] - 23s 336ms/step - loss: 0.6376 - accuracy: 0.7901
# Epoch 48/100
# 68/68 [==============================] - 23s 335ms/step - loss: 0.5861 - accuracy: 0.7915
# Epoch 49/100
# 68/68 [==============================] - 23s 341ms/step - loss: 0.5736 - accuracy: 0.7934
# Epoch 50/100
# 68/68 [==============================] - 23s 341ms/step - loss: 0.6325 - accuracy: 0.7757
# Epoch 51/100
# 68/68 [==============================] - 23s 341ms/step - loss: 0.7882 - accuracy: 0.7510
# Epoch 52/100
# 68/68 [==============================] - 23s 344ms/step - loss: 0.6404 - accuracy: 0.7734
# Epoch 53/100
# 68/68 [==============================] - 23s 340ms/step - loss: 0.5715 - accuracy: 0.7934
# Epoch 54/100
# 68/68 [==============================] - 24s 345ms/step - loss: 0.6370 - accuracy: 0.7813
# Epoch 55/100
# 68/68 [==============================] - 24s 345ms/step - loss: 0.6065 - accuracy: 0.7859
# Epoch 56/100
# 68/68 [==============================] - 24s 345ms/step - loss: 0.5682 - accuracy: 0.8111
# Epoch 57/100
# 68/68 [==============================] - 23s 342ms/step - loss: 0.5870 - accuracy: 0.7971
# Epoch 58/100
# 68/68 [==============================] - 23s 339ms/step - loss: 0.6068 - accuracy: 0.7850
# Epoch 59/100
# 68/68 [==============================] - 23s 338ms/step - loss: 0.5886 - accuracy: 0.7953
# Epoch 60/100
# 68/68 [==============================] - 23s 344ms/step - loss: 0.7051 - accuracy: 0.7692
# Epoch 61/100
# 68/68 [==============================] - 23s 340ms/step - loss: 0.8106 - accuracy: 0.7534
# Epoch 62/100
# 68/68 [==============================] - 23s 344ms/step - loss: 0.6570 - accuracy: 0.7780
# Epoch 63/100
# 68/68 [==============================] - 24s 349ms/step - loss: 0.7167 - accuracy: 0.7725
# Epoch 64/100
# 68/68 [==============================] - 24s 345ms/step - loss: 0.6310 - accuracy: 0.7971
# Epoch 65/100
# 68/68 [==============================] - 23s 343ms/step - loss: 0.6185 - accuracy: 0.7920
# Epoch 66/100
# 68/68 [==============================] - 23s 344ms/step - loss: 0.7294 - accuracy: 0.7752
# Epoch 67/100
# 68/68 [==============================] - 23s 343ms/step - loss: 0.5716 - accuracy: 0.7929
# Epoch 68/100
# 68/68 [==============================] - 24s 350ms/step - loss: 0.5446 - accuracy: 0.8018
# Epoch 69/100
# 68/68 [==============================] - 24s 345ms/step - loss: 0.6507 - accuracy: 0.7878
# Epoch 70/100
# 68/68 [==============================] - 24s 347ms/step - loss: 0.7092 - accuracy: 0.7748
# Epoch 71/100
# 68/68 [==============================] - 23s 339ms/step - loss: 0.6513 - accuracy: 0.7887
# Epoch 72/100
# 68/68 [==============================] - 23s 340ms/step - loss: 0.6569 - accuracy: 0.7939
# Epoch 73/100
# 68/68 [==============================] - 24s 346ms/step - loss: 0.5857 - accuracy: 0.8022
# Epoch 74/100
# 68/68 [==============================] - 23s 344ms/step - loss: 0.7047 - accuracy: 0.7766
# Epoch 75/100
# 68/68 [==============================] - 23s 344ms/step - loss: 0.6231 - accuracy: 0.7897
# Epoch 76/100
# 68/68 [==============================] - 23s 341ms/step - loss: 0.6267 - accuracy: 0.7915
# Epoch 77/100
# 68/68 [==============================] - 23s 339ms/step - loss: 0.6064 - accuracy: 0.7934
# Epoch 78/100
# 68/68 [==============================] - 23s 337ms/step - loss: 0.6779 - accuracy: 0.7878
# Epoch 79/100
# 68/68 [==============================] - 23s 335ms/step - loss: 0.6136 - accuracy: 0.7929
# Epoch 80/100
# 68/68 [==============================] - 23s 337ms/step - loss: 0.6215 - accuracy: 0.7980
# Epoch 81/100
# 68/68 [==============================] - 23s 339ms/step - loss: 0.6330 - accuracy: 0.7855
# Epoch 82/100
# 68/68 [==============================] - 23s 338ms/step - loss: 0.6011 - accuracy: 0.7971
# Epoch 83/100
# 68/68 [==============================] - 23s 337ms/step - loss: 0.7140 - accuracy: 0.7762
# Epoch 84/100
# 68/68 [==============================] - 23s 335ms/step - loss: 0.6348 - accuracy: 0.7846
# Epoch 85/100
# 68/68 [==============================] - 23s 335ms/step - loss: 0.6149 - accuracy: 0.7915
# Epoch 86/100
# 68/68 [==============================] - 23s 335ms/step - loss: 0.6655 - accuracy: 0.7966
# Epoch 87/100
# 68/68 [==============================] - 23s 334ms/step - loss: 0.8531 - accuracy: 0.7529
# Epoch 88/100
# 68/68 [==============================] - 23s 334ms/step - loss: 0.6375 - accuracy: 0.7990
# Epoch 89/100
# 68/68 [==============================] - 23s 335ms/step - loss: 0.7070 - accuracy: 0.7878
# Epoch 90/100
# 68/68 [==============================] - 23s 335ms/step - loss: 0.6840 - accuracy: 0.7864
# Epoch 91/100
# 68/68 [==============================] - 23s 332ms/step - loss: 0.6323 - accuracy: 0.7813
# Epoch 92/100
# 68/68 [==============================] - 23s 333ms/step - loss: 0.6947 - accuracy: 0.7906
# Epoch 93/100
# 68/68 [==============================] - 23s 332ms/step - loss: 0.6473 - accuracy: 0.7897
# Epoch 94/100
# 68/68 [==============================] - 23s 331ms/step - loss: 0.7200 - accuracy: 0.7859
# Epoch 95/100
# 68/68 [==============================] - 23s 332ms/step - loss: 0.6218 - accuracy: 0.7943
# Epoch 96/100
# 68/68 [==============================] - 23s 330ms/step - loss: 0.6592 - accuracy: 0.7892
# Epoch 97/100
# 68/68 [==============================] - 22s 329ms/step - loss: 0.6432 - accuracy: 0.7957
# Epoch 98/100
# 68/68 [==============================] - 22s 329ms/step - loss: 0.6647 - accuracy: 0.8004
# Epoch 99/100
# 68/68 [==============================] - 22s 329ms/step - loss: 0.6467 - accuracy: 0.7980
# Epoch 100/100
# 68/68 [==============================] - 23s 330ms/step - loss: 0.6709 - accuracy: 0.7846
# Score for fold 2: loss of 0.4277394115924835; accuracy of 84.74418520927429%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Epoch 1/100
# 68/68 [==============================] - 24s 335ms/step - loss: 1.0130 - accuracy: 0.5856
# Epoch 2/100
# 68/68 [==============================] - 23s 331ms/step - loss: 0.6317 - accuracy: 0.6893
# Epoch 3/100
# 68/68 [==============================] - 23s 330ms/step - loss: 0.5954 - accuracy: 0.7140
# Epoch 4/100
# 68/68 [==============================] - 22s 329ms/step - loss: 0.5762 - accuracy: 0.7498
# Epoch 5/100
# 68/68 [==============================] - 23s 332ms/step - loss: 0.5981 - accuracy: 0.7381
# Epoch 6/100
# 68/68 [==============================] - 23s 331ms/step - loss: 0.5818 - accuracy: 0.7326
# Epoch 7/100
# 68/68 [==============================] - 22s 329ms/step - loss: 0.6194 - accuracy: 0.7381
# Epoch 8/100
# 68/68 [==============================] - 23s 334ms/step - loss: 0.6415 - accuracy: 0.7409
# Epoch 9/100
# 68/68 [==============================] - 23s 331ms/step - loss: 0.5383 - accuracy: 0.7674
# Epoch 10/100
# 68/68 [==============================] - 22s 329ms/step - loss: 0.5915 - accuracy: 0.7567
# Epoch 11/100
# 68/68 [==============================] - 23s 332ms/step - loss: 0.6624 - accuracy: 0.7470
# Epoch 12/100
# 68/68 [==============================] - 23s 331ms/step - loss: 0.6348 - accuracy: 0.7553
# Epoch 13/100
# 68/68 [==============================] - 23s 331ms/step - loss: 0.6001 - accuracy: 0.7567
# Epoch 14/100
# 68/68 [==============================] - 23s 337ms/step - loss: 0.6330 - accuracy: 0.7535
# Epoch 15/100
# 68/68 [==============================] - 23s 331ms/step - loss: 0.5754 - accuracy: 0.7665
# Epoch 16/100
# 68/68 [==============================] - 23s 330ms/step - loss: 0.6384 - accuracy: 0.7553
# Epoch 17/100
# 68/68 [==============================] - 23s 331ms/step - loss: 0.5712 - accuracy: 0.7758
# Epoch 18/100
# 68/68 [==============================] - 22s 327ms/step - loss: 0.5940 - accuracy: 0.7684
# Epoch 19/100
# 68/68 [==============================] - 23s 332ms/step - loss: 0.5894 - accuracy: 0.7651
# Epoch 20/100
# 68/68 [==============================] - 23s 335ms/step - loss: 0.5687 - accuracy: 0.7688
# Epoch 21/100
# 68/68 [==============================] - 23s 330ms/step - loss: 0.5784 - accuracy: 0.7851
# Epoch 22/100
# 68/68 [==============================] - 22s 330ms/step - loss: 0.6146 - accuracy: 0.7688
# Epoch 23/100
# 68/68 [==============================] - 23s 334ms/step - loss: 0.6013 - accuracy: 0.7702
# Epoch 24/100
# 68/68 [==============================] - 23s 334ms/step - loss: 0.6011 - accuracy: 0.7679
# Epoch 25/100
# 68/68 [==============================] - 23s 336ms/step - loss: 0.6512 - accuracy: 0.7581
# Epoch 26/100
# 68/68 [==============================] - 23s 337ms/step - loss: 0.6766 - accuracy: 0.7470
# Epoch 27/100
# 68/68 [==============================] - 23s 335ms/step - loss: 0.6457 - accuracy: 0.7716
# Epoch 28/100
# 68/68 [==============================] - 23s 333ms/step - loss: 0.5942 - accuracy: 0.7735
# Epoch 29/100
# 68/68 [==============================] - 22s 329ms/step - loss: 0.7601 - accuracy: 0.7535
# Epoch 30/100
# 68/68 [==============================] - 23s 331ms/step - loss: 0.6648 - accuracy: 0.7744
# Epoch 31/100
# 68/68 [==============================] - 22s 328ms/step - loss: 0.6162 - accuracy: 0.7791
# Epoch 32/100
# 68/68 [==============================] - 23s 333ms/step - loss: 0.5811 - accuracy: 0.7814
# Epoch 33/100
# 68/68 [==============================] - 23s 334ms/step - loss: 0.5754 - accuracy: 0.7772
# Epoch 34/100
# 68/68 [==============================] - 23s 331ms/step - loss: 0.6800 - accuracy: 0.7577
# Epoch 35/100
# 68/68 [==============================] - 22s 330ms/step - loss: 0.6004 - accuracy: 0.7860
# Epoch 36/100
# 68/68 [==============================] - 23s 331ms/step - loss: 0.6264 - accuracy: 0.7753
# Epoch 37/100
# 68/68 [==============================] - 23s 332ms/step - loss: 0.5882 - accuracy: 0.7884
# Epoch 38/100
# 68/68 [==============================] - 22s 329ms/step - loss: 0.7321 - accuracy: 0.7614
# Epoch 39/100
# 68/68 [==============================] - 23s 331ms/step - loss: 0.7672 - accuracy: 0.7544
# Epoch 40/100
# 68/68 [==============================] - 22s 328ms/step - loss: 0.7026 - accuracy: 0.7795
# Epoch 41/100
# 68/68 [==============================] - 22s 329ms/step - loss: 0.5903 - accuracy: 0.7893
# Epoch 42/100
# 68/68 [==============================] - 22s 330ms/step - loss: 0.7390 - accuracy: 0.7684
# Epoch 43/100
# 68/68 [==============================] - 22s 329ms/step - loss: 0.7009 - accuracy: 0.7586
# Epoch 44/100
# 68/68 [==============================] - 22s 329ms/step - loss: 0.6086 - accuracy: 0.7856
# Epoch 45/100
# 68/68 [==============================] - 23s 334ms/step - loss: 0.6829 - accuracy: 0.7665
# Epoch 46/100
# 68/68 [==============================] - 22s 328ms/step - loss: 0.5756 - accuracy: 0.7995
# Epoch 47/100
# 68/68 [==============================] - 23s 333ms/step - loss: 0.6039 - accuracy: 0.7902
# Epoch 48/100
# 68/68 [==============================] - 22s 330ms/step - loss: 0.7245 - accuracy: 0.7753
# Epoch 49/100
# 68/68 [==============================] - 22s 329ms/step - loss: 0.6276 - accuracy: 0.7837
# Epoch 50/100
# 68/68 [==============================] - 23s 332ms/step - loss: 0.6356 - accuracy: 0.7860
# Epoch 51/100
# 68/68 [==============================] - 22s 329ms/step - loss: 0.6189 - accuracy: 0.7865
# Epoch 52/100
# 68/68 [==============================] - 23s 331ms/step - loss: 0.6789 - accuracy: 0.7721
# Epoch 53/100
# 68/68 [==============================] - 23s 330ms/step - loss: 0.6873 - accuracy: 0.7656
# Epoch 54/100
# 68/68 [==============================] - 22s 326ms/step - loss: 0.6013 - accuracy: 0.7967
# Epoch 55/100
# 68/68 [==============================] - 22s 324ms/step - loss: 0.6155 - accuracy: 0.7842
# Epoch 56/100
# 68/68 [==============================] - 23s 333ms/step - loss: 0.6557 - accuracy: 0.7707
# Epoch 57/100
# 68/68 [==============================] - 22s 330ms/step - loss: 0.6824 - accuracy: 0.7777
# Epoch 58/100
# 68/68 [==============================] - 23s 332ms/step - loss: 0.6213 - accuracy: 0.7819
# Epoch 59/100
# 68/68 [==============================] - 23s 331ms/step - loss: 0.7436 - accuracy: 0.7633
# Epoch 60/100
# 68/68 [==============================] - 23s 335ms/step - loss: 0.6383 - accuracy: 0.7814
# Epoch 61/100
# 68/68 [==============================] - 23s 334ms/step - loss: 0.6249 - accuracy: 0.7963
# Epoch 62/100
# 68/68 [==============================] - 23s 333ms/step - loss: 0.6364 - accuracy: 0.7865
# Epoch 63/100
# 68/68 [==============================] - 23s 330ms/step - loss: 0.5645 - accuracy: 0.8126
# Epoch 64/100
# 68/68 [==============================] - 22s 329ms/step - loss: 0.6986 - accuracy: 0.7716
# Epoch 65/100
# 68/68 [==============================] - 22s 330ms/step - loss: 0.6649 - accuracy: 0.7842
# Epoch 66/100
# 68/68 [==============================] - 23s 332ms/step - loss: 0.6380 - accuracy: 0.7767
# Epoch 67/100
# 68/68 [==============================] - 23s 331ms/step - loss: 0.6811 - accuracy: 0.7674
# Epoch 68/100
# 68/68 [==============================] - 22s 327ms/step - loss: 0.6926 - accuracy: 0.7758
# Epoch 69/100
# 68/68 [==============================] - 22s 328ms/step - loss: 0.5990 - accuracy: 0.8060
# Epoch 70/100
# 68/68 [==============================] - 23s 331ms/step - loss: 0.6018 - accuracy: 0.7977
# Epoch 71/100
# 68/68 [==============================] - 23s 331ms/step - loss: 0.5767 - accuracy: 0.8112
# Epoch 72/100
# 68/68 [==============================] - 23s 334ms/step - loss: 0.5746 - accuracy: 0.7926
# Epoch 73/100
# 68/68 [==============================] - 22s 329ms/step - loss: 0.7362 - accuracy: 0.7637
# Epoch 74/100
# 68/68 [==============================] - 23s 331ms/step - loss: 0.6518 - accuracy: 0.7898
# Epoch 75/100
# 68/68 [==============================] - 22s 329ms/step - loss: 0.6075 - accuracy: 0.7981
# Epoch 76/100
# 68/68 [==============================] - 22s 328ms/step - loss: 0.6493 - accuracy: 0.7958
# Epoch 77/100
# 68/68 [==============================] - 23s 334ms/step - loss: 0.7158 - accuracy: 0.7795
# Epoch 78/100
# 68/68 [==============================] - 22s 329ms/step - loss: 0.6901 - accuracy: 0.7865
# Epoch 79/100
# 68/68 [==============================] - 22s 329ms/step - loss: 0.7644 - accuracy: 0.7767
# Epoch 80/100
# 68/68 [==============================] - 22s 329ms/step - loss: 0.6416 - accuracy: 0.7953
# Epoch 81/100
# 68/68 [==============================] - 22s 329ms/step - loss: 0.6311 - accuracy: 0.7972
# Epoch 82/100
# 68/68 [==============================] - 22s 329ms/step - loss: 0.5912 - accuracy: 0.8098
# Epoch 83/100
# 68/68 [==============================] - 22s 328ms/step - loss: 0.6413 - accuracy: 0.7930
# Epoch 84/100
# 68/68 [==============================] - 23s 330ms/step - loss: 0.6773 - accuracy: 0.7888
# Epoch 85/100
# 68/68 [==============================] - 23s 332ms/step - loss: 0.6644 - accuracy: 0.7949
# Epoch 86/100
# 68/68 [==============================] - 22s 328ms/step - loss: 0.6396 - accuracy: 0.7823
# Epoch 87/100
# 68/68 [==============================] - 23s 332ms/step - loss: 0.6301 - accuracy: 0.7926
# Epoch 88/100
# 68/68 [==============================] - 22s 318ms/step - loss: 0.6653 - accuracy: 0.7935
# Epoch 89/100
# 68/68 [==============================] - 22s 329ms/step - loss: 0.6555 - accuracy: 0.7926
# Epoch 90/100
# 68/68 [==============================] - 22s 326ms/step - loss: 0.6588 - accuracy: 0.7888
# Epoch 91/100
# 68/68 [==============================] - 22s 329ms/step - loss: 0.6540 - accuracy: 0.7930
# Epoch 92/100
# 68/68 [==============================] - 23s 335ms/step - loss: 0.6921 - accuracy: 0.7758
# Epoch 93/100
# 68/68 [==============================] - 22s 329ms/step - loss: 0.6043 - accuracy: 0.7944
# Epoch 94/100
# 68/68 [==============================] - 22s 329ms/step - loss: 0.6231 - accuracy: 0.7874
# Epoch 95/100
# 68/68 [==============================] - 23s 332ms/step - loss: 0.6726 - accuracy: 0.7865
# Epoch 96/100
# 68/68 [==============================] - 23s 332ms/step - loss: 0.6662 - accuracy: 0.7902
# Epoch 97/100
# 68/68 [==============================] - 22s 324ms/step - loss: 0.6668 - accuracy: 0.7856
# Epoch 98/100
# 68/68 [==============================] - 22s 325ms/step - loss: 0.6913 - accuracy: 0.7800
# Epoch 99/100
# 68/68 [==============================] - 22s 329ms/step - loss: 0.6373 - accuracy: 0.7958
# Epoch 100/100
# 68/68 [==============================] - 22s 329ms/step - loss: 0.7943 - accuracy: 0.7712
# Score for fold 3: loss of 0.5008293390274048; accuracy of 82.6815664768219%
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.4449298679828644 - Accuracy: 83.25581550598145%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.4277394115924835 - Accuracy: 84.74418520927429%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.5008293390274048 - Accuracy: 82.6815664768219%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 83.56052239735921 (+- 0.8691887888929176)
# > Loss: 0.45783287286758423
# ------------------------------------------------------------------------

# %%
acc_per_fold
# Out:
# [83.25581550598145, 84.74418520927429, 82.6815664768219]

# %%
loss_per_fold
# Out:
# [0.4449298679828644, 0.4277394115924835, 0.5008293390274048]

# %%
import pandas as pd
metrics = pd.DataFrame(acc_per_fold)
metrics = metrics.rename(columns={0:'accuracy'})
loss_df = pd.DataFrame(loss_per_fold)

# %%
metrics.head()
# Out:
#     accuracy
# 0  83.255816
# 1  84.744185
# 2  82.681566

# %%
metrics_df = metrics.join(loss_df.rename(columns={0:'loss'}))

# %%
metrics_df.head()
# Out:
#     accuracy      loss
# 0  83.255816  0.444930
# 1  84.744185  0.427739
# 2  82.681566  0.500829

# %%
report_csv_file = '/content/drive/MyDrive/Colab Notebooks/CTCov/Fold/VGG19/vgg_class_report.csv'
with open(report_csv_file, mode='w') as f:
    metrics_df.to_csv(f)
