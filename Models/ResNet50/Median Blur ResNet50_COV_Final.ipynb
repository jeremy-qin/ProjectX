# %% [markdown]
# Covid 19 CT scan Image classification with VGG19 pretrained model.
#
# Datasets: 2 public datasets stored in the folders CT_DATA (CT_COVID and CT_NonCovid) and SARS-COV-2-DATA.
#
# DATA-Split folder : initially used to split data from CT-DATA, but will not be used here in the final.

# %%
from builtins import range, input

from tensorflow.keras.layers import Input, Lambda, Dense, Flatten, AveragePooling2D, Dropout
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from sklearn.metrics import confusion_matrix, roc_curve
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

import os
import cv2
from glob import glob

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from tensorflow.keras.utils import to_categorical

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
cov_path = "/content/drive/MyDrive/Colab Notebooks/CTCov/CT_Data/CT_COVID/"
norm_path = "/content/drive/MyDrive/Colab Notebooks/CTCov/CT_Data/CT_NonCOVID/"

# %%
IMAGE_SIZE=[224,224]
epochs = 300
batch_size=32
#define paths
covid_path = '/content/drive/MyDrive/Colab Notebooks/CTCov/SARS-COV-2-Data/COVID'
noncovid_path = '/content/drive/MyDrive/Colab Notebooks/CTCov/SARS-COV-2-Data/NON-COVID'

# Use glob to grab images from path .jpg or jpeg
cov_files = glob(cov_path + '/*')
norm_files = glob(norm_path + '/*')

covid_files = glob(covid_path + '/*')
noncovid_files = glob(noncovid_path + '/*')

# %%
# Fetch Images and Class Labels from Files
cov_labels = []
norm_labels = []

cov_images=[]
norm_images=[]

for i in range(len(cov_files)):
  image = cv2.imread(cov_files[i]) # read file 
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # arrange format as per keras
  image = cv2.resize(image,(224,224)) # resize as per model
  cov_images.append(image) # append image
  cov_labels.append('CT_COVID') #append class label
  
for i in range(len(norm_files)):
  image = cv2.imread(norm_files[i])
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
  image = cv2.resize(image,(224,224))
  norm_images.append(image)
  norm_labels.append('CT_NonCOVID')

# %%
# Fetch Images and Class Labels from Files
covid_labels = []
noncovid_labels = []

covid_images=[]
noncovid_images=[]

for i in range(len(covid_files)):
  image = cv2.imread(covid_files[i]) # read file 
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # arrange format as per keras
  image = cv2.resize(image,(224,224)) # resize as per model
  covid_images.append(image) # append image
  covid_labels.append('CT_COVID') #append class label
  
for i in range(len(noncovid_files)):
  image = cv2.imread(noncovid_files[i])
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
  image = cv2.resize(image,(224,224))
  noncovid_images.append(image)
  noncovid_labels.append('CT_NonCOVID')

# %%
plt.imshow(covid_images[10])

# %%
covid_labels[10]
# Out:
# 'CT_COVID'

# %%
cov_img_all = np.concatenate((covid_images, cov_images), axis=0)
norm_img_all = np.concatenate((noncovid_images, norm_images),axis=0)

# %%
covid_labels = np.concatenate((covid_labels, cov_labels), axis=0)
noncovid_labels = np.concatenate((noncovid_labels, norm_labels),axis=0)

# %%
len(cov_img_all)
# Out:
# 1598

# %% [markdown]
# # Median Blur

# %%
blurred_cov = [cv2.medianBlur(img, 5) for img in cov_img_all]

# %%
blurred_norm = [cv2.medianBlur(img, 5) for img in norm_img_all]

# %%
plt.imshow(blurred_norm[100])

# %%
plt.imshow(norm_img_all[100])

# %%
len(blurred_cov)
# Out:
# 1598

# %%
covid_images = np.array(blurred_cov)/255
noncovid_images = np.array(blurred_norm)/255

# %%
plt.imshow(covid_images[10])

# %%
# Split into training and testing sets for both types of images
covid_x_train, covid_x_test, covid_y_train, covid_y_test = train_test_split(
    covid_images, covid_labels, test_size=0.2)
noncovid_x_train, noncovid_x_test, noncovid_y_train, noncovid_y_test = train_test_split(
    noncovid_images, noncovid_labels, test_size=0.2)

# Merge sets for both types of images
X_train = np.concatenate((noncovid_x_train, covid_x_train), axis=0)
X_test = np.concatenate((noncovid_x_test, covid_x_test), axis=0)
y_train = np.concatenate((noncovid_y_train, covid_y_train), axis=0)
y_test = np.concatenate((noncovid_y_test, covid_y_test), axis=0)

# Make labels into categories - either 0 or 1, for our model
y_train = LabelBinarizer().fit_transform(y_train)
y_train = to_categorical(y_train)

y_test = LabelBinarizer().fit_transform(y_test)
y_test = to_categorical(y_test)

# %%
# look at some images
def plot_images(images, title):
    nrows, ncols = 5, 8
    figsize = [10, 6]

    fig, ax = plt.subplots(nrows=nrows, ncols=ncols, figsize=figsize, facecolor=(1, 1, 1))

    for i, axi in enumerate(ax.flat):
        axi.imshow(images[i])
        axi.set_axis_off()

    plt.suptitle(title, fontsize=24)
    plt.tight_layout(pad=0.2, rect=[0, 0, 1, 0.9])
    plt.show()
plot_images(covid_images, 'Positive COVID-19 CT Scan')
plot_images(noncovid_images, 'Negative COVID-19 CT Scan')

# %%
plot_images(X_train, 'X_train')
plot_images(X_test, 'X_test')
# y_train and y_test contain class lables 0 and 1 representing COVID and NonCOVID for X_train and X_test

# %%
plt.imshow(covid_x_train[100])

# %% [markdown]
# # ResNet50 model

# %%
# Building Model
resnet = ResNet50(weights="imagenet", include_top=False,
    input_tensor=Input(shape=(224, 224, 3)))

outputs = resnet.output
outputs = Flatten(name="flatten")(outputs)
outputs = Dropout(0.5)(outputs)
outputs = Dense(2, activation="softmax")(outputs)

model = Model(inputs=resnet.input, outputs=outputs)

for layer in resnet.layers:
    layer.trainable = False

model.compile(
        loss='categorical_crossentropy', 
        optimizer='adam', 
        metrics=['accuracy']
)

train_aug = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True
)

# %%
res = model.fit(train_aug.flow(X_train, y_train, batch_size=batch_size),
                    validation_data=(X_test, y_test),
                    validation_steps=len(X_test) / batch_size,
                    steps_per_epoch=len(X_train) / batch_size,
                    epochs=epochs)
# Out:
# Epoch 1/300
# 80/80 [==============================] - 34s 363ms/step - loss: 1.9858 - accuracy: 0.5194 - val_loss: 0.9094 - val_accuracy: 0.5232
# Epoch 2/300
# 80/80 [==============================] - 28s 342ms/step - loss: 1.0816 - accuracy: 0.5299 - val_loss: 0.7357 - val_accuracy: 0.5991
# Epoch 3/300
# 80/80 [==============================] - 28s 341ms/step - loss: 1.1372 - accuracy: 0.5462 - val_loss: 0.6696 - val_accuracy: 0.6548
# Epoch 4/300
# 80/80 [==============================] - 28s 342ms/step - loss: 1.1242 - accuracy: 0.5434 - val_loss: 1.8602 - val_accuracy: 0.4985
# Epoch 5/300
# 80/80 [==============================] - 28s 342ms/step - loss: 1.3582 - accuracy: 0.5601 - val_loss: 1.3330 - val_accuracy: 0.5263
# Epoch 6/300
# 80/80 [==============================] - 28s 342ms/step - loss: 1.4048 - accuracy: 0.5481 - val_loss: 0.7858 - val_accuracy: 0.6084
# Epoch 7/300
# 80/80 [==============================] - 27s 341ms/step - loss: 1.1105 - accuracy: 0.5675 - val_loss: 1.0595 - val_accuracy: 0.5480
# Epoch 8/300
# 80/80 [==============================] - 28s 341ms/step - loss: 1.1018 - accuracy: 0.5690 - val_loss: 0.7270 - val_accuracy: 0.6115
# Epoch 9/300
# 80/80 [==============================] - 27s 340ms/step - loss: 1.0803 - accuracy: 0.5815 - val_loss: 0.8031 - val_accuracy: 0.6378
# Epoch 10/300
# 80/80 [==============================] - 27s 338ms/step - loss: 1.1557 - accuracy: 0.5667 - val_loss: 1.5692 - val_accuracy: 0.5015
# Epoch 11/300
# 80/80 [==============================] - 28s 342ms/step - loss: 1.3092 - accuracy: 0.5648 - val_loss: 0.6957 - val_accuracy: 0.6548
# Epoch 12/300
# 80/80 [==============================] - 28s 341ms/step - loss: 1.1232 - accuracy: 0.5807 - val_loss: 0.6481 - val_accuracy: 0.6780
# Epoch 13/300
# 80/80 [==============================] - 27s 335ms/step - loss: 1.0705 - accuracy: 0.5764 - val_loss: 0.8097 - val_accuracy: 0.6331
# Epoch 14/300
# 80/80 [==============================] - 27s 336ms/step - loss: 1.3828 - accuracy: 0.5636 - val_loss: 1.1520 - val_accuracy: 0.5418
# Epoch 15/300
# 80/80 [==============================] - 27s 340ms/step - loss: 1.3231 - accuracy: 0.5803 - val_loss: 0.7611 - val_accuracy: 0.6440
# Epoch 16/300
# 80/80 [==============================] - 27s 340ms/step - loss: 1.3279 - accuracy: 0.5780 - val_loss: 0.7584 - val_accuracy: 0.6331
# Epoch 17/300
# 80/80 [==============================] - 27s 340ms/step - loss: 1.1294 - accuracy: 0.5853 - val_loss: 0.7823 - val_accuracy: 0.6300
# Epoch 18/300
# 80/80 [==============================] - 28s 342ms/step - loss: 1.4195 - accuracy: 0.5597 - val_loss: 1.0309 - val_accuracy: 0.6146
# Epoch 19/300
# 80/80 [==============================] - 27s 333ms/step - loss: 1.2133 - accuracy: 0.5900 - val_loss: 0.7846 - val_accuracy: 0.6347
# Epoch 20/300
# 80/80 [==============================] - 27s 336ms/step - loss: 1.4147 - accuracy: 0.5718 - val_loss: 1.9979 - val_accuracy: 0.5046
# Epoch 21/300
# 80/80 [==============================] - 27s 337ms/step - loss: 1.1243 - accuracy: 0.6082 - val_loss: 0.7672 - val_accuracy: 0.6563
# Epoch 22/300
# 80/80 [==============================] - 27s 335ms/step - loss: 1.1503 - accuracy: 0.5853 - val_loss: 0.6623 - val_accuracy: 0.6796
# Epoch 23/300
# 80/80 [==============================] - 27s 335ms/step - loss: 1.0453 - accuracy: 0.5888 - val_loss: 0.6251 - val_accuracy: 0.7105
# Epoch 24/300
# 80/80 [==============================] - 27s 336ms/step - loss: 1.3469 - accuracy: 0.5780 - val_loss: 1.4285 - val_accuracy: 0.5449
# Epoch 25/300
# 80/80 [==============================] - 27s 334ms/step - loss: 1.1892 - accuracy: 0.5981 - val_loss: 0.7828 - val_accuracy: 0.6625
# Epoch 26/300
# 80/80 [==============================] - 27s 332ms/step - loss: 1.3142 - accuracy: 0.5884 - val_loss: 2.5263 - val_accuracy: 0.5062
# Epoch 27/300
# 80/80 [==============================] - 27s 332ms/step - loss: 1.3341 - accuracy: 0.5815 - val_loss: 0.6993 - val_accuracy: 0.6625
# Epoch 28/300
# 80/80 [==============================] - 27s 338ms/step - loss: 1.1376 - accuracy: 0.5958 - val_loss: 1.1519 - val_accuracy: 0.5635
# Epoch 29/300
# 80/80 [==============================] - 27s 335ms/step - loss: 1.0838 - accuracy: 0.5966 - val_loss: 0.7008 - val_accuracy: 0.6579
# Epoch 30/300
# 80/80 [==============================] - 27s 334ms/step - loss: 1.1788 - accuracy: 0.5904 - val_loss: 0.8626 - val_accuracy: 0.6393
# Epoch 31/300
# 80/80 [==============================] - 27s 336ms/step - loss: 1.1298 - accuracy: 0.6020 - val_loss: 0.8405 - val_accuracy: 0.6533
# Epoch 32/300
# 80/80 [==============================] - 27s 337ms/step - loss: 1.3119 - accuracy: 0.5803 - val_loss: 0.7441 - val_accuracy: 0.6331
# Epoch 33/300
# 80/80 [==============================] - 27s 335ms/step - loss: 1.0804 - accuracy: 0.6109 - val_loss: 0.6392 - val_accuracy: 0.6950
# Epoch 34/300
# 80/80 [==============================] - 27s 335ms/step - loss: 1.1702 - accuracy: 0.6082 - val_loss: 0.6461 - val_accuracy: 0.6950
# Epoch 35/300
# 80/80 [==============================] - 27s 334ms/step - loss: 1.1205 - accuracy: 0.6067 - val_loss: 0.8782 - val_accuracy: 0.6037
# Epoch 36/300
# 80/80 [==============================] - 27s 334ms/step - loss: 1.3988 - accuracy: 0.5799 - val_loss: 2.8933 - val_accuracy: 0.5170
# Epoch 37/300
# 80/80 [==============================] - 27s 336ms/step - loss: 1.2450 - accuracy: 0.6040 - val_loss: 1.0967 - val_accuracy: 0.5805
# Epoch 38/300
# 80/80 [==============================] - 28s 342ms/step - loss: 1.4298 - accuracy: 0.5853 - val_loss: 0.8925 - val_accuracy: 0.6409
# Epoch 39/300
# 80/80 [==============================] - 28s 342ms/step - loss: 1.4312 - accuracy: 0.5993 - val_loss: 1.7317 - val_accuracy: 0.5248
# Epoch 40/300
# 80/80 [==============================] - 29s 354ms/step - loss: 1.2898 - accuracy: 0.5958 - val_loss: 0.7742 - val_accuracy: 0.6594
# Epoch 41/300
# 80/80 [==============================] - 29s 362ms/step - loss: 1.2641 - accuracy: 0.5822 - val_loss: 1.0750 - val_accuracy: 0.5882
# Epoch 42/300
# 80/80 [==============================] - 28s 342ms/step - loss: 1.1851 - accuracy: 0.5943 - val_loss: 1.4112 - val_accuracy: 0.5526
# Epoch 43/300
# 80/80 [==============================] - 27s 338ms/step - loss: 1.3198 - accuracy: 0.5904 - val_loss: 0.7057 - val_accuracy: 0.6672
# Epoch 44/300
# 80/80 [==============================] - 28s 342ms/step - loss: 1.1832 - accuracy: 0.6040 - val_loss: 0.6609 - val_accuracy: 0.6904
# Epoch 45/300
# 80/80 [==============================] - 27s 337ms/step - loss: 1.0611 - accuracy: 0.6074 - val_loss: 1.0810 - val_accuracy: 0.5991
# Epoch 46/300
# 80/80 [==============================] - 27s 339ms/step - loss: 1.3561 - accuracy: 0.5803 - val_loss: 1.2273 - val_accuracy: 0.5774
# Epoch 47/300
# 80/80 [==============================] - 27s 336ms/step - loss: 1.2157 - accuracy: 0.6001 - val_loss: 0.6093 - val_accuracy: 0.7028
# Epoch 48/300
# 80/80 [==============================] - 27s 337ms/step - loss: 1.0618 - accuracy: 0.6195 - val_loss: 0.7393 - val_accuracy: 0.6765
# Epoch 49/300
# 80/80 [==============================] - 27s 336ms/step - loss: 1.1245 - accuracy: 0.6129 - val_loss: 0.7233 - val_accuracy: 0.6687
# Epoch 50/300
# 80/80 [==============================] - 27s 339ms/step - loss: 1.2360 - accuracy: 0.6012 - val_loss: 1.1622 - val_accuracy: 0.5820
# Epoch 51/300
# 80/80 [==============================] - 28s 341ms/step - loss: 1.3769 - accuracy: 0.5690 - val_loss: 0.8780 - val_accuracy: 0.6641
# Epoch 52/300
# 80/80 [==============================] - 27s 338ms/step - loss: 1.1832 - accuracy: 0.6024 - val_loss: 0.7418 - val_accuracy: 0.6471
# Epoch 53/300
# 80/80 [==============================] - 27s 341ms/step - loss: 1.3508 - accuracy: 0.5884 - val_loss: 1.2017 - val_accuracy: 0.5836
# Epoch 54/300
# 80/80 [==============================] - 27s 339ms/step - loss: 1.1898 - accuracy: 0.6109 - val_loss: 0.6226 - val_accuracy: 0.7183
# Epoch 55/300
# 80/80 [==============================] - 28s 341ms/step - loss: 1.2725 - accuracy: 0.6179 - val_loss: 0.6802 - val_accuracy: 0.7136
# Epoch 56/300
# 80/80 [==============================] - 27s 339ms/step - loss: 1.1482 - accuracy: 0.5904 - val_loss: 0.6752 - val_accuracy: 0.7105
# Epoch 57/300
# 80/80 [==============================] - 28s 342ms/step - loss: 1.1750 - accuracy: 0.6109 - val_loss: 0.7740 - val_accuracy: 0.6687
# Epoch 58/300
# 80/80 [==============================] - 28s 341ms/step - loss: 1.2187 - accuracy: 0.6191 - val_loss: 1.0920 - val_accuracy: 0.6254
# Epoch 59/300
# 80/80 [==============================] - 27s 339ms/step - loss: 1.4130 - accuracy: 0.5865 - val_loss: 1.2408 - val_accuracy: 0.6084
# Epoch 60/300
# 80/80 [==============================] - 28s 342ms/step - loss: 1.1716 - accuracy: 0.5896 - val_loss: 0.7020 - val_accuracy: 0.6889
# Epoch 61/300
# 80/80 [==============================] - 28s 342ms/step - loss: 1.0919 - accuracy: 0.6106 - val_loss: 0.6730 - val_accuracy: 0.6935
# Epoch 62/300
# 80/80 [==============================] - 28s 347ms/step - loss: 1.1302 - accuracy: 0.6016 - val_loss: 1.0513 - val_accuracy: 0.6316
# Epoch 63/300
# 80/80 [==============================] - 28s 344ms/step - loss: 1.1695 - accuracy: 0.6032 - val_loss: 0.6738 - val_accuracy: 0.6873
# Epoch 64/300
# 80/80 [==============================] - 28s 345ms/step - loss: 1.5423 - accuracy: 0.5756 - val_loss: 0.7336 - val_accuracy: 0.6858
# Epoch 65/300
# 80/80 [==============================] - 27s 340ms/step - loss: 1.5296 - accuracy: 0.5904 - val_loss: 0.7030 - val_accuracy: 0.6935
# Epoch 66/300
# 80/80 [==============================] - 27s 340ms/step - loss: 1.1829 - accuracy: 0.6245 - val_loss: 2.4352 - val_accuracy: 0.5248
# Epoch 67/300
# 80/80 [==============================] - 28s 342ms/step - loss: 1.5128 - accuracy: 0.5888 - val_loss: 0.7075 - val_accuracy: 0.7028
# Epoch 68/300
# 80/80 [==============================] - 28s 343ms/step - loss: 1.2606 - accuracy: 0.5981 - val_loss: 1.0604 - val_accuracy: 0.6099
# Epoch 69/300
# 80/80 [==============================] - 28s 350ms/step - loss: 1.2885 - accuracy: 0.6012 - val_loss: 0.6877 - val_accuracy: 0.7167
# Epoch 70/300
# 80/80 [==============================] - 28s 345ms/step - loss: 1.1903 - accuracy: 0.6071 - val_loss: 0.7582 - val_accuracy: 0.6734
# Epoch 71/300
# 80/80 [==============================] - 27s 341ms/step - loss: 1.5629 - accuracy: 0.5842 - val_loss: 1.1644 - val_accuracy: 0.6316
# Epoch 72/300
# 80/80 [==============================] - 27s 339ms/step - loss: 1.3274 - accuracy: 0.5989 - val_loss: 1.1636 - val_accuracy: 0.6130
# Epoch 73/300
# 80/80 [==============================] - 27s 340ms/step - loss: 1.0994 - accuracy: 0.6354 - val_loss: 0.6397 - val_accuracy: 0.7121
# Epoch 74/300
# 80/80 [==============================] - 27s 340ms/step - loss: 1.2311 - accuracy: 0.5970 - val_loss: 0.7158 - val_accuracy: 0.6811
# Epoch 75/300
# 80/80 [==============================] - 27s 338ms/step - loss: 1.5627 - accuracy: 0.5857 - val_loss: 0.6411 - val_accuracy: 0.7353
# Epoch 76/300
# 80/80 [==============================] - 28s 342ms/step - loss: 1.2419 - accuracy: 0.6059 - val_loss: 0.6929 - val_accuracy: 0.6889
# Epoch 77/300
# 80/80 [==============================] - 28s 342ms/step - loss: 1.2271 - accuracy: 0.6171 - val_loss: 0.6772 - val_accuracy: 0.6780
# Epoch 78/300
# 80/80 [==============================] - 27s 339ms/step - loss: 1.1617 - accuracy: 0.6117 - val_loss: 1.5529 - val_accuracy: 0.5650
# Epoch 79/300
# 80/80 [==============================] - 28s 344ms/step - loss: 1.1610 - accuracy: 0.6299 - val_loss: 0.6886 - val_accuracy: 0.7136
# Epoch 80/300
# 80/80 [==============================] - 27s 336ms/step - loss: 1.3578 - accuracy: 0.6032 - val_loss: 0.6555 - val_accuracy: 0.7121
# Epoch 81/300
# 80/80 [==============================] - 27s 335ms/step - loss: 1.2496 - accuracy: 0.6032 - val_loss: 0.9347 - val_accuracy: 0.6656
# Epoch 82/300
# 80/80 [==============================] - 27s 334ms/step - loss: 1.1019 - accuracy: 0.6249 - val_loss: 1.0445 - val_accuracy: 0.6053
# Epoch 83/300
# 80/80 [==============================] - 27s 333ms/step - loss: 1.3171 - accuracy: 0.5923 - val_loss: 2.2000 - val_accuracy: 0.5217
# Epoch 84/300
# 80/80 [==============================] - 27s 336ms/step - loss: 1.4089 - accuracy: 0.5943 - val_loss: 1.4194 - val_accuracy: 0.5635
# Epoch 85/300
# 80/80 [==============================] - 27s 334ms/step - loss: 1.4846 - accuracy: 0.5904 - val_loss: 0.7982 - val_accuracy: 0.6563
# Epoch 86/300
# 80/80 [==============================] - 27s 331ms/step - loss: 1.1751 - accuracy: 0.6144 - val_loss: 1.3603 - val_accuracy: 0.5604
# Epoch 87/300
# 80/80 [==============================] - 27s 335ms/step - loss: 1.5642 - accuracy: 0.5853 - val_loss: 0.7502 - val_accuracy: 0.6950
# Epoch 88/300
# 80/80 [==============================] - 27s 331ms/step - loss: 1.3010 - accuracy: 0.6067 - val_loss: 0.8060 - val_accuracy: 0.6981
# Epoch 89/300
# 80/80 [==============================] - 27s 335ms/step - loss: 1.1842 - accuracy: 0.6195 - val_loss: 0.8890 - val_accuracy: 0.6625
# Epoch 90/300
# 80/80 [==============================] - 27s 334ms/step - loss: 1.3568 - accuracy: 0.5993 - val_loss: 0.7910 - val_accuracy: 0.6858
# Epoch 91/300
# 80/80 [==============================] - 27s 334ms/step - loss: 1.4179 - accuracy: 0.5981 - val_loss: 1.9441 - val_accuracy: 0.5372
# Epoch 92/300
# 80/80 [==============================] - 27s 333ms/step - loss: 1.1479 - accuracy: 0.6183 - val_loss: 0.6404 - val_accuracy: 0.7229
# Epoch 93/300
# 80/80 [==============================] - 27s 338ms/step - loss: 1.4346 - accuracy: 0.5997 - val_loss: 0.7165 - val_accuracy: 0.7090
# Epoch 94/300
# 80/80 [==============================] - 27s 335ms/step - loss: 1.0700 - accuracy: 0.6330 - val_loss: 0.9167 - val_accuracy: 0.6455
# Epoch 95/300
# 80/80 [==============================] - 27s 333ms/step - loss: 1.2617 - accuracy: 0.6055 - val_loss: 1.4988 - val_accuracy: 0.5542
# Epoch 96/300
# 80/80 [==============================] - 27s 333ms/step - loss: 1.4301 - accuracy: 0.5873 - val_loss: 1.3605 - val_accuracy: 0.5789
# Epoch 97/300
# 80/80 [==============================] - 27s 334ms/step - loss: 1.3674 - accuracy: 0.5912 - val_loss: 0.7677 - val_accuracy: 0.6981
# Epoch 98/300
# 80/80 [==============================] - 27s 332ms/step - loss: 1.1381 - accuracy: 0.6191 - val_loss: 0.6753 - val_accuracy: 0.7183
# Epoch 99/300
# 80/80 [==============================] - 27s 334ms/step - loss: 1.1483 - accuracy: 0.6113 - val_loss: 1.2506 - val_accuracy: 0.5882
# Epoch 100/300
# 80/80 [==============================] - 27s 338ms/step - loss: 1.2256 - accuracy: 0.6206 - val_loss: 0.7026 - val_accuracy: 0.7291
# Epoch 101/300
# 80/80 [==============================] - 27s 333ms/step - loss: 1.1751 - accuracy: 0.6086 - val_loss: 0.7823 - val_accuracy: 0.6765
# Epoch 102/300
# 80/80 [==============================] - 27s 337ms/step - loss: 1.2368 - accuracy: 0.6086 - val_loss: 0.8091 - val_accuracy: 0.6703
# Epoch 103/300
# 80/80 [==============================] - 27s 333ms/step - loss: 1.3797 - accuracy: 0.6009 - val_loss: 0.8849 - val_accuracy: 0.6749
# Epoch 104/300
# 80/80 [==============================] - 27s 335ms/step - loss: 1.1538 - accuracy: 0.6218 - val_loss: 0.7378 - val_accuracy: 0.7229
# Epoch 105/300
# 80/80 [==============================] - 27s 335ms/step - loss: 1.2839 - accuracy: 0.5974 - val_loss: 0.7274 - val_accuracy: 0.7214
# Epoch 106/300
# 80/80 [==============================] - 27s 333ms/step - loss: 1.5634 - accuracy: 0.5873 - val_loss: 0.8566 - val_accuracy: 0.6780
# Epoch 107/300
# 80/80 [==============================] - 27s 333ms/step - loss: 1.1295 - accuracy: 0.6307 - val_loss: 0.7059 - val_accuracy: 0.7074
# Epoch 108/300
# 80/80 [==============================] - 27s 331ms/step - loss: 1.2199 - accuracy: 0.6040 - val_loss: 1.5828 - val_accuracy: 0.5557
# Epoch 109/300
# 80/80 [==============================] - 27s 333ms/step - loss: 1.7293 - accuracy: 0.5780 - val_loss: 1.3036 - val_accuracy: 0.5975
# Epoch 110/300
# 80/80 [==============================] - 27s 333ms/step - loss: 1.2917 - accuracy: 0.6024 - val_loss: 0.7513 - val_accuracy: 0.7028
# Epoch 111/300
# 80/80 [==============================] - 27s 333ms/step - loss: 1.5641 - accuracy: 0.5807 - val_loss: 0.9635 - val_accuracy: 0.6347
# Epoch 112/300
# 80/80 [==============================] - 27s 332ms/step - loss: 1.2620 - accuracy: 0.6393 - val_loss: 0.8745 - val_accuracy: 0.6563
# Epoch 113/300
# 80/80 [==============================] - 27s 334ms/step - loss: 1.3680 - accuracy: 0.6036 - val_loss: 2.4102 - val_accuracy: 0.5232
# Epoch 114/300
# 80/80 [==============================] - 27s 333ms/step - loss: 1.3537 - accuracy: 0.5950 - val_loss: 0.6725 - val_accuracy: 0.7121
# Epoch 115/300
# 80/80 [==============================] - 27s 334ms/step - loss: 1.2410 - accuracy: 0.6090 - val_loss: 2.9707 - val_accuracy: 0.5077
# Epoch 116/300
# 80/80 [==============================] - 27s 332ms/step - loss: 1.4604 - accuracy: 0.5974 - val_loss: 0.7139 - val_accuracy: 0.7074
# Epoch 117/300
# 80/80 [==============================] - 27s 333ms/step - loss: 1.2364 - accuracy: 0.6140 - val_loss: 0.9250 - val_accuracy: 0.6594
# Epoch 118/300
# 80/80 [==============================] - 27s 337ms/step - loss: 1.1468 - accuracy: 0.6272 - val_loss: 0.9603 - val_accuracy: 0.6548
# Epoch 119/300
# 80/80 [==============================] - 27s 338ms/step - loss: 1.1097 - accuracy: 0.6234 - val_loss: 0.6759 - val_accuracy: 0.7074
# Epoch 120/300
# 80/80 [==============================] - 27s 337ms/step - loss: 1.3595 - accuracy: 0.6055 - val_loss: 0.8830 - val_accuracy: 0.6656
# Epoch 121/300
# 80/80 [==============================] - 27s 333ms/step - loss: 1.1889 - accuracy: 0.6098 - val_loss: 1.1113 - val_accuracy: 0.6146
# Epoch 122/300
# 80/80 [==============================] - 27s 332ms/step - loss: 1.2217 - accuracy: 0.5997 - val_loss: 1.0269 - val_accuracy: 0.6347
# Epoch 123/300
# 80/80 [==============================] - 27s 331ms/step - loss: 1.0508 - accuracy: 0.6292 - val_loss: 0.7353 - val_accuracy: 0.7121
# Epoch 124/300
# 80/80 [==============================] - 27s 331ms/step - loss: 1.3065 - accuracy: 0.6133 - val_loss: 0.9415 - val_accuracy: 0.6594
# Epoch 125/300
# 80/80 [==============================] - 27s 332ms/step - loss: 1.2116 - accuracy: 0.6164 - val_loss: 0.9775 - val_accuracy: 0.6486
# Epoch 126/300
# 80/80 [==============================] - 27s 333ms/step - loss: 1.1346 - accuracy: 0.6206 - val_loss: 0.9883 - val_accuracy: 0.6223
# Epoch 127/300
# 80/80 [==============================] - 27s 333ms/step - loss: 1.4026 - accuracy: 0.6098 - val_loss: 0.7228 - val_accuracy: 0.7245
# Epoch 128/300
# 80/80 [==============================] - 27s 332ms/step - loss: 1.5170 - accuracy: 0.5853 - val_loss: 1.3626 - val_accuracy: 0.5882
# Epoch 129/300
# 80/80 [==============================] - 27s 334ms/step - loss: 1.1954 - accuracy: 0.6133 - val_loss: 0.8434 - val_accuracy: 0.6950
# Epoch 130/300
# 80/80 [==============================] - 27s 336ms/step - loss: 1.0618 - accuracy: 0.6377 - val_loss: 0.7488 - val_accuracy: 0.7090
# Epoch 131/300
# 80/80 [==============================] - 27s 334ms/step - loss: 1.1701 - accuracy: 0.6245 - val_loss: 1.2232 - val_accuracy: 0.6099
# Epoch 132/300
# 80/80 [==============================] - 27s 333ms/step - loss: 1.2353 - accuracy: 0.6171 - val_loss: 0.7608 - val_accuracy: 0.6997
# Epoch 133/300
# 80/80 [==============================] - 27s 331ms/step - loss: 1.0908 - accuracy: 0.6400 - val_loss: 0.7336 - val_accuracy: 0.7121
# Epoch 134/300
# 80/80 [==============================] - 27s 335ms/step - loss: 1.2341 - accuracy: 0.6074 - val_loss: 0.7747 - val_accuracy: 0.6765
# Epoch 135/300
# 80/80 [==============================] - 27s 333ms/step - loss: 1.0990 - accuracy: 0.6299 - val_loss: 1.9004 - val_accuracy: 0.5248
# Epoch 136/300
# 80/80 [==============================] - 27s 334ms/step - loss: 1.3678 - accuracy: 0.5896 - val_loss: 1.3755 - val_accuracy: 0.5681
# Epoch 137/300
# 80/80 [==============================] - 27s 335ms/step - loss: 1.2624 - accuracy: 0.6237 - val_loss: 0.7098 - val_accuracy: 0.7043
# Epoch 138/300
# 80/80 [==============================] - 27s 335ms/step - loss: 1.2189 - accuracy: 0.6074 - val_loss: 0.7105 - val_accuracy: 0.7074
# Epoch 139/300
# 80/80 [==============================] - 27s 336ms/step - loss: 1.1530 - accuracy: 0.6230 - val_loss: 0.8531 - val_accuracy: 0.6811
# Epoch 140/300
# 80/80 [==============================] - 27s 336ms/step - loss: 1.0866 - accuracy: 0.6179 - val_loss: 1.1221 - val_accuracy: 0.6115
# Epoch 141/300
# 80/80 [==============================] - 27s 333ms/step - loss: 1.3569 - accuracy: 0.6102 - val_loss: 0.8303 - val_accuracy: 0.7028
# Epoch 142/300
# 80/80 [==============================] - 27s 337ms/step - loss: 1.2439 - accuracy: 0.6102 - val_loss: 0.8189 - val_accuracy: 0.6734
# Epoch 143/300
# 80/80 [==============================] - 27s 334ms/step - loss: 1.2267 - accuracy: 0.6078 - val_loss: 0.8193 - val_accuracy: 0.6873
# Epoch 144/300
# 80/80 [==============================] - 27s 334ms/step - loss: 1.3196 - accuracy: 0.5946 - val_loss: 0.8571 - val_accuracy: 0.6889
# Epoch 145/300
# 80/80 [==============================] - 27s 335ms/step - loss: 1.3695 - accuracy: 0.6005 - val_loss: 1.0422 - val_accuracy: 0.6285
# Epoch 146/300
# 80/80 [==============================] - 27s 334ms/step - loss: 1.1378 - accuracy: 0.6249 - val_loss: 1.0813 - val_accuracy: 0.6285
# Epoch 147/300
# 80/80 [==============================] - 27s 337ms/step - loss: 1.1986 - accuracy: 0.6222 - val_loss: 0.6919 - val_accuracy: 0.7245
# Epoch 148/300
# 80/80 [==============================] - 27s 334ms/step - loss: 1.4304 - accuracy: 0.6005 - val_loss: 1.5002 - val_accuracy: 0.5712
# Epoch 149/300
# 80/80 [==============================] - 27s 336ms/step - loss: 1.2946 - accuracy: 0.6106 - val_loss: 0.8287 - val_accuracy: 0.6935
# Epoch 150/300
# 80/80 [==============================] - 27s 333ms/step - loss: 1.1795 - accuracy: 0.6206 - val_loss: 0.7904 - val_accuracy: 0.6718
# Epoch 151/300
# 80/80 [==============================] - 27s 336ms/step - loss: 1.4510 - accuracy: 0.6094 - val_loss: 1.3115 - val_accuracy: 0.6084
# Epoch 152/300
# 80/80 [==============================] - 27s 334ms/step - loss: 1.2994 - accuracy: 0.5954 - val_loss: 0.6899 - val_accuracy: 0.7260
# Epoch 153/300
# 80/80 [==============================] - 27s 332ms/step - loss: 1.5828 - accuracy: 0.6024 - val_loss: 2.4340 - val_accuracy: 0.5310
# Epoch 154/300
# 80/80 [==============================] - 27s 334ms/step - loss: 1.1197 - accuracy: 0.6416 - val_loss: 1.5953 - val_accuracy: 0.5681
# Epoch 155/300
# 80/80 [==============================] - 27s 332ms/step - loss: 1.3647 - accuracy: 0.6071 - val_loss: 1.0748 - val_accuracy: 0.6409
# Epoch 156/300
# 80/80 [==============================] - 27s 333ms/step - loss: 1.4743 - accuracy: 0.5954 - val_loss: 1.2070 - val_accuracy: 0.6037
# Epoch 157/300
# 80/80 [==============================] - 27s 332ms/step - loss: 1.3400 - accuracy: 0.6063 - val_loss: 0.9380 - val_accuracy: 0.6842
# Epoch 158/300
# 80/80 [==============================] - 27s 335ms/step - loss: 1.3883 - accuracy: 0.6074 - val_loss: 1.4693 - val_accuracy: 0.5697
# Epoch 159/300
# 80/80 [==============================] - 27s 332ms/step - loss: 1.4897 - accuracy: 0.6024 - val_loss: 1.3838 - val_accuracy: 0.5728
# Epoch 160/300
# 80/80 [==============================] - 27s 334ms/step - loss: 1.1784 - accuracy: 0.6210 - val_loss: 1.6334 - val_accuracy: 0.5542
# Epoch 161/300
# 80/80 [==============================] - 27s 333ms/step - loss: 1.3710 - accuracy: 0.5978 - val_loss: 1.2057 - val_accuracy: 0.6223
# Epoch 162/300
# 80/80 [==============================] - 27s 333ms/step - loss: 1.3251 - accuracy: 0.6106 - val_loss: 0.7154 - val_accuracy: 0.7121
# Epoch 163/300
# 80/80 [==============================] - 27s 329ms/step - loss: 1.1377 - accuracy: 0.6261 - val_loss: 0.6703 - val_accuracy: 0.7152
# Epoch 164/300
# 80/80 [==============================] - 27s 333ms/step - loss: 1.2058 - accuracy: 0.6191 - val_loss: 0.7038 - val_accuracy: 0.7012
# Epoch 165/300
# 80/80 [==============================] - 27s 330ms/step - loss: 1.1649 - accuracy: 0.6206 - val_loss: 2.2743 - val_accuracy: 0.5201
# Epoch 166/300
# 80/80 [==============================] - 27s 329ms/step - loss: 1.3141 - accuracy: 0.6086 - val_loss: 1.6815 - val_accuracy: 0.5526
# Epoch 167/300
# 80/80 [==============================] - 27s 337ms/step - loss: 1.4238 - accuracy: 0.6028 - val_loss: 0.8776 - val_accuracy: 0.6610
# Epoch 168/300
# 80/80 [==============================] - 27s 330ms/step - loss: 1.2978 - accuracy: 0.6268 - val_loss: 0.7348 - val_accuracy: 0.7074
# Epoch 169/300
# 80/80 [==============================] - 27s 333ms/step - loss: 1.2105 - accuracy: 0.6047 - val_loss: 1.5703 - val_accuracy: 0.5635
# Epoch 170/300
# 80/80 [==============================] - 27s 332ms/step - loss: 1.2817 - accuracy: 0.6063 - val_loss: 1.8104 - val_accuracy: 0.5495
# Epoch 171/300
# 80/80 [==============================] - 27s 333ms/step - loss: 1.2297 - accuracy: 0.6148 - val_loss: 0.9009 - val_accuracy: 0.6703
# Epoch 172/300
# 80/80 [==============================] - 27s 337ms/step - loss: 1.1062 - accuracy: 0.6249 - val_loss: 0.6682 - val_accuracy: 0.7461
# Epoch 173/300
# 80/80 [==============================] - 27s 336ms/step - loss: 1.3285 - accuracy: 0.6020 - val_loss: 2.7723 - val_accuracy: 0.5170
# Epoch 174/300
# 80/80 [==============================] - 27s 340ms/step - loss: 1.3064 - accuracy: 0.6152 - val_loss: 0.9145 - val_accuracy: 0.6873
# Epoch 175/300
# 80/80 [==============================] - 27s 337ms/step - loss: 1.0885 - accuracy: 0.6377 - val_loss: 0.6749 - val_accuracy: 0.7183
# Epoch 176/300
# 80/80 [==============================] - 27s 336ms/step - loss: 1.1008 - accuracy: 0.6342 - val_loss: 0.7246 - val_accuracy: 0.7090
# Epoch 177/300
# 80/80 [==============================] - 27s 336ms/step - loss: 1.2860 - accuracy: 0.5989 - val_loss: 0.8523 - val_accuracy: 0.6904
# Epoch 178/300
# 80/80 [==============================] - 27s 333ms/step - loss: 1.2806 - accuracy: 0.6082 - val_loss: 0.8174 - val_accuracy: 0.6950
# Epoch 179/300
# 80/80 [==============================] - 27s 333ms/step - loss: 1.2098 - accuracy: 0.6144 - val_loss: 0.7060 - val_accuracy: 0.6997
# Epoch 180/300
# 80/80 [==============================] - 27s 334ms/step - loss: 1.3638 - accuracy: 0.6078 - val_loss: 0.9959 - val_accuracy: 0.6625
# Epoch 181/300
# 80/80 [==============================] - 27s 331ms/step - loss: 1.3779 - accuracy: 0.6028 - val_loss: 0.7072 - val_accuracy: 0.7043
# Epoch 182/300
# 80/80 [==============================] - 27s 331ms/step - loss: 1.3097 - accuracy: 0.6160 - val_loss: 0.7730 - val_accuracy: 0.6811
# Epoch 183/300
# 80/80 [==============================] - 27s 330ms/step - loss: 1.2823 - accuracy: 0.5989 - val_loss: 0.7363 - val_accuracy: 0.6950
# Epoch 184/300
# 80/80 [==============================] - 28s 341ms/step - loss: 1.1842 - accuracy: 0.6164 - val_loss: 0.7237 - val_accuracy: 0.7105
# Epoch 185/300
# 80/80 [==============================] - 27s 337ms/step - loss: 1.1030 - accuracy: 0.6377 - val_loss: 0.7053 - val_accuracy: 0.7245
# Epoch 186/300
# 80/80 [==============================] - 27s 337ms/step - loss: 1.0994 - accuracy: 0.6350 - val_loss: 1.1002 - val_accuracy: 0.6269
# Epoch 187/300
# 80/80 [==============================] - 27s 337ms/step - loss: 1.1749 - accuracy: 0.6354 - val_loss: 0.7065 - val_accuracy: 0.7214
# Epoch 188/300
# 80/80 [==============================] - 27s 335ms/step - loss: 1.2964 - accuracy: 0.5985 - val_loss: 1.1244 - val_accuracy: 0.6238
# Epoch 189/300
# 80/80 [==============================] - 27s 332ms/step - loss: 1.1605 - accuracy: 0.6272 - val_loss: 0.6592 - val_accuracy: 0.7276
# Epoch 190/300
# 80/80 [==============================] - 27s 335ms/step - loss: 1.2523 - accuracy: 0.6152 - val_loss: 0.7001 - val_accuracy: 0.6966
# Epoch 191/300
# 80/80 [==============================] - 27s 335ms/step - loss: 1.1864 - accuracy: 0.6187 - val_loss: 0.6885 - val_accuracy: 0.7121
# Epoch 192/300
# 80/80 [==============================] - 27s 332ms/step - loss: 1.1365 - accuracy: 0.6280 - val_loss: 0.7575 - val_accuracy: 0.6904
# Epoch 193/300
# 80/80 [==============================] - 27s 333ms/step - loss: 1.2563 - accuracy: 0.6156 - val_loss: 0.9523 - val_accuracy: 0.6424
# Epoch 194/300
# 80/80 [==============================] - 27s 336ms/step - loss: 1.1682 - accuracy: 0.6202 - val_loss: 0.7763 - val_accuracy: 0.6935
# Epoch 195/300
# 80/80 [==============================] - 27s 333ms/step - loss: 1.1739 - accuracy: 0.6241 - val_loss: 1.0153 - val_accuracy: 0.6409
# Epoch 196/300
# 80/80 [==============================] - 27s 332ms/step - loss: 1.1533 - accuracy: 0.6272 - val_loss: 1.0453 - val_accuracy: 0.6393
# Epoch 197/300
# 80/80 [==============================] - 27s 336ms/step - loss: 1.3769 - accuracy: 0.6047 - val_loss: 0.7946 - val_accuracy: 0.7090
# Epoch 198/300
# 80/80 [==============================] - 27s 333ms/step - loss: 1.1315 - accuracy: 0.6280 - val_loss: 0.6702 - val_accuracy: 0.7260
# Epoch 199/300
# 80/80 [==============================] - 27s 331ms/step - loss: 1.3548 - accuracy: 0.6090 - val_loss: 1.3424 - val_accuracy: 0.6022
# Epoch 200/300
# 80/80 [==============================] - 27s 339ms/step - loss: 1.2439 - accuracy: 0.6315 - val_loss: 0.7181 - val_accuracy: 0.7167
# Epoch 201/300
# 80/80 [==============================] - 27s 333ms/step - loss: 1.3605 - accuracy: 0.6187 - val_loss: 0.6787 - val_accuracy: 0.7291
# Epoch 202/300
# 80/80 [==============================] - 27s 334ms/step - loss: 1.3248 - accuracy: 0.6230 - val_loss: 0.6471 - val_accuracy: 0.7260
# Epoch 203/300
# 80/80 [==============================] - 27s 333ms/step - loss: 1.1276 - accuracy: 0.6373 - val_loss: 0.7854 - val_accuracy: 0.7167
# Epoch 204/300
# 80/80 [==============================] - 27s 334ms/step - loss: 1.2561 - accuracy: 0.6133 - val_loss: 0.6933 - val_accuracy: 0.7152
# Epoch 205/300
# 80/80 [==============================] - 27s 334ms/step - loss: 1.2906 - accuracy: 0.6164 - val_loss: 0.9957 - val_accuracy: 0.6517
# Epoch 206/300
# 80/80 [==============================] - 27s 334ms/step - loss: 1.3947 - accuracy: 0.6055 - val_loss: 2.0260 - val_accuracy: 0.5387
# Epoch 207/300
# 80/80 [==============================] - 27s 337ms/step - loss: 1.3812 - accuracy: 0.6206 - val_loss: 1.4706 - val_accuracy: 0.5805
# Epoch 208/300
# 80/80 [==============================] - 27s 334ms/step - loss: 1.4996 - accuracy: 0.6113 - val_loss: 0.6651 - val_accuracy: 0.7245
# Epoch 209/300
# 80/80 [==============================] - 27s 333ms/step - loss: 1.1010 - accuracy: 0.6319 - val_loss: 0.6871 - val_accuracy: 0.7167
# Epoch 210/300
# 80/80 [==============================] - 27s 332ms/step - loss: 1.4628 - accuracy: 0.5923 - val_loss: 0.6847 - val_accuracy: 0.7136
# Epoch 211/300
# 80/80 [==============================] - 27s 334ms/step - loss: 1.2081 - accuracy: 0.6098 - val_loss: 0.7015 - val_accuracy: 0.7059
# Epoch 212/300
# 80/80 [==============================] - 27s 331ms/step - loss: 1.1421 - accuracy: 0.6191 - val_loss: 0.6413 - val_accuracy: 0.7415
# Epoch 213/300
# 80/80 [==============================] - 27s 332ms/step - loss: 1.1438 - accuracy: 0.6199 - val_loss: 0.7675 - val_accuracy: 0.7090
# Epoch 214/300
# 80/80 [==============================] - 27s 335ms/step - loss: 1.0814 - accuracy: 0.6358 - val_loss: 0.6616 - val_accuracy: 0.7446
# Epoch 215/300
# 80/80 [==============================] - 27s 332ms/step - loss: 1.4198 - accuracy: 0.6012 - val_loss: 0.6550 - val_accuracy: 0.7399
# Epoch 216/300
# 80/80 [==============================] - 27s 333ms/step - loss: 1.2546 - accuracy: 0.6078 - val_loss: 0.6931 - val_accuracy: 0.7307
# Epoch 217/300
# 80/80 [==============================] - 27s 337ms/step - loss: 1.2568 - accuracy: 0.6140 - val_loss: 0.8196 - val_accuracy: 0.7043
# Epoch 218/300
# 80/80 [==============================] - 27s 335ms/step - loss: 1.3149 - accuracy: 0.6121 - val_loss: 0.6556 - val_accuracy: 0.7461
# Epoch 219/300
# 80/80 [==============================] - 27s 334ms/step - loss: 1.4387 - accuracy: 0.6032 - val_loss: 1.7720 - val_accuracy: 0.5542
# Epoch 220/300
# 80/80 [==============================] - 27s 331ms/step - loss: 1.3260 - accuracy: 0.6226 - val_loss: 1.1855 - val_accuracy: 0.6053
# Epoch 221/300
# 80/80 [==============================] - 27s 331ms/step - loss: 1.4618 - accuracy: 0.6040 - val_loss: 0.8826 - val_accuracy: 0.7028
# Epoch 222/300
# 80/80 [==============================] - 27s 331ms/step - loss: 1.1578 - accuracy: 0.6202 - val_loss: 0.7478 - val_accuracy: 0.6935
# Epoch 223/300
# 80/80 [==============================] - 27s 335ms/step - loss: 1.1511 - accuracy: 0.6350 - val_loss: 1.0703 - val_accuracy: 0.6579
# Epoch 224/300
# 80/80 [==============================] - 27s 334ms/step - loss: 1.2163 - accuracy: 0.5981 - val_loss: 1.3487 - val_accuracy: 0.5882
# Epoch 225/300
# 80/80 [==============================] - 27s 331ms/step - loss: 1.4820 - accuracy: 0.6036 - val_loss: 0.8203 - val_accuracy: 0.6904
# Epoch 226/300
# 80/80 [==============================] - 27s 332ms/step - loss: 1.2749 - accuracy: 0.6086 - val_loss: 0.8480 - val_accuracy: 0.6873
# Epoch 227/300
# 80/80 [==============================] - 27s 335ms/step - loss: 1.2391 - accuracy: 0.6222 - val_loss: 0.6873 - val_accuracy: 0.7183
# Epoch 228/300
# 80/80 [==============================] - 27s 335ms/step - loss: 1.5246 - accuracy: 0.6074 - val_loss: 2.6126 - val_accuracy: 0.5108
# Epoch 229/300
# 80/80 [==============================] - 27s 334ms/step - loss: 1.3345 - accuracy: 0.6071 - val_loss: 1.3864 - val_accuracy: 0.5789
# Epoch 230/300
# 80/80 [==============================] - 27s 334ms/step - loss: 1.2513 - accuracy: 0.6137 - val_loss: 1.5167 - val_accuracy: 0.5666
# Epoch 231/300
# 80/80 [==============================] - 27s 333ms/step - loss: 1.2225 - accuracy: 0.6261 - val_loss: 0.9065 - val_accuracy: 0.6734
# Epoch 232/300
# 80/80 [==============================] - 27s 332ms/step - loss: 1.2360 - accuracy: 0.6144 - val_loss: 0.7300 - val_accuracy: 0.7291
# Epoch 233/300
# 80/80 [==============================] - 27s 332ms/step - loss: 1.3271 - accuracy: 0.6210 - val_loss: 1.0640 - val_accuracy: 0.6146
# Epoch 234/300
# 80/80 [==============================] - 27s 332ms/step - loss: 1.4381 - accuracy: 0.6009 - val_loss: 2.0867 - val_accuracy: 0.5480
# Epoch 235/300
# 80/80 [==============================] - 27s 335ms/step - loss: 1.4521 - accuracy: 0.6016 - val_loss: 1.4076 - val_accuracy: 0.6022
# Epoch 236/300
# 80/80 [==============================] - 27s 331ms/step - loss: 1.2997 - accuracy: 0.6210 - val_loss: 0.7762 - val_accuracy: 0.7121
# Epoch 237/300
# 80/80 [==============================] - 27s 332ms/step - loss: 1.2861 - accuracy: 0.6234 - val_loss: 2.1046 - val_accuracy: 0.5356
# Epoch 238/300
# 80/80 [==============================] - 27s 336ms/step - loss: 1.4015 - accuracy: 0.6094 - val_loss: 1.0704 - val_accuracy: 0.6594
# Epoch 239/300
# 80/80 [==============================] - 27s 330ms/step - loss: 1.1508 - accuracy: 0.6458 - val_loss: 0.8978 - val_accuracy: 0.6734
# Epoch 240/300
# 80/80 [==============================] - 27s 335ms/step - loss: 1.6271 - accuracy: 0.5815 - val_loss: 1.2619 - val_accuracy: 0.5929
# Epoch 241/300
# 80/80 [==============================] - 27s 337ms/step - loss: 1.2955 - accuracy: 0.6268 - val_loss: 1.1190 - val_accuracy: 0.6471
# Epoch 242/300
# 80/80 [==============================] - 27s 330ms/step - loss: 1.1061 - accuracy: 0.6373 - val_loss: 0.6860 - val_accuracy: 0.7415
# Epoch 243/300
# 80/80 [==============================] - 27s 335ms/step - loss: 1.1852 - accuracy: 0.6265 - val_loss: 0.8199 - val_accuracy: 0.6950
# Epoch 244/300
# 80/80 [==============================] - 27s 333ms/step - loss: 1.0947 - accuracy: 0.6381 - val_loss: 1.3069 - val_accuracy: 0.6130
# Epoch 245/300
# 80/80 [==============================] - 27s 332ms/step - loss: 1.4056 - accuracy: 0.6117 - val_loss: 1.2711 - val_accuracy: 0.6176
# Epoch 246/300
# 80/80 [==============================] - 27s 334ms/step - loss: 1.1886 - accuracy: 0.6334 - val_loss: 0.6678 - val_accuracy: 0.7415
# Epoch 247/300
# 80/80 [==============================] - 27s 332ms/step - loss: 1.1188 - accuracy: 0.6296 - val_loss: 0.6748 - val_accuracy: 0.7322
# Epoch 248/300
# 80/80 [==============================] - 27s 334ms/step - loss: 1.2192 - accuracy: 0.6249 - val_loss: 1.7170 - val_accuracy: 0.5511
# Epoch 249/300
# 80/80 [==============================] - 27s 336ms/step - loss: 1.3700 - accuracy: 0.5997 - val_loss: 0.8499 - val_accuracy: 0.6889
# Epoch 250/300
# 80/80 [==============================] - 27s 335ms/step - loss: 1.0852 - accuracy: 0.6307 - val_loss: 0.6561 - val_accuracy: 0.7337
# Epoch 251/300
# 80/80 [==============================] - 27s 334ms/step - loss: 1.0284 - accuracy: 0.6412 - val_loss: 0.8914 - val_accuracy: 0.6842
# Epoch 252/300
# 80/80 [==============================] - 27s 329ms/step - loss: 1.1355 - accuracy: 0.6299 - val_loss: 1.1632 - val_accuracy: 0.6440
# Epoch 253/300
# 80/80 [==============================] - 27s 330ms/step - loss: 1.1962 - accuracy: 0.6222 - val_loss: 0.6585 - val_accuracy: 0.7245
# Epoch 254/300
# 80/80 [==============================] - 27s 333ms/step - loss: 1.4630 - accuracy: 0.6005 - val_loss: 0.7049 - val_accuracy: 0.7152
# Epoch 255/300
# 80/80 [==============================] - 27s 335ms/step - loss: 1.4811 - accuracy: 0.5935 - val_loss: 0.6717 - val_accuracy: 0.7276
# Epoch 256/300
# 80/80 [==============================] - 26s 328ms/step - loss: 1.1215 - accuracy: 0.6299 - val_loss: 0.9856 - val_accuracy: 0.6703
# Epoch 257/300
# 80/80 [==============================] - 27s 333ms/step - loss: 1.2903 - accuracy: 0.6222 - val_loss: 0.7034 - val_accuracy: 0.7105
# Epoch 258/300
# 80/80 [==============================] - 27s 331ms/step - loss: 1.2050 - accuracy: 0.6195 - val_loss: 0.9814 - val_accuracy: 0.6625
# Epoch 259/300
# 80/80 [==============================] - 27s 332ms/step - loss: 1.2165 - accuracy: 0.6183 - val_loss: 0.6937 - val_accuracy: 0.6920
# Epoch 260/300
# 80/80 [==============================] - 27s 333ms/step - loss: 1.1760 - accuracy: 0.6265 - val_loss: 0.8125 - val_accuracy: 0.6827
# Epoch 261/300
# 80/80 [==============================] - 27s 333ms/step - loss: 1.2873 - accuracy: 0.6272 - val_loss: 0.8645 - val_accuracy: 0.6749
# Epoch 262/300
# 80/80 [==============================] - 27s 335ms/step - loss: 1.1972 - accuracy: 0.6187 - val_loss: 0.9275 - val_accuracy: 0.6656
# Epoch 263/300
# 80/80 [==============================] - 27s 331ms/step - loss: 1.0590 - accuracy: 0.6393 - val_loss: 0.6655 - val_accuracy: 0.7322
# Epoch 264/300
# 80/80 [==============================] - 27s 333ms/step - loss: 1.6116 - accuracy: 0.5873 - val_loss: 1.5776 - val_accuracy: 0.5898
# Epoch 265/300
# 80/80 [==============================] - 27s 333ms/step - loss: 1.2110 - accuracy: 0.6455 - val_loss: 1.1369 - val_accuracy: 0.6347
# Epoch 266/300
# 80/80 [==============================] - 27s 335ms/step - loss: 1.1305 - accuracy: 0.6137 - val_loss: 1.0438 - val_accuracy: 0.6424
# Epoch 267/300
# 80/80 [==============================] - 27s 335ms/step - loss: 1.1861 - accuracy: 0.6214 - val_loss: 0.7556 - val_accuracy: 0.7074
# Epoch 268/300
# 80/80 [==============================] - 27s 329ms/step - loss: 1.1128 - accuracy: 0.6234 - val_loss: 0.7855 - val_accuracy: 0.6966
# Epoch 269/300
# 80/80 [==============================] - 27s 333ms/step - loss: 1.4626 - accuracy: 0.6086 - val_loss: 1.9601 - val_accuracy: 0.5588
# Epoch 270/300
# 80/80 [==============================] - 27s 335ms/step - loss: 1.3549 - accuracy: 0.6090 - val_loss: 0.6720 - val_accuracy: 0.7136
# Epoch 271/300
# 80/80 [==============================] - 27s 335ms/step - loss: 1.3732 - accuracy: 0.6059 - val_loss: 0.6794 - val_accuracy: 0.7152
# Epoch 272/300
# 80/80 [==============================] - 27s 337ms/step - loss: 1.1636 - accuracy: 0.6276 - val_loss: 0.9200 - val_accuracy: 0.6672
# Epoch 273/300
# 80/80 [==============================] - 27s 335ms/step - loss: 1.1162 - accuracy: 0.6346 - val_loss: 0.7409 - val_accuracy: 0.6873
# Epoch 274/300
# 80/80 [==============================] - 27s 333ms/step - loss: 1.3260 - accuracy: 0.6113 - val_loss: 0.6537 - val_accuracy: 0.7260
# Epoch 275/300
# 80/80 [==============================] - 27s 334ms/step - loss: 1.3551 - accuracy: 0.6183 - val_loss: 1.6569 - val_accuracy: 0.5588
# Epoch 276/300
# 80/80 [==============================] - 27s 331ms/step - loss: 1.2734 - accuracy: 0.6090 - val_loss: 1.2249 - val_accuracy: 0.6269
# Epoch 277/300
# 80/80 [==============================] - 27s 333ms/step - loss: 1.1107 - accuracy: 0.6311 - val_loss: 0.6887 - val_accuracy: 0.7152
# Epoch 278/300
# 80/80 [==============================] - 27s 332ms/step - loss: 1.3174 - accuracy: 0.6059 - val_loss: 0.7152 - val_accuracy: 0.6842
# Epoch 279/300
# 80/80 [==============================] - 27s 332ms/step - loss: 1.2448 - accuracy: 0.6265 - val_loss: 0.6976 - val_accuracy: 0.7152
# Epoch 280/300
# 80/80 [==============================] - 27s 330ms/step - loss: 1.2973 - accuracy: 0.6156 - val_loss: 0.8190 - val_accuracy: 0.6811
# Epoch 281/300
# 80/80 [==============================] - 27s 333ms/step - loss: 1.3282 - accuracy: 0.6133 - val_loss: 2.0618 - val_accuracy: 0.5402
# Epoch 282/300
# 80/80 [==============================] - 27s 333ms/step - loss: 1.1376 - accuracy: 0.6396 - val_loss: 1.2936 - val_accuracy: 0.5975
# Epoch 283/300
# 80/80 [==============================] - 27s 337ms/step - loss: 1.1370 - accuracy: 0.6214 - val_loss: 0.8518 - val_accuracy: 0.6935
# Epoch 284/300
# 80/80 [==============================] - 27s 340ms/step - loss: 1.1794 - accuracy: 0.6237 - val_loss: 1.2228 - val_accuracy: 0.6192
# Epoch 285/300
# 80/80 [==============================] - 28s 343ms/step - loss: 1.2160 - accuracy: 0.6265 - val_loss: 0.7916 - val_accuracy: 0.6873
# Epoch 286/300
# 80/80 [==============================] - 28s 341ms/step - loss: 1.1968 - accuracy: 0.6199 - val_loss: 0.7705 - val_accuracy: 0.7105
# Epoch 287/300
# 80/80 [==============================] - 28s 342ms/step - loss: 1.3835 - accuracy: 0.5997 - val_loss: 1.3709 - val_accuracy: 0.5882
# Epoch 288/300
# 80/80 [==============================] - 27s 340ms/step - loss: 1.2938 - accuracy: 0.6102 - val_loss: 1.7073 - val_accuracy: 0.5650
# Epoch 289/300
# 80/80 [==============================] - 27s 339ms/step - loss: 1.2122 - accuracy: 0.6257 - val_loss: 0.8173 - val_accuracy: 0.7059
# Epoch 290/300
# 80/80 [==============================] - 27s 338ms/step - loss: 1.1983 - accuracy: 0.6218 - val_loss: 0.7606 - val_accuracy: 0.6966
# Epoch 291/300
# 80/80 [==============================] - 27s 332ms/step - loss: 1.2065 - accuracy: 0.6082 - val_loss: 0.6926 - val_accuracy: 0.7307
# Epoch 292/300
# 80/80 [==============================] - 27s 331ms/step - loss: 1.2193 - accuracy: 0.6051 - val_loss: 0.6901 - val_accuracy: 0.7229
# Epoch 293/300
# 80/80 [==============================] - 27s 332ms/step - loss: 1.2339 - accuracy: 0.6265 - val_loss: 0.7046 - val_accuracy: 0.7198
# Epoch 294/300
# 80/80 [==============================] - 27s 333ms/step - loss: 1.1179 - accuracy: 0.6362 - val_loss: 0.8871 - val_accuracy: 0.6796
# Epoch 295/300
# 80/80 [==============================] - 27s 333ms/step - loss: 1.2075 - accuracy: 0.6296 - val_loss: 0.7651 - val_accuracy: 0.7028
# Epoch 296/300
# 80/80 [==============================] - 27s 332ms/step - loss: 1.4243 - accuracy: 0.6078 - val_loss: 1.4350 - val_accuracy: 0.5789
# Epoch 297/300
# 80/80 [==============================] - 27s 331ms/step - loss: 1.2260 - accuracy: 0.6082 - val_loss: 1.2970 - val_accuracy: 0.5944
# Epoch 298/300
# 80/80 [==============================] - 27s 335ms/step - loss: 1.2907 - accuracy: 0.6218 - val_loss: 0.7126 - val_accuracy: 0.7291
# Epoch 299/300
# 80/80 [==============================] - 27s 334ms/step - loss: 1.0705 - accuracy: 0.6505 - val_loss: 0.6939 - val_accuracy: 0.7074
# Epoch 300/300
# 80/80 [==============================] - 27s 335ms/step - loss: 1.5219 - accuracy: 0.5946 - val_loss: 2.4776 - val_accuracy: 0.5387

# %%
# Save Model and Weights
model.save('/content/drive/MyDrive/Colab Notebooks/CTCov/Median blur/ResNet50/res_ct.h5')
model.save_weights('/content/drive/MyDrive/Colab Notebooks/CTCov/Median blur/ResNet50/res_weights_ct.hdf5')
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)

# %%
y_pred = model.predict(X_test, batch_size=batch_size)

# %%
prediction=y_pred[0:10]
for index, probability in enumerate(prediction):
  if probability[1] > 0.5:
        plt.title('%.2f' % (probability[1]*100) + '% COVID')
  else:
        plt.title('%.2f' % ((1-probability[1])*100) + '% NonCOVID')
  plt.imshow(X_test[index])
  plt.show()

# %%
# Convert to Binary classes
y_pred_bin = np.argmax(y_pred, axis=1)
y_test_bin = np.argmax(y_test, axis=1)

# %%
from sklearn.metrics import classification_report
report = classification_report(y_test_bin, y_pred_bin, output_dict=True)
print(report)
# Out:
# {'0': {'precision': 0.8928571428571429, 'recall': 0.078125, 'f1-score': 0.14367816091954022, 'support': 320}, '1': {'precision': 0.5226537216828478, 'recall': 0.99079754601227, 'f1-score': 0.6843220338983049, 'support': 326}, 'accuracy': 0.5386996904024768, 'macro avg': {'precision': 0.7077554322699954, 'recall': 0.534461273006135, 'f1-score': 0.4140000974089226, 'support': 646}, 'weighted avg': {'precision': 0.7060362213357494, 'recall': 0.5386996904024768, 'f1-score': 0.4165108274691955, 'support': 646}}

# %%
import pandas as pd
report_df = pd.DataFrame(report).transpose()
report_df
# Out:
#               precision    recall  f1-score   support
# 0              0.892857  0.078125  0.143678  320.0000
# 1              0.522654  0.990798  0.684322  326.0000
# accuracy       0.538700  0.538700  0.538700    0.5387
# macro avg      0.707755  0.534461  0.414000  646.0000
# weighted avg   0.706036  0.538700  0.416511  646.0000

# %%
# or save to csv: 
report_csv_file = '/content/drive/MyDrive/Colab Notebooks/CTCov/Median blur/ResNet50/res_class_report.csv'
with open(report_csv_file, mode='w') as f:
    report_df.to_csv(f)

# %%
test_report = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/CTCov/Median blur/ResNet50/res_class_report.csv')
test_report
# Out:
#      Unnamed: 0  precision    recall  f1-score   support
# 0             0   0.892857  0.078125  0.143678  320.0000
# 1             1   0.522654  0.990798  0.684322  326.0000
# 2      accuracy   0.538700  0.538700  0.538700    0.5387
# 3     macro avg   0.707755  0.534461  0.414000  646.0000
# 4  weighted avg   0.706036  0.538700  0.416511  646.0000

# %%
plt.plot(res.history['accuracy'])
plt.plot(res.history['val_accuracy'])

plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')

plt.legend(['Training', 'Testing'])
plt.savefig('/content/drive/MyDrive/Colab Notebooks/CTCov/Median blur/ResNet50/res_ct_accuracy.png')
plt.show()

# %%
plt.plot(res.history['loss'])
plt.plot(res.history['val_loss'])

plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')

plt.legend(['Training', 'Testing'])
plt.savefig('/content/drive/MyDrive/Colab Notebooks/CTCov/Median blur/ResNet50/res_ct_loss.png')
plt.show()

# %%
def plot_confusion_matrix(normalize):
  classes = ['COVID','NonCOVID']
  tick_marks = [0.5,1.5]
  cn = confusion_matrix(y_test_bin, y_pred_bin,normalize=normalize)
  sns.heatmap(cn,cmap='plasma',annot=True)
  plt.xticks(tick_marks, classes)
  plt.yticks(tick_marks, classes)
  plt.title('Confusion Matrix')
  plt.ylabel('True label')
  plt.xlabel('Predicted label')
  if normalize != 'true':
    plt.savefig("/content/drive/MyDrive/Colab Notebooks/CTCov/Median blur/ResNet50/res_conf_matrix_not_norm.png")
  else:
    plt.savefig("/content/drive/MyDrive/Colab Notebooks/CTCov/Median blur/ResNet50/res_conf_matrix_norm.png")
  plt.show()

print('Confusion Matrix without Normalization')
plot_confusion_matrix(normalize=None)
# print('Confusion Matrix with Normalized Values')
plot_confusion_matrix(normalize='true')
# Out:
# Confusion Matrix without Normalization

# %%
import pandas as pd

# convert the history.history dict to a pandas DataFrame:     
hist_df = pd.DataFrame(res.history)

# %%
hist_df.head()
# Out:
#        loss  accuracy  val_loss  val_accuracy
# 0  1.985774  0.519395  0.909369      0.523220
# 1  1.081590  0.529868  0.735732      0.599071
# 2  1.137241  0.546160  0.669606      0.654799
# 3  1.124213  0.543445  1.860170      0.498452
# 4  1.358220  0.560124  1.333024      0.526316

# %%
# save to json:  
hist_json_file = '/content/drive/MyDrive/Colab Notebooks/CTCov/Median blur/ResNet50/res_history.json' 
with open(hist_json_file, mode='w') as f:
    hist_df.to_json(f)

# or save to csv: 
hist_csv_file = '/content/drive/MyDrive/Colab Notebooks/CTCov/Median blur/ResNet50/res_history.csv'
with open(hist_csv_file, mode='w') as f:
    hist_df.to_csv(f)

# %%
test_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/CTCov/Median blur/ResNet50/res_history.csv')
test_df.head()
# Out:
#    Unnamed: 0      loss  accuracy  val_loss  val_accuracy
# 0           0  1.985774  0.519395  0.909369      0.523220
# 1           1  1.081590  0.529868  0.735732      0.599071
# 2           2  1.137241  0.546160  0.669606      0.654799
# 3           3  1.124213  0.543445  1.860170      0.498452
# 4           4  1.358220  0.560124  1.333024      0.526316
