# %% [markdown]
# Covid 19 CT scan Image classification with VGG19 pretrained model.
#
# Datasets: 2 public datasets stored in the folders CT_DATA (CT_COVID and CT_NonCovid) and SARS-COV-2-DATA.
#
# DATA-Split folder : initially used to split data from CT-DATA, but will not be used here in the final.

# %%
from builtins import range, input

from tensorflow.keras.layers import Input, Lambda, Dense, Flatten, AveragePooling2D, Dropout
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from sklearn.metrics import confusion_matrix, roc_curve
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

import os
import cv2
from glob import glob

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from tensorflow.keras.utils import to_categorical

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
cov_path = "/content/drive/MyDrive/Colab Notebooks/CTCov/CT_Data/CT_COVID/"
norm_path = "/content/drive/MyDrive/Colab Notebooks/CTCov/CT_Data/CT_NonCOVID/"

# %%
IMAGE_SIZE=[224,224]
epochs = 300
batch_size=32
#define paths
covid_path = '/content/drive/MyDrive/Colab Notebooks/CTCov/SARS-COV-2-Data/COVID'
noncovid_path = '/content/drive/MyDrive/Colab Notebooks/CTCov/SARS-COV-2-Data/NON-COVID'

# Use glob to grab images from path .jpg or jpeg
cov_files = glob(cov_path + '/*')
norm_files = glob(norm_path + '/*')

covid_files = glob(covid_path + '/*')
noncovid_files = glob(noncovid_path + '/*')

# %%
# Fetch Images and Class Labels from Files
cov_labels = []
norm_labels = []

cov_images=[]
norm_images=[]

for i in range(len(cov_files)):
  image = cv2.imread(cov_files[i]) # read file 
  image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) # arrange format as per keras
  image = cv2.resize(image,(224,224)) # resize as per model
  cov_images.append(image) # append image
  cov_labels.append('CT_COVID') #append class label
  
for i in range(len(norm_files)):
  image = cv2.imread(norm_files[i])
  image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
  image = cv2.resize(image,(224,224))
  norm_images.append(image)
  norm_labels.append('CT_NonCOVID')

# %%
# Fetch Images and Class Labels from Files
covid_labels = []
noncovid_labels = []

covid_images=[]
noncovid_images=[]

for i in range(len(covid_files)):
  image = cv2.imread(covid_files[i]) # read file 
  image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) # arrange format as per keras
  image = cv2.resize(image,(224,224)) # resize as per model
  covid_images.append(image) # append image
  covid_labels.append('CT_COVID') #append class label
  
for i in range(len(noncovid_files)):
  image = cv2.imread(noncovid_files[i])
  image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
  image = cv2.resize(image,(224,224))
  noncovid_images.append(image)
  noncovid_labels.append('CT_NonCOVID')

# %%
covid_images = np.concatenate((covid_images, cov_images), axis=0)
noncovid_images = np.concatenate((noncovid_images, norm_images),axis=0)

# %%
covid_labels = np.concatenate((covid_labels, cov_labels), axis=0)
noncovid_labels = np.concatenate((noncovid_labels, norm_labels),axis=0)

# %% [markdown]
# # CLAHE

# %%
clahe = cv2.createCLAHE(clipLimit=4.0)

# %%
covid_images = [clahe.apply(img) for img in covid_images]
noncovid_images = [clahe.apply(img) for img in noncovid_images]

# %%
plt.imshow(covid_images[100])

# %%
covid_images = [cv2.cvtColor(img, cv2.COLOR_BGR2RGB) for img in covid_images]

# %%
noncovid_images = [cv2.cvtColor(img, cv2.COLOR_BGR2RGB) for img in noncovid_images]

# %% [markdown]
# Normalize

# %%
covid_images = np.array(covid_images)/255
noncovid_images = np.array(noncovid_images)/255

# %%
len(covid_images)
# Out:
# 1598

# %%
# Split into training and testing sets for both types of images
covid_x_train, covid_x_test, covid_y_train, covid_y_test = train_test_split(
    covid_images, covid_labels, test_size=0.2)
noncovid_x_train, noncovid_x_test, noncovid_y_train, noncovid_y_test = train_test_split(
    noncovid_images, noncovid_labels, test_size=0.2)

# Merge sets for both types of images
X_train = np.concatenate((noncovid_x_train, covid_x_train), axis=0)
X_test = np.concatenate((noncovid_x_test, covid_x_test), axis=0)
y_train = np.concatenate((noncovid_y_train, covid_y_train), axis=0)
y_test = np.concatenate((noncovid_y_test, covid_y_test), axis=0)

# Make labels into categories - either 0 or 1, for our model
y_train = LabelBinarizer().fit_transform(y_train)
y_train = to_categorical(y_train)

y_test = LabelBinarizer().fit_transform(y_test)
y_test = to_categorical(y_test)

# %% [markdown]
# # ResNet50 model

# %%
from sklearn.model_selection import KFold

kfold = KFold(n_splits=3, shuffle=True)
inputs = np.concatenate((X_train, X_test), axis=0)
targets = np.concatenate((y_train, y_test), axis=0)

# Building Model
acc_per_fold = []
loss_per_fold = []
fold_no = 1

resnet = ResNet50(weights="imagenet", include_top=False,
  input_tensor=Input(shape=(224, 224, 3)))

for layer in resnet.layers:
      layer.trainable = False

train_aug = ImageDataGenerator(
      rotation_range=20,
      width_shift_range=0.2,
      height_shift_range=0.2,
      horizontal_flip=True
  )

for train, test in kfold.split(inputs, targets):

  outputs = resnet.output
  outputs = Flatten(name="flatten")(outputs)
  outputs = Dropout(0.5)(outputs)
  outputs = Dense(2, activation="softmax")(outputs)

  model = Model(inputs=resnet.input, outputs=outputs)


  model.compile(
          loss='categorical_crossentropy', 
          optimizer='adam', 
          metrics=['accuracy']
  )

  

  # Generate a print
  print('------------------------------------------------------------------------')
  print(f'Training for fold {fold_no} ...')
  model.fit(train_aug.flow(inputs[train], targets[train], batch_size=batch_size),
                    verbose=1,
                    epochs=100)
  
  # Generate generalization metrics
  scores = model.evaluate(inputs[test], targets[test], verbose=0)
  print(f'Score for fold {fold_no}: {model.metrics_names[0]} of {scores[0]}; {model.metrics_names[1]} of {scores[1]*100}%')
  acc_per_fold.append(scores[1] * 100)
  loss_per_fold.append(scores[0])

  # Increase fold number
  fold_no = fold_no + 1

# == Provide average scores ==
print('------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(acc_per_fold)):
  print('------------------------------------------------------------------------')
  print(f'> Fold {i+1} - Loss: {loss_per_fold[i]} - Accuracy: {acc_per_fold[i]}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(acc_per_fold)} (+- {np.std(acc_per_fold)})')
print(f'> Loss: {np.mean(loss_per_fold)}')
print('------------------------------------------------------------------------')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 1s 0us/step
# 94781440/94765736 [==============================] - 1s 0us/step
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Epoch 1/100
# 68/68 [==============================] - 29s 288ms/step - loss: 2.7154 - accuracy: 0.5100
# Epoch 2/100
# 68/68 [==============================] - 20s 290ms/step - loss: 0.9369 - accuracy: 0.5724
# Epoch 3/100
# 68/68 [==============================] - 20s 294ms/step - loss: 1.2332 - accuracy: 0.5719
# Epoch 4/100
# 68/68 [==============================] - 20s 303ms/step - loss: 1.2564 - accuracy: 0.5584
# Epoch 5/100
# 68/68 [==============================] - 20s 291ms/step - loss: 1.0187 - accuracy: 0.6184
# Epoch 6/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.9550 - accuracy: 0.6180
# Epoch 7/100
# 68/68 [==============================] - 20s 294ms/step - loss: 1.2239 - accuracy: 0.5947
# Epoch 8/100
# 68/68 [==============================] - 20s 297ms/step - loss: 1.0999 - accuracy: 0.6166
# Epoch 9/100
# 68/68 [==============================] - 20s 294ms/step - loss: 1.0412 - accuracy: 0.6105
# Epoch 10/100
# 68/68 [==============================] - 20s 295ms/step - loss: 1.1648 - accuracy: 0.6166
# Epoch 11/100
# 68/68 [==============================] - 20s 294ms/step - loss: 1.2994 - accuracy: 0.5924
# Epoch 12/100
# 68/68 [==============================] - 20s 292ms/step - loss: 1.0337 - accuracy: 0.6440
# Epoch 13/100
# 68/68 [==============================] - 20s 290ms/step - loss: 1.1396 - accuracy: 0.6282
# Epoch 14/100
# 68/68 [==============================] - 20s 293ms/step - loss: 1.3934 - accuracy: 0.6161
# Epoch 15/100
# 68/68 [==============================] - 20s 293ms/step - loss: 1.3015 - accuracy: 0.6077
# Epoch 16/100
# 68/68 [==============================] - 20s 292ms/step - loss: 1.2444 - accuracy: 0.6203
# Epoch 17/100
# 68/68 [==============================] - 20s 294ms/step - loss: 1.1088 - accuracy: 0.6352
# Epoch 18/100
# 68/68 [==============================] - 20s 294ms/step - loss: 1.2018 - accuracy: 0.6384
# Epoch 19/100
# 68/68 [==============================] - 20s 294ms/step - loss: 1.0931 - accuracy: 0.6263
# Epoch 20/100
# 68/68 [==============================] - 20s 294ms/step - loss: 1.0222 - accuracy: 0.6519
# Epoch 21/100
# 68/68 [==============================] - 20s 294ms/step - loss: 1.2006 - accuracy: 0.6142
# Epoch 22/100
# 68/68 [==============================] - 20s 293ms/step - loss: 1.1267 - accuracy: 0.6454
# Epoch 23/100
# 68/68 [==============================] - 20s 294ms/step - loss: 1.5538 - accuracy: 0.6138
# Epoch 24/100
# 68/68 [==============================] - 20s 293ms/step - loss: 1.1853 - accuracy: 0.6263
# Epoch 25/100
# 68/68 [==============================] - 20s 292ms/step - loss: 1.0497 - accuracy: 0.6505
# Epoch 26/100
# 68/68 [==============================] - 20s 295ms/step - loss: 1.1228 - accuracy: 0.6403
# Epoch 27/100
# 68/68 [==============================] - 20s 294ms/step - loss: 1.2924 - accuracy: 0.6059
# Epoch 28/100
# 68/68 [==============================] - 20s 289ms/step - loss: 1.2610 - accuracy: 0.6380
# Epoch 29/100
# 68/68 [==============================] - 20s 293ms/step - loss: 1.1949 - accuracy: 0.6482
# Epoch 30/100
# 68/68 [==============================] - 20s 293ms/step - loss: 1.0496 - accuracy: 0.6566
# Epoch 31/100
# 68/68 [==============================] - 20s 294ms/step - loss: 1.1849 - accuracy: 0.6282
# Epoch 32/100
# 68/68 [==============================] - 20s 292ms/step - loss: 1.1223 - accuracy: 0.6398
# Epoch 33/100
# 68/68 [==============================] - 20s 296ms/step - loss: 1.2545 - accuracy: 0.6450
# Epoch 34/100
# 68/68 [==============================] - 20s 291ms/step - loss: 1.1912 - accuracy: 0.6319
# Epoch 35/100
# 68/68 [==============================] - 20s 296ms/step - loss: 1.2425 - accuracy: 0.6389
# Epoch 36/100
# 68/68 [==============================] - 20s 294ms/step - loss: 1.2677 - accuracy: 0.6538
# Epoch 37/100
# 68/68 [==============================] - 20s 291ms/step - loss: 1.1268 - accuracy: 0.6543
# Epoch 38/100
# 68/68 [==============================] - 20s 293ms/step - loss: 1.0737 - accuracy: 0.6505
# Epoch 39/100
# 68/68 [==============================] - 20s 294ms/step - loss: 1.5458 - accuracy: 0.6254
# Epoch 40/100
# 68/68 [==============================] - 20s 293ms/step - loss: 1.3928 - accuracy: 0.6342
# Epoch 41/100
# 68/68 [==============================] - 20s 294ms/step - loss: 1.3541 - accuracy: 0.6473
# Epoch 42/100
# 68/68 [==============================] - 20s 292ms/step - loss: 1.1101 - accuracy: 0.6696
# Epoch 43/100
# 68/68 [==============================] - 20s 292ms/step - loss: 1.1251 - accuracy: 0.6473
# Epoch 44/100
# 68/68 [==============================] - 20s 291ms/step - loss: 1.4925 - accuracy: 0.6342
# Epoch 45/100
# 68/68 [==============================] - 20s 296ms/step - loss: 1.1081 - accuracy: 0.6640
# Epoch 46/100
# 68/68 [==============================] - 20s 292ms/step - loss: 1.3199 - accuracy: 0.6273
# Epoch 47/100
# 68/68 [==============================] - 20s 292ms/step - loss: 1.1086 - accuracy: 0.6617
# Epoch 48/100
# 68/68 [==============================] - 20s 291ms/step - loss: 1.3154 - accuracy: 0.6315
# Epoch 49/100
# 68/68 [==============================] - 20s 295ms/step - loss: 1.5341 - accuracy: 0.6105
# Epoch 50/100
# 68/68 [==============================] - 20s 290ms/step - loss: 1.2024 - accuracy: 0.6678
# Epoch 51/100
# 68/68 [==============================] - 20s 292ms/step - loss: 1.0723 - accuracy: 0.6854
# Epoch 52/100
# 68/68 [==============================] - 20s 292ms/step - loss: 1.2230 - accuracy: 0.6412
# Epoch 53/100
# 68/68 [==============================] - 20s 294ms/step - loss: 1.0327 - accuracy: 0.6687
# Epoch 54/100
# 68/68 [==============================] - 20s 294ms/step - loss: 1.0644 - accuracy: 0.6598
# Epoch 55/100
# 68/68 [==============================] - 20s 293ms/step - loss: 1.1017 - accuracy: 0.6654
# Epoch 56/100
# 68/68 [==============================] - 20s 293ms/step - loss: 1.7774 - accuracy: 0.6133
# Epoch 57/100
# 68/68 [==============================] - 20s 292ms/step - loss: 1.2345 - accuracy: 0.6510
# Epoch 58/100
# 68/68 [==============================] - 20s 288ms/step - loss: 1.2405 - accuracy: 0.6450
# Epoch 59/100
# 68/68 [==============================] - 20s 294ms/step - loss: 1.1297 - accuracy: 0.6668
# Epoch 60/100
# 68/68 [==============================] - 20s 296ms/step - loss: 1.6595 - accuracy: 0.6175
# Epoch 61/100
# 68/68 [==============================] - 20s 297ms/step - loss: 1.0612 - accuracy: 0.6836
# Epoch 62/100
# 68/68 [==============================] - 20s 295ms/step - loss: 1.0929 - accuracy: 0.6543
# Epoch 63/100
# 68/68 [==============================] - 20s 294ms/step - loss: 1.5131 - accuracy: 0.6273
# Epoch 64/100
# 68/68 [==============================] - 20s 292ms/step - loss: 1.3984 - accuracy: 0.6533
# Epoch 65/100
# 68/68 [==============================] - 20s 295ms/step - loss: 1.3038 - accuracy: 0.6519
# Epoch 66/100
# 68/68 [==============================] - 20s 296ms/step - loss: 1.1482 - accuracy: 0.6799
# Epoch 67/100
# 68/68 [==============================] - 20s 292ms/step - loss: 1.2585 - accuracy: 0.6496
# Epoch 68/100
# 68/68 [==============================] - 20s 291ms/step - loss: 1.2268 - accuracy: 0.6440
# Epoch 69/100
# 68/68 [==============================] - 20s 294ms/step - loss: 1.1358 - accuracy: 0.6608
# Epoch 70/100
# 68/68 [==============================] - 20s 292ms/step - loss: 1.1557 - accuracy: 0.6654
# Epoch 71/100
# 68/68 [==============================] - 20s 294ms/step - loss: 1.2107 - accuracy: 0.6496
# Epoch 72/100
# 68/68 [==============================] - 20s 292ms/step - loss: 1.2049 - accuracy: 0.6570
# Epoch 73/100
# 68/68 [==============================] - 20s 294ms/step - loss: 1.2869 - accuracy: 0.6496
# Epoch 74/100
# 68/68 [==============================] - 20s 292ms/step - loss: 1.3550 - accuracy: 0.6436
# Epoch 75/100
# 68/68 [==============================] - 20s 293ms/step - loss: 1.1925 - accuracy: 0.6682
# Epoch 76/100
# 68/68 [==============================] - 20s 291ms/step - loss: 1.2408 - accuracy: 0.6557
# Epoch 77/100
# 68/68 [==============================] - 20s 292ms/step - loss: 1.2245 - accuracy: 0.6538
# Epoch 78/100
# 68/68 [==============================] - 20s 291ms/step - loss: 1.2589 - accuracy: 0.6547
# Epoch 79/100
# 68/68 [==============================] - 20s 293ms/step - loss: 1.3980 - accuracy: 0.6436
# Epoch 80/100
# 68/68 [==============================] - 20s 291ms/step - loss: 1.1552 - accuracy: 0.6645
# Epoch 81/100
# 68/68 [==============================] - 20s 292ms/step - loss: 1.3024 - accuracy: 0.6519
# Epoch 82/100
# 68/68 [==============================] - 20s 294ms/step - loss: 1.2536 - accuracy: 0.6524
# Epoch 83/100
# 68/68 [==============================] - 20s 290ms/step - loss: 1.3546 - accuracy: 0.6575
# Epoch 84/100
# 68/68 [==============================] - 20s 293ms/step - loss: 1.1726 - accuracy: 0.6696
# Epoch 85/100
# 68/68 [==============================] - 20s 288ms/step - loss: 1.0451 - accuracy: 0.6896
# Epoch 86/100
# 68/68 [==============================] - 20s 292ms/step - loss: 1.3685 - accuracy: 0.6380
# Epoch 87/100
# 68/68 [==============================] - 20s 290ms/step - loss: 1.2560 - accuracy: 0.6603
# Epoch 88/100
# 68/68 [==============================] - 20s 292ms/step - loss: 1.3509 - accuracy: 0.6463
# Epoch 89/100
# 68/68 [==============================] - 20s 289ms/step - loss: 1.3463 - accuracy: 0.6622
# Epoch 90/100
# 68/68 [==============================] - 20s 289ms/step - loss: 1.2909 - accuracy: 0.6626
# Epoch 91/100
# 68/68 [==============================] - 20s 291ms/step - loss: 1.2497 - accuracy: 0.6636
# Epoch 92/100
# 68/68 [==============================] - 20s 291ms/step - loss: 1.1302 - accuracy: 0.6654
# Epoch 93/100
# 68/68 [==============================] - 20s 289ms/step - loss: 1.1800 - accuracy: 0.6491
# Epoch 94/100
# 68/68 [==============================] - 20s 289ms/step - loss: 1.1879 - accuracy: 0.6715
# Epoch 95/100
# 68/68 [==============================] - 20s 287ms/step - loss: 1.1507 - accuracy: 0.6668
# Epoch 96/100
# 68/68 [==============================] - 20s 290ms/step - loss: 1.1163 - accuracy: 0.6775
# Epoch 97/100
# 68/68 [==============================] - 20s 289ms/step - loss: 1.5222 - accuracy: 0.6287
# Epoch 98/100
# 68/68 [==============================] - 20s 292ms/step - loss: 1.4896 - accuracy: 0.6524
# Epoch 99/100
# 68/68 [==============================] - 20s 290ms/step - loss: 1.8665 - accuracy: 0.6110
# Epoch 100/100
# 68/68 [==============================] - 20s 291ms/step - loss: 1.2802 - accuracy: 0.6510
# Score for fold 1: loss of 3.036233901977539; accuracy of 50.325578451156616%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Epoch 1/100
# 68/68 [==============================] - 22s 290ms/step - loss: 1.4351 - accuracy: 0.5286
# Epoch 2/100
# 68/68 [==============================] - 20s 292ms/step - loss: 1.2048 - accuracy: 0.5668
# Epoch 3/100
# 68/68 [==============================] - 20s 292ms/step - loss: 1.2307 - accuracy: 0.5821
# Epoch 4/100
# 68/68 [==============================] - 20s 292ms/step - loss: 1.1484 - accuracy: 0.5980
# Epoch 5/100
# 68/68 [==============================] - 20s 293ms/step - loss: 1.1676 - accuracy: 0.5789
# Epoch 6/100
# 68/68 [==============================] - 20s 293ms/step - loss: 1.0530 - accuracy: 0.6012
# Epoch 7/100
# 68/68 [==============================] - 20s 294ms/step - loss: 1.1002 - accuracy: 0.6110
# Epoch 8/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.9990 - accuracy: 0.6273
# Epoch 9/100
# 68/68 [==============================] - 20s 291ms/step - loss: 1.0745 - accuracy: 0.6175
# Epoch 10/100
# 68/68 [==============================] - 20s 293ms/step - loss: 1.3392 - accuracy: 0.5980
# Epoch 11/100
# 68/68 [==============================] - 20s 298ms/step - loss: 1.0808 - accuracy: 0.6338
# Epoch 12/100
# 68/68 [==============================] - 20s 294ms/step - loss: 1.0432 - accuracy: 0.6166
# Epoch 13/100
# 68/68 [==============================] - 20s 293ms/step - loss: 1.0897 - accuracy: 0.6203
# Epoch 14/100
# 68/68 [==============================] - 20s 297ms/step - loss: 1.3225 - accuracy: 0.5942
# Epoch 15/100
# 68/68 [==============================] - 20s 295ms/step - loss: 1.3230 - accuracy: 0.6301
# Epoch 16/100
# 68/68 [==============================] - 20s 295ms/step - loss: 1.6316 - accuracy: 0.6021
# Epoch 17/100
# 68/68 [==============================] - 20s 294ms/step - loss: 1.2493 - accuracy: 0.6166
# Epoch 18/100
# 68/68 [==============================] - 20s 296ms/step - loss: 1.0211 - accuracy: 0.6496
# Epoch 19/100
# 68/68 [==============================] - 20s 298ms/step - loss: 1.1278 - accuracy: 0.6329
# Epoch 20/100
# 68/68 [==============================] - 20s 294ms/step - loss: 1.1209 - accuracy: 0.6249
# Epoch 21/100
# 68/68 [==============================] - 20s 295ms/step - loss: 1.5444 - accuracy: 0.6049
# Epoch 22/100
# 68/68 [==============================] - 20s 291ms/step - loss: 1.2622 - accuracy: 0.6319
# Epoch 23/100
# 68/68 [==============================] - 20s 295ms/step - loss: 1.3023 - accuracy: 0.6342
# Epoch 24/100
# 68/68 [==============================] - 20s 294ms/step - loss: 1.2045 - accuracy: 0.6445
# Epoch 25/100
# 68/68 [==============================] - 20s 293ms/step - loss: 1.2174 - accuracy: 0.6305
# Epoch 26/100
# 68/68 [==============================] - 20s 294ms/step - loss: 1.1897 - accuracy: 0.6217
# Epoch 27/100
# 68/68 [==============================] - 20s 294ms/step - loss: 1.4903 - accuracy: 0.6184
# Epoch 28/100
# 68/68 [==============================] - 20s 295ms/step - loss: 1.1844 - accuracy: 0.6487
# Epoch 29/100
# 68/68 [==============================] - 20s 292ms/step - loss: 1.2603 - accuracy: 0.6333
# Epoch 30/100
# 68/68 [==============================] - 20s 294ms/step - loss: 1.2900 - accuracy: 0.6221
# Epoch 31/100
# 68/68 [==============================] - 20s 294ms/step - loss: 1.1566 - accuracy: 0.6482
# Epoch 32/100
# 68/68 [==============================] - 20s 294ms/step - loss: 1.2405 - accuracy: 0.6315
# Epoch 33/100
# 68/68 [==============================] - 20s 293ms/step - loss: 1.3939 - accuracy: 0.6189
# Epoch 34/100
# 68/68 [==============================] - 20s 292ms/step - loss: 1.4207 - accuracy: 0.6194
# Epoch 35/100
# 68/68 [==============================] - 20s 294ms/step - loss: 1.5210 - accuracy: 0.6040
# Epoch 36/100
# 68/68 [==============================] - 20s 293ms/step - loss: 1.3357 - accuracy: 0.6510
# Epoch 37/100
# 68/68 [==============================] - 20s 293ms/step - loss: 1.7150 - accuracy: 0.6091
# Epoch 38/100
# 68/68 [==============================] - 20s 294ms/step - loss: 1.1238 - accuracy: 0.6650
# Epoch 39/100
# 68/68 [==============================] - 20s 292ms/step - loss: 1.2313 - accuracy: 0.6431
# Epoch 40/100
# 68/68 [==============================] - 20s 292ms/step - loss: 1.2708 - accuracy: 0.6496
# Epoch 41/100
# 68/68 [==============================] - 20s 295ms/step - loss: 1.0843 - accuracy: 0.6645
# Epoch 42/100
# 68/68 [==============================] - 20s 295ms/step - loss: 1.5057 - accuracy: 0.6315
# Epoch 43/100
# 68/68 [==============================] - 20s 294ms/step - loss: 1.2004 - accuracy: 0.6715
# Epoch 44/100
# 68/68 [==============================] - 20s 296ms/step - loss: 1.2143 - accuracy: 0.6477
# Epoch 45/100
# 68/68 [==============================] - 20s 294ms/step - loss: 1.3119 - accuracy: 0.6496
# Epoch 46/100
# 68/68 [==============================] - 20s 295ms/step - loss: 1.4274 - accuracy: 0.6296
# Epoch 47/100
# 68/68 [==============================] - 20s 293ms/step - loss: 1.5371 - accuracy: 0.6459
# Epoch 48/100
# 68/68 [==============================] - 20s 296ms/step - loss: 1.1452 - accuracy: 0.6626
# Epoch 49/100
# 68/68 [==============================] - 20s 294ms/step - loss: 1.3976 - accuracy: 0.6519
# Epoch 50/100
# 68/68 [==============================] - 20s 297ms/step - loss: 1.2252 - accuracy: 0.6510
# Epoch 51/100
# 68/68 [==============================] - 20s 296ms/step - loss: 1.3731 - accuracy: 0.6324
# Epoch 52/100
# 68/68 [==============================] - 20s 293ms/step - loss: 1.3063 - accuracy: 0.6412
# Epoch 53/100
# 68/68 [==============================] - 20s 295ms/step - loss: 1.3714 - accuracy: 0.6361
# Epoch 54/100
# 68/68 [==============================] - 20s 299ms/step - loss: 1.7451 - accuracy: 0.6156
# Epoch 55/100
# 68/68 [==============================] - 20s 297ms/step - loss: 1.6433 - accuracy: 0.6310
# Epoch 56/100
# 68/68 [==============================] - 20s 295ms/step - loss: 1.2722 - accuracy: 0.6561
# Epoch 57/100
# 68/68 [==============================] - 20s 292ms/step - loss: 1.1362 - accuracy: 0.6659
# Epoch 58/100
# 68/68 [==============================] - 20s 295ms/step - loss: 1.2485 - accuracy: 0.6519
# Epoch 59/100
# 68/68 [==============================] - 20s 296ms/step - loss: 1.0835 - accuracy: 0.6738
# Epoch 60/100
# 68/68 [==============================] - 20s 294ms/step - loss: 1.2716 - accuracy: 0.6533
# Epoch 61/100
# 68/68 [==============================] - 20s 295ms/step - loss: 1.0877 - accuracy: 0.6775
# Epoch 62/100
# 68/68 [==============================] - 20s 298ms/step - loss: 1.2159 - accuracy: 0.6626
# Epoch 63/100
# 68/68 [==============================] - 20s 294ms/step - loss: 1.0462 - accuracy: 0.6878
# Epoch 64/100
# 68/68 [==============================] - 20s 295ms/step - loss: 1.3097 - accuracy: 0.6408
# Epoch 65/100
# 68/68 [==============================] - 20s 294ms/step - loss: 1.1118 - accuracy: 0.6631
# Epoch 66/100
# 68/68 [==============================] - 20s 293ms/step - loss: 1.3844 - accuracy: 0.6445
# Epoch 67/100
# 68/68 [==============================] - 20s 300ms/step - loss: 1.3195 - accuracy: 0.6566
# Epoch 68/100
# 68/68 [==============================] - 20s 294ms/step - loss: 1.5819 - accuracy: 0.6263
# Epoch 69/100
# 68/68 [==============================] - 20s 295ms/step - loss: 1.1548 - accuracy: 0.6678
# Epoch 70/100
# 68/68 [==============================] - 20s 296ms/step - loss: 1.3322 - accuracy: 0.6366
# Epoch 71/100
# 68/68 [==============================] - 20s 296ms/step - loss: 1.3581 - accuracy: 0.6398
# Epoch 72/100
# 68/68 [==============================] - 20s 295ms/step - loss: 1.0138 - accuracy: 0.6961
# Epoch 73/100
# 68/68 [==============================] - 20s 293ms/step - loss: 1.3983 - accuracy: 0.6380
# Epoch 74/100
# 68/68 [==============================] - 20s 297ms/step - loss: 1.2002 - accuracy: 0.6491
# Epoch 75/100
# 68/68 [==============================] - 20s 296ms/step - loss: 1.3163 - accuracy: 0.6463
# Epoch 76/100
# 68/68 [==============================] - 20s 293ms/step - loss: 1.3962 - accuracy: 0.6338
# Epoch 77/100
# 68/68 [==============================] - 20s 295ms/step - loss: 1.1202 - accuracy: 0.6589
# Epoch 78/100
# 68/68 [==============================] - 20s 292ms/step - loss: 1.2344 - accuracy: 0.6557
# Epoch 79/100
# 68/68 [==============================] - 20s 297ms/step - loss: 1.1706 - accuracy: 0.6510
# Epoch 80/100
# 68/68 [==============================] - 20s 292ms/step - loss: 1.4900 - accuracy: 0.6417
# Epoch 81/100
# 68/68 [==============================] - 20s 292ms/step - loss: 1.6723 - accuracy: 0.6370
# Epoch 82/100
# 68/68 [==============================] - 20s 295ms/step - loss: 1.2963 - accuracy: 0.6580
# Epoch 83/100
# 68/68 [==============================] - 20s 296ms/step - loss: 1.3702 - accuracy: 0.6515
# Epoch 84/100
# 68/68 [==============================] - 20s 292ms/step - loss: 1.3352 - accuracy: 0.6491
# Epoch 85/100
# 68/68 [==============================] - 20s 293ms/step - loss: 1.2422 - accuracy: 0.6515
# Epoch 86/100
# 68/68 [==============================] - 20s 295ms/step - loss: 1.3678 - accuracy: 0.6640
# Epoch 87/100
# 68/68 [==============================] - 20s 293ms/step - loss: 1.2434 - accuracy: 0.6757
# Epoch 88/100
# 68/68 [==============================] - 20s 298ms/step - loss: 1.2164 - accuracy: 0.6664
# Epoch 89/100
# 68/68 [==============================] - 20s 296ms/step - loss: 1.1742 - accuracy: 0.6729
# Epoch 90/100
# 68/68 [==============================] - 20s 293ms/step - loss: 1.2631 - accuracy: 0.6487
# Epoch 91/100
# 68/68 [==============================] - 20s 297ms/step - loss: 1.2333 - accuracy: 0.6715
# Epoch 92/100
# 68/68 [==============================] - 20s 296ms/step - loss: 1.0532 - accuracy: 0.6715
# Epoch 93/100
# 68/68 [==============================] - 20s 295ms/step - loss: 1.2525 - accuracy: 0.6510
# Epoch 94/100
# 68/68 [==============================] - 20s 296ms/step - loss: 1.0969 - accuracy: 0.6775
# Epoch 95/100
# 68/68 [==============================] - 20s 297ms/step - loss: 1.4954 - accuracy: 0.6352
# Epoch 96/100
# 68/68 [==============================] - 20s 296ms/step - loss: 1.1766 - accuracy: 0.6738
# Epoch 97/100
# 68/68 [==============================] - 20s 298ms/step - loss: 1.1702 - accuracy: 0.6589
# Epoch 98/100
# 68/68 [==============================] - 20s 294ms/step - loss: 1.1826 - accuracy: 0.6645
# Epoch 99/100
# 68/68 [==============================] - 20s 294ms/step - loss: 1.1691 - accuracy: 0.6659
# Epoch 100/100
# 68/68 [==============================] - 20s 296ms/step - loss: 1.1130 - accuracy: 0.6729
# Score for fold 2: loss of 1.2503212690353394; accuracy of 63.8139545917511%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Epoch 1/100
# 68/68 [==============================] - 23s 301ms/step - loss: 1.6239 - accuracy: 0.5284
# Epoch 2/100
# 68/68 [==============================] - 20s 300ms/step - loss: 1.1059 - accuracy: 0.5558
# Epoch 3/100
# 68/68 [==============================] - 21s 302ms/step - loss: 1.1729 - accuracy: 0.5707
# Epoch 4/100
# 68/68 [==============================] - 21s 302ms/step - loss: 1.0935 - accuracy: 0.5823
# Epoch 5/100
# 68/68 [==============================] - 20s 298ms/step - loss: 1.2228 - accuracy: 0.5707
# Epoch 6/100
# 68/68 [==============================] - 20s 299ms/step - loss: 1.7895 - accuracy: 0.5549
# Epoch 7/100
# 68/68 [==============================] - 20s 295ms/step - loss: 1.2918 - accuracy: 0.6056
# Epoch 8/100
# 68/68 [==============================] - 20s 296ms/step - loss: 1.1665 - accuracy: 0.6019
# Epoch 9/100
# 68/68 [==============================] - 20s 294ms/step - loss: 1.0819 - accuracy: 0.6093
# Epoch 10/100
# 68/68 [==============================] - 20s 294ms/step - loss: 1.0528 - accuracy: 0.6060
# Epoch 11/100
# 68/68 [==============================] - 20s 292ms/step - loss: 1.4332 - accuracy: 0.5926
# Epoch 12/100
# 68/68 [==============================] - 20s 296ms/step - loss: 1.1219 - accuracy: 0.6149
# Epoch 13/100
# 68/68 [==============================] - 20s 293ms/step - loss: 1.0567 - accuracy: 0.6367
# Epoch 14/100
# 68/68 [==============================] - 20s 297ms/step - loss: 1.1459 - accuracy: 0.6279
# Epoch 15/100
# 68/68 [==============================] - 20s 293ms/step - loss: 1.2985 - accuracy: 0.6084
# Epoch 16/100
# 68/68 [==============================] - 20s 295ms/step - loss: 1.0923 - accuracy: 0.6265
# Epoch 17/100
# 68/68 [==============================] - 20s 296ms/step - loss: 1.0449 - accuracy: 0.6358
# Epoch 18/100
# 68/68 [==============================] - 20s 296ms/step - loss: 1.1054 - accuracy: 0.6400
# Epoch 19/100
# 68/68 [==============================] - 20s 295ms/step - loss: 1.0638 - accuracy: 0.6279
# Epoch 20/100
# 68/68 [==============================] - 20s 296ms/step - loss: 1.1209 - accuracy: 0.6316
# Epoch 21/100
# 68/68 [==============================] - 20s 292ms/step - loss: 1.3480 - accuracy: 0.6130
# Epoch 22/100
# 68/68 [==============================] - 20s 299ms/step - loss: 1.0294 - accuracy: 0.6437
# Epoch 23/100
# 68/68 [==============================] - 20s 293ms/step - loss: 1.1209 - accuracy: 0.6349
# Epoch 24/100
# 68/68 [==============================] - 20s 295ms/step - loss: 1.0886 - accuracy: 0.6474
# Epoch 25/100
# 68/68 [==============================] - 20s 294ms/step - loss: 1.0239 - accuracy: 0.6502
# Epoch 26/100
# 68/68 [==============================] - 20s 293ms/step - loss: 1.4672 - accuracy: 0.6242
# Epoch 27/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.9912 - accuracy: 0.6633
# Epoch 28/100
# 68/68 [==============================] - 20s 293ms/step - loss: 1.0423 - accuracy: 0.6512
# Epoch 29/100
# 68/68 [==============================] - 20s 296ms/step - loss: 1.2029 - accuracy: 0.6326
# Epoch 30/100
# 68/68 [==============================] - 20s 297ms/step - loss: 1.3168 - accuracy: 0.6307
# Epoch 31/100
# 68/68 [==============================] - 20s 297ms/step - loss: 1.2431 - accuracy: 0.6284
# Epoch 32/100
# 68/68 [==============================] - 20s 298ms/step - loss: 1.0651 - accuracy: 0.6553
# Epoch 33/100
# 68/68 [==============================] - 20s 294ms/step - loss: 1.0955 - accuracy: 0.6493
# Epoch 34/100
# 68/68 [==============================] - 20s 295ms/step - loss: 1.4180 - accuracy: 0.6000
# Epoch 35/100
# 68/68 [==============================] - 20s 298ms/step - loss: 1.1745 - accuracy: 0.6391
# Epoch 36/100
# 68/68 [==============================] - 20s 295ms/step - loss: 1.3477 - accuracy: 0.6312
# Epoch 37/100
# 68/68 [==============================] - 20s 295ms/step - loss: 1.0825 - accuracy: 0.6577
# Epoch 38/100
# 68/68 [==============================] - 20s 295ms/step - loss: 1.2958 - accuracy: 0.6391
# Epoch 39/100
# 68/68 [==============================] - 20s 298ms/step - loss: 1.0929 - accuracy: 0.6577
# Epoch 40/100
# 68/68 [==============================] - 20s 297ms/step - loss: 1.1369 - accuracy: 0.6437
# Epoch 41/100
# 68/68 [==============================] - 20s 297ms/step - loss: 1.6069 - accuracy: 0.6098
# Epoch 42/100
# 68/68 [==============================] - 20s 299ms/step - loss: 1.8170 - accuracy: 0.6047
# Epoch 43/100
# 68/68 [==============================] - 20s 297ms/step - loss: 1.1916 - accuracy: 0.6563
# Epoch 44/100
# 68/68 [==============================] - 20s 295ms/step - loss: 1.2578 - accuracy: 0.6405
# Epoch 45/100
# 68/68 [==============================] - 20s 298ms/step - loss: 1.1812 - accuracy: 0.6540
# Epoch 46/100
# 68/68 [==============================] - 20s 294ms/step - loss: 1.3469 - accuracy: 0.6372
# Epoch 47/100
# 68/68 [==============================] - 20s 297ms/step - loss: 1.0253 - accuracy: 0.6763
# Epoch 48/100
# 68/68 [==============================] - 20s 294ms/step - loss: 1.1550 - accuracy: 0.6609
# Epoch 49/100
# 68/68 [==============================] - 20s 296ms/step - loss: 1.1149 - accuracy: 0.6753
# Epoch 50/100
# 68/68 [==============================] - 20s 296ms/step - loss: 1.2356 - accuracy: 0.6460
# Epoch 51/100
# 68/68 [==============================] - 20s 297ms/step - loss: 1.1365 - accuracy: 0.6623
# Epoch 52/100
# 68/68 [==============================] - 20s 297ms/step - loss: 1.5766 - accuracy: 0.6247
# Epoch 53/100
# 68/68 [==============================] - 20s 295ms/step - loss: 1.2703 - accuracy: 0.6456
# Epoch 54/100
# 68/68 [==============================] - 20s 299ms/step - loss: 1.1294 - accuracy: 0.6526
# Epoch 55/100
# 68/68 [==============================] - 20s 296ms/step - loss: 1.1762 - accuracy: 0.6595
# Epoch 56/100
# 68/68 [==============================] - 20s 295ms/step - loss: 1.0661 - accuracy: 0.6684
# Epoch 57/100
# 68/68 [==============================] - 20s 295ms/step - loss: 1.1631 - accuracy: 0.6605
# Epoch 58/100
# 68/68 [==============================] - 20s 294ms/step - loss: 1.2002 - accuracy: 0.6395
# Epoch 59/100
# 68/68 [==============================] - 20s 297ms/step - loss: 1.0859 - accuracy: 0.6614
# Epoch 60/100
# 68/68 [==============================] - 20s 298ms/step - loss: 1.2039 - accuracy: 0.6465
# Epoch 61/100
# 68/68 [==============================] - 20s 296ms/step - loss: 1.1988 - accuracy: 0.6572
# Epoch 62/100
# 68/68 [==============================] - 20s 294ms/step - loss: 1.2192 - accuracy: 0.6535
# Epoch 63/100
# 68/68 [==============================] - 20s 298ms/step - loss: 1.0593 - accuracy: 0.6777
# Epoch 64/100
# 68/68 [==============================] - 20s 294ms/step - loss: 1.2045 - accuracy: 0.6558
# Epoch 65/100
# 68/68 [==============================] - 20s 298ms/step - loss: 1.1231 - accuracy: 0.6591
# Epoch 66/100
# 68/68 [==============================] - 20s 297ms/step - loss: 1.1262 - accuracy: 0.6623
# Epoch 67/100
# 68/68 [==============================] - 20s 296ms/step - loss: 1.2092 - accuracy: 0.6502
# Epoch 68/100
# 68/68 [==============================] - 20s 295ms/step - loss: 1.2598 - accuracy: 0.6507
# Epoch 69/100
# 68/68 [==============================] - 20s 297ms/step - loss: 1.0876 - accuracy: 0.6567
# Epoch 70/100
# 68/68 [==============================] - 20s 297ms/step - loss: 1.3645 - accuracy: 0.6237
# Epoch 71/100
# 68/68 [==============================] - 20s 295ms/step - loss: 1.2767 - accuracy: 0.6507
# Epoch 72/100
# 68/68 [==============================] - 20s 299ms/step - loss: 1.3274 - accuracy: 0.6451
# Epoch 73/100
# 68/68 [==============================] - 20s 296ms/step - loss: 1.3262 - accuracy: 0.6419
# Epoch 74/100
# 68/68 [==============================] - 20s 295ms/step - loss: 1.1460 - accuracy: 0.6470
# Epoch 75/100
# 68/68 [==============================] - 20s 299ms/step - loss: 1.0391 - accuracy: 0.6735
# Epoch 76/100
# 68/68 [==============================] - 20s 297ms/step - loss: 1.0504 - accuracy: 0.6716
# Epoch 77/100
# 68/68 [==============================] - 20s 297ms/step - loss: 1.0828 - accuracy: 0.6712
# Epoch 78/100
# 68/68 [==============================] - 20s 298ms/step - loss: 1.1948 - accuracy: 0.6581
# Epoch 79/100
# 68/68 [==============================] - 20s 295ms/step - loss: 1.1667 - accuracy: 0.6679
# Epoch 80/100
# 68/68 [==============================] - 20s 295ms/step - loss: 1.2425 - accuracy: 0.6526
# Epoch 81/100
# 68/68 [==============================] - 20s 298ms/step - loss: 1.2003 - accuracy: 0.6735
# Epoch 82/100
# 68/68 [==============================] - 20s 294ms/step - loss: 1.1739 - accuracy: 0.6563
# Epoch 83/100
# 68/68 [==============================] - 20s 297ms/step - loss: 1.4573 - accuracy: 0.6181
# Epoch 84/100
# 68/68 [==============================] - 20s 298ms/step - loss: 1.0779 - accuracy: 0.6740
# Epoch 85/100
# 68/68 [==============================] - 20s 294ms/step - loss: 1.2572 - accuracy: 0.6419
# Epoch 86/100
# 68/68 [==============================] - 20s 298ms/step - loss: 1.2545 - accuracy: 0.6600
# Epoch 87/100
# 68/68 [==============================] - 20s 298ms/step - loss: 1.3326 - accuracy: 0.6460
# Epoch 88/100
# 68/68 [==============================] - 20s 299ms/step - loss: 1.2883 - accuracy: 0.6642
# Epoch 89/100
# 68/68 [==============================] - 20s 296ms/step - loss: 1.3848 - accuracy: 0.6507
# Epoch 90/100
# 68/68 [==============================] - 20s 299ms/step - loss: 1.0798 - accuracy: 0.6874
# Epoch 91/100
# 68/68 [==============================] - 20s 298ms/step - loss: 1.0794 - accuracy: 0.6651
# Epoch 92/100
# 68/68 [==============================] - 20s 298ms/step - loss: 1.0902 - accuracy: 0.6642
# Epoch 93/100
# 68/68 [==============================] - 20s 295ms/step - loss: 1.3749 - accuracy: 0.6442
# Epoch 94/100
# 68/68 [==============================] - 20s 296ms/step - loss: 1.3852 - accuracy: 0.6405
# Epoch 95/100
# 68/68 [==============================] - 20s 299ms/step - loss: 1.3512 - accuracy: 0.6428
# Epoch 96/100
# 68/68 [==============================] - 20s 300ms/step - loss: 1.1689 - accuracy: 0.6749
# Epoch 97/100
# 68/68 [==============================] - 20s 299ms/step - loss: 1.2958 - accuracy: 0.6540
# Epoch 98/100
# 68/68 [==============================] - 20s 296ms/step - loss: 1.2280 - accuracy: 0.6763
# Epoch 99/100
# 68/68 [==============================] - 20s 295ms/step - loss: 1.2994 - accuracy: 0.6581
# Epoch 100/100
# 68/68 [==============================] - 20s 299ms/step - loss: 1.1784 - accuracy: 0.6679
# Score for fold 3: loss of 1.3171429634094238; accuracy of 65.36312699317932%
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 3.036233901977539 - Accuracy: 50.325578451156616%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 1.2503212690353394 - Accuracy: 63.8139545917511%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 1.3171429634094238 - Accuracy: 65.36312699317932%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 59.834220012029014 (+- 6.753304476683944)
# > Loss: 1.8678993781407673
# ------------------------------------------------------------------------

# %%
import pandas as pd
metrics = pd.DataFrame(acc_per_fold)
metrics = metrics.rename(columns={0:'accuracy'})
loss_df = pd.DataFrame(loss_per_fold)

# %%
metrics.head()
# Out:
#     accuracy
# 0  50.325578
# 1  63.813955
# 2  65.363127

# %%
metrics_df = metrics.join(loss_df.rename(columns={0:'loss'}))

# %%
metrics_df.head()
# Out:
#     accuracy      loss
# 0  50.325578  3.036234
# 1  63.813955  1.250321
# 2  65.363127  1.317143

# %%
report_csv_file = '/content/drive/MyDrive/Colab Notebooks/CTCov/Fold/ResNet50/res_clahe_class_report.csv'
with open(report_csv_file, mode='w') as f:
    metrics_df.to_csv(f)
