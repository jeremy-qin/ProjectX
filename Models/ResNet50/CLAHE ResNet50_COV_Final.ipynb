# %% [markdown]
# Covid 19 CT scan Image classification with VGG19 pretrained model.
#
# Datasets: 2 public datasets stored in the folders CT_DATA (CT_COVID and CT_NonCovid) and SARS-COV-2-DATA.
#
# DATA-Split folder : initially used to split data from CT-DATA, but will not be used here in the final.

# %%
from builtins import range, input

from tensorflow.keras.layers import Input, Lambda, Dense, Flatten, AveragePooling2D, Dropout
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from sklearn.metrics import confusion_matrix, roc_curve
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

import os
import cv2
from glob import glob

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from tensorflow.keras.utils import to_categorical

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
cov_path = "/content/drive/MyDrive/Colab Notebooks/CTCov/CT_Data/CT_COVID/"
norm_path = "/content/drive/MyDrive/Colab Notebooks/CTCov/CT_Data/CT_NonCOVID/"

# %%
IMAGE_SIZE=[224,224]
epochs = 300
batch_size=32
#define paths
covid_path = '/content/drive/MyDrive/Colab Notebooks/CTCov/SARS-COV-2-Data/COVID'
noncovid_path = '/content/drive/MyDrive/Colab Notebooks/CTCov/SARS-COV-2-Data/NON-COVID'

# Use glob to grab images from path .jpg or jpeg
cov_files = glob(cov_path + '/*')
norm_files = glob(norm_path + '/*')

covid_files = glob(covid_path + '/*')
noncovid_files = glob(noncovid_path + '/*')

# %%
# Fetch Images and Class Labels from Files
cov_labels = []
norm_labels = []

cov_images=[]
norm_images=[]

for i in range(len(cov_files)):
  image = cv2.imread(cov_files[i]) # read file 
  image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) # arrange format as per keras
  image = cv2.resize(image,(224,224)) # resize as per model
  cov_images.append(image) # append image
  cov_labels.append('CT_COVID') #append class label
  
for i in range(len(norm_files)):
  image = cv2.imread(norm_files[i])
  image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
  image = cv2.resize(image,(224,224))
  norm_images.append(image)
  norm_labels.append('CT_NonCOVID')

# %%
# Fetch Images and Class Labels from Files
covid_labels = []
noncovid_labels = []

covid_images=[]
noncovid_images=[]

for i in range(len(covid_files)):
  image = cv2.imread(covid_files[i]) # read file 
  image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) # arrange format as per keras
  image = cv2.resize(image,(224,224)) # resize as per model
  covid_images.append(image) # append image
  covid_labels.append('CT_COVID') #append class label
  
for i in range(len(noncovid_files)):
  image = cv2.imread(noncovid_files[i])
  image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
  image = cv2.resize(image,(224,224))
  noncovid_images.append(image)
  noncovid_labels.append('CT_NonCOVID')

# %%
plt.imshow(covid_images[10])

# %%
covid_labels[10]
# Out:
# 'CT_COVID'

# %%
cov_img_all = np.concatenate((covid_images, cov_images), axis=0)
norm_img_all = np.concatenate((noncovid_images, norm_images),axis=0)

# %%
covid_labels = np.concatenate((covid_labels, cov_labels), axis=0)
noncovid_labels = np.concatenate((noncovid_labels, norm_labels),axis=0)

# %%
len(cov_img_all)
# Out:
# 1598

# %% [markdown]
# # CLAHE

# %%
clahe = cv2.createCLAHE(clipLimit=4.0)

# %%
clahe_cov_img = [clahe.apply(img) for img in cov_img_all]
clahe_norm_img = [clahe.apply(img) for img in norm_img_all]

# %%
plt.imshow(clahe_cov_img[100], cmap='gray')

# %%
plt.imshow(cov_img_all[100])

# %%
rgb_cov = [cv2.cvtColor(img, cv2.COLOR_BGR2RGB) for img in clahe_cov_img]

# %%
plt.imshow(rgb_cov[100])

# %%
rgb_norm = [cv2.cvtColor(img, cv2.COLOR_BGR2RGB) for img in clahe_norm_img]

# %% [markdown]
# Normalize

# %%
covid_images = np.array(rgb_cov)/255
noncovid_images = np.array(rgb_norm)/255

# %%
plt.imshow(covid_images[100])

# %%
# Split into training and testing sets for both types of images
covid_x_train, covid_x_test, covid_y_train, covid_y_test = train_test_split(
    covid_images, covid_labels, test_size=0.2)
noncovid_x_train, noncovid_x_test, noncovid_y_train, noncovid_y_test = train_test_split(
    noncovid_images, noncovid_labels, test_size=0.2)

# Merge sets for both types of images
X_train = np.concatenate((noncovid_x_train, covid_x_train), axis=0)
X_test = np.concatenate((noncovid_x_test, covid_x_test), axis=0)
y_train = np.concatenate((noncovid_y_train, covid_y_train), axis=0)
y_test = np.concatenate((noncovid_y_test, covid_y_test), axis=0)

# Make labels into categories - either 0 or 1, for our model
y_train = LabelBinarizer().fit_transform(y_train)
y_train = to_categorical(y_train)

y_test = LabelBinarizer().fit_transform(y_test)
y_test = to_categorical(y_test)

# %%
# look at some images
def plot_images(images, title):
    nrows, ncols = 5, 8
    figsize = [10, 6]

    fig, ax = plt.subplots(nrows=nrows, ncols=ncols, figsize=figsize, facecolor=(1, 1, 1))

    for i, axi in enumerate(ax.flat):
        axi.imshow(images[i])
        axi.set_axis_off()

    plt.suptitle(title, fontsize=24)
    plt.tight_layout(pad=0.2, rect=[0, 0, 1, 0.9])
    plt.show()
plot_images(covid_images, 'Positive COVID-19 CT Scan')
plot_images(noncovid_images, 'Negative COVID-19 CT Scan')

# %%
plot_images(X_train, 'X_train')
plot_images(X_test, 'X_test')
# y_train and y_test contain class lables 0 and 1 representing COVID and NonCOVID for X_train and X_test

# %%
plt.imshow(covid_x_train[100])

# %% [markdown]
# # ResNet50 model

# %%
# Building Model
resnet = ResNet50(weights="imagenet", include_top=False,
    input_tensor=Input(shape=(224, 224, 3)))

outputs = resnet.output
outputs = Flatten(name="flatten")(outputs)
outputs = Dropout(0.5)(outputs)
outputs = Dense(2, activation="softmax")(outputs)

model = Model(inputs=resnet.input, outputs=outputs)

for layer in resnet.layers:
    layer.trainable = False

model.compile(
        loss='categorical_crossentropy', 
        optimizer='adam', 
        metrics=['accuracy']
)

train_aug = ImageDataGenerator(
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 1s 0us/step
# 94781440/94765736 [==============================] - 1s 0us/step

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  conv1_pad (ZeroPadding2D)      (None, 230, 230, 3)  0           ['input_1[0][0]']
#
#  conv1_conv (Conv2D)            (None, 112, 112, 64  9472        ['conv1_pad[0][0]']
#                                 )
#
#  conv1_bn (BatchNormalization)  (None, 112, 112, 64  256         ['conv1_conv[0][0]']
#                                 )
#
#  conv1_relu (Activation)        (None, 112, 112, 64  0           ['conv1_bn[0][0]']
#                                 )
#
#  pool1_pad (ZeroPadding2D)      (None, 114, 114, 64  0           ['conv1_relu[0][0]']
#                                 )
#
#  pool1_pool (MaxPooling2D)      (None, 56, 56, 64)   0           ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2D)   (None, 56, 56, 64)   4160        ['pool1_pool[0][0]']
#
#  conv2_block1_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_1_conv[0][0]']
#  ization)
#
#  conv2_block1_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_1_bn[0][0]']
#  n)
#
#  conv2_block1_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block1_1_relu[0][0]']
#
#  conv2_block1_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block1_2_conv[0][0]']
#  ization)
#
#  conv2_block1_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block1_2_bn[0][0]']
#  n)
#
#  conv2_block1_0_conv (Conv2D)   (None, 56, 56, 256)  16640       ['pool1_pool[0][0]']
#
#  conv2_block1_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block1_2_relu[0][0]']
#
#  conv2_block1_0_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block1_0_conv[0][0]']
#  ization)
#
#  conv2_block1_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block1_3_conv[0][0]']
#  ization)
#
#  conv2_block1_add (Add)         (None, 56, 56, 256)  0           ['conv2_block1_0_bn[0][0]',
#                                                                   'conv2_block1_3_bn[0][0]']
#
#  conv2_block1_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block1_add[0][0]']
#
#  conv2_block2_1_conv (Conv2D)   (None, 56, 56, 64)   16448       ['conv2_block1_out[0][0]']
#
#  conv2_block2_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_1_conv[0][0]']
#  ization)
#
#  conv2_block2_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_1_bn[0][0]']
#  n)
#
#  conv2_block2_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block2_1_relu[0][0]']
#
#  conv2_block2_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block2_2_conv[0][0]']
#  ization)
#
#  conv2_block2_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block2_2_bn[0][0]']
#  n)
#
#  conv2_block2_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block2_2_relu[0][0]']
#
#  conv2_block2_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block2_3_conv[0][0]']
#  ization)
#
#  conv2_block2_add (Add)         (None, 56, 56, 256)  0           ['conv2_block1_out[0][0]',
#                                                                   'conv2_block2_3_bn[0][0]']
#
#  conv2_block2_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block2_add[0][0]']
#
#  conv2_block3_1_conv (Conv2D)   (None, 56, 56, 64)   16448       ['conv2_block2_out[0][0]']
#
#  conv2_block3_1_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_1_conv[0][0]']
#  ization)
#
#  conv2_block3_1_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_1_bn[0][0]']
#  n)
#
#  conv2_block3_2_conv (Conv2D)   (None, 56, 56, 64)   36928       ['conv2_block3_1_relu[0][0]']
#
#  conv2_block3_2_bn (BatchNormal  (None, 56, 56, 64)  256         ['conv2_block3_2_conv[0][0]']
#  ization)
#
#  conv2_block3_2_relu (Activatio  (None, 56, 56, 64)  0           ['conv2_block3_2_bn[0][0]']
#  n)
#
#  conv2_block3_3_conv (Conv2D)   (None, 56, 56, 256)  16640       ['conv2_block3_2_relu[0][0]']
#
#  conv2_block3_3_bn (BatchNormal  (None, 56, 56, 256)  1024       ['conv2_block3_3_conv[0][0]']
#  ization)
#
#  conv2_block3_add (Add)         (None, 56, 56, 256)  0           ['conv2_block2_out[0][0]',
#                                                                   'conv2_block3_3_bn[0][0]']
#
#  conv2_block3_out (Activation)  (None, 56, 56, 256)  0           ['conv2_block3_add[0][0]']
#
#  conv3_block1_1_conv (Conv2D)   (None, 28, 28, 128)  32896       ['conv2_block3_out[0][0]']
#
#  conv3_block1_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_1_conv[0][0]']
#  ization)
#
#  conv3_block1_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_1_bn[0][0]']
#  n)
#
#  conv3_block1_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block1_1_relu[0][0]']
#
#  conv3_block1_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block1_2_conv[0][0]']
#  ization)
#
#  conv3_block1_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block1_2_bn[0][0]']
#  n)
#
#  conv3_block1_0_conv (Conv2D)   (None, 28, 28, 512)  131584      ['conv2_block3_out[0][0]']
#
#  conv3_block1_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block1_2_relu[0][0]']
#
#  conv3_block1_0_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block1_0_conv[0][0]']
#  ization)
#
#  conv3_block1_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block1_3_conv[0][0]']
#  ization)
#
#  conv3_block1_add (Add)         (None, 28, 28, 512)  0           ['conv3_block1_0_bn[0][0]',
#                                                                   'conv3_block1_3_bn[0][0]']
#
#  conv3_block1_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block1_add[0][0]']
#
#  conv3_block2_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block1_out[0][0]']
#
#  conv3_block2_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_1_conv[0][0]']
#  ization)
#
#  conv3_block2_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_1_bn[0][0]']
#  n)
#
#  conv3_block2_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block2_1_relu[0][0]']
#
#  conv3_block2_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block2_2_conv[0][0]']
#  ization)
#
#  conv3_block2_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block2_2_bn[0][0]']
#  n)
#
#  conv3_block2_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block2_2_relu[0][0]']
#
#  conv3_block2_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block2_3_conv[0][0]']
#  ization)
#
#  conv3_block2_add (Add)         (None, 28, 28, 512)  0           ['conv3_block1_out[0][0]',
#                                                                   'conv3_block2_3_bn[0][0]']
#
#  conv3_block2_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block2_add[0][0]']
#
#  conv3_block3_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block2_out[0][0]']
#
#  conv3_block3_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_1_conv[0][0]']
#  ization)
#
#  conv3_block3_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_1_bn[0][0]']
#  n)
#
#  conv3_block3_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block3_1_relu[0][0]']
#
#  conv3_block3_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block3_2_conv[0][0]']
#  ization)
#
#  conv3_block3_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block3_2_bn[0][0]']
#  n)
#
#  conv3_block3_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block3_2_relu[0][0]']
#
#  conv3_block3_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block3_3_conv[0][0]']
#  ization)
#
#  conv3_block3_add (Add)         (None, 28, 28, 512)  0           ['conv3_block2_out[0][0]',
#                                                                   'conv3_block3_3_bn[0][0]']
#
#  conv3_block3_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block3_add[0][0]']
#
#  conv3_block4_1_conv (Conv2D)   (None, 28, 28, 128)  65664       ['conv3_block3_out[0][0]']
#
#  conv3_block4_1_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_1_conv[0][0]']
#  ization)
#
#  conv3_block4_1_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_1_bn[0][0]']
#  n)
#
#  conv3_block4_2_conv (Conv2D)   (None, 28, 28, 128)  147584      ['conv3_block4_1_relu[0][0]']
#
#  conv3_block4_2_bn (BatchNormal  (None, 28, 28, 128)  512        ['conv3_block4_2_conv[0][0]']
#  ization)
#
#  conv3_block4_2_relu (Activatio  (None, 28, 28, 128)  0          ['conv3_block4_2_bn[0][0]']
#  n)
#
#  conv3_block4_3_conv (Conv2D)   (None, 28, 28, 512)  66048       ['conv3_block4_2_relu[0][0]']
#
#  conv3_block4_3_bn (BatchNormal  (None, 28, 28, 512)  2048       ['conv3_block4_3_conv[0][0]']
#  ization)
#
#  conv3_block4_add (Add)         (None, 28, 28, 512)  0           ['conv3_block3_out[0][0]',
#                                                                   'conv3_block4_3_bn[0][0]']
#
#  conv3_block4_out (Activation)  (None, 28, 28, 512)  0           ['conv3_block4_add[0][0]']
#
#  conv4_block1_1_conv (Conv2D)   (None, 14, 14, 256)  131328      ['conv3_block4_out[0][0]']
#
#  conv4_block1_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_1_conv[0][0]']
#  ization)
#
#  conv4_block1_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_1_bn[0][0]']
#  n)
#
#  conv4_block1_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block1_1_relu[0][0]']
#
#  conv4_block1_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block1_2_conv[0][0]']
#  ization)
#
#  conv4_block1_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block1_2_bn[0][0]']
#  n)
#
#  conv4_block1_0_conv (Conv2D)   (None, 14, 14, 1024  525312      ['conv3_block4_out[0][0]']
#                                 )
#
#  conv4_block1_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block1_2_relu[0][0]']
#                                 )
#
#  conv4_block1_0_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block1_0_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block1_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block1_add (Add)         (None, 14, 14, 1024  0           ['conv4_block1_0_bn[0][0]',
#                                 )                                 'conv4_block1_3_bn[0][0]']
#
#  conv4_block1_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block1_add[0][0]']
#                                 )
#
#  conv4_block2_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block1_out[0][0]']
#
#  conv4_block2_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_1_conv[0][0]']
#  ization)
#
#  conv4_block2_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_1_bn[0][0]']
#  n)
#
#  conv4_block2_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block2_1_relu[0][0]']
#
#  conv4_block2_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block2_2_conv[0][0]']
#  ization)
#
#  conv4_block2_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block2_2_bn[0][0]']
#  n)
#
#  conv4_block2_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block2_2_relu[0][0]']
#                                 )
#
#  conv4_block2_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block2_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block2_add (Add)         (None, 14, 14, 1024  0           ['conv4_block1_out[0][0]',
#                                 )                                 'conv4_block2_3_bn[0][0]']
#
#  conv4_block2_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block2_add[0][0]']
#                                 )
#
#  conv4_block3_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block2_out[0][0]']
#
#  conv4_block3_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_1_conv[0][0]']
#  ization)
#
#  conv4_block3_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_1_bn[0][0]']
#  n)
#
#  conv4_block3_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block3_1_relu[0][0]']
#
#  conv4_block3_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block3_2_conv[0][0]']
#  ization)
#
#  conv4_block3_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block3_2_bn[0][0]']
#  n)
#
#  conv4_block3_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block3_2_relu[0][0]']
#                                 )
#
#  conv4_block3_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block3_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block3_add (Add)         (None, 14, 14, 1024  0           ['conv4_block2_out[0][0]',
#                                 )                                 'conv4_block3_3_bn[0][0]']
#
#  conv4_block3_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block3_add[0][0]']
#                                 )
#
#  conv4_block4_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block3_out[0][0]']
#
#  conv4_block4_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_1_conv[0][0]']
#  ization)
#
#  conv4_block4_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_1_bn[0][0]']
#  n)
#
#  conv4_block4_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block4_1_relu[0][0]']
#
#  conv4_block4_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block4_2_conv[0][0]']
#  ization)
#
#  conv4_block4_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block4_2_bn[0][0]']
#  n)
#
#  conv4_block4_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block4_2_relu[0][0]']
#                                 )
#
#  conv4_block4_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block4_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block4_add (Add)         (None, 14, 14, 1024  0           ['conv4_block3_out[0][0]',
#                                 )                                 'conv4_block4_3_bn[0][0]']
#
#  conv4_block4_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block4_add[0][0]']
#                                 )
#
#  conv4_block5_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block4_out[0][0]']
#
#  conv4_block5_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_1_conv[0][0]']
#  ization)
#
#  conv4_block5_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_1_bn[0][0]']
#  n)
#
#  conv4_block5_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block5_1_relu[0][0]']
#
#  conv4_block5_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block5_2_conv[0][0]']
#  ization)
#
#  conv4_block5_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block5_2_bn[0][0]']
#  n)
#
#  conv4_block5_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block5_2_relu[0][0]']
#                                 )
#
#  conv4_block5_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block5_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block5_add (Add)         (None, 14, 14, 1024  0           ['conv4_block4_out[0][0]',
#                                 )                                 'conv4_block5_3_bn[0][0]']
#
#  conv4_block5_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block5_add[0][0]']
#                                 )
#
#  conv4_block6_1_conv (Conv2D)   (None, 14, 14, 256)  262400      ['conv4_block5_out[0][0]']
#
#  conv4_block6_1_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_1_conv[0][0]']
#  ization)
#
#  conv4_block6_1_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_1_bn[0][0]']
#  n)
#
#  conv4_block6_2_conv (Conv2D)   (None, 14, 14, 256)  590080      ['conv4_block6_1_relu[0][0]']
#
#  conv4_block6_2_bn (BatchNormal  (None, 14, 14, 256)  1024       ['conv4_block6_2_conv[0][0]']
#  ization)
#
#  conv4_block6_2_relu (Activatio  (None, 14, 14, 256)  0          ['conv4_block6_2_bn[0][0]']
#  n)
#
#  conv4_block6_3_conv (Conv2D)   (None, 14, 14, 1024  263168      ['conv4_block6_2_relu[0][0]']
#                                 )
#
#  conv4_block6_3_bn (BatchNormal  (None, 14, 14, 1024  4096       ['conv4_block6_3_conv[0][0]']
#  ization)                       )
#
#  conv4_block6_add (Add)         (None, 14, 14, 1024  0           ['conv4_block5_out[0][0]',
#                                 )                                 'conv4_block6_3_bn[0][0]']
#
#  conv4_block6_out (Activation)  (None, 14, 14, 1024  0           ['conv4_block6_add[0][0]']
#                                 )
#
#  conv5_block1_1_conv (Conv2D)   (None, 7, 7, 512)    524800      ['conv4_block6_out[0][0]']
#
#  conv5_block1_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_1_conv[0][0]']
#  ization)
#
#  conv5_block1_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_1_bn[0][0]']
#  n)
#
#  conv5_block1_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block1_1_relu[0][0]']
#
#  conv5_block1_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block1_2_conv[0][0]']
#  ization)
#
#  conv5_block1_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block1_2_bn[0][0]']
#  n)
#
#  conv5_block1_0_conv (Conv2D)   (None, 7, 7, 2048)   2099200     ['conv4_block6_out[0][0]']
#
#  conv5_block1_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block1_2_relu[0][0]']
#
#  conv5_block1_0_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block1_0_conv[0][0]']
#  ization)
#
#  conv5_block1_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block1_3_conv[0][0]']
#  ization)
#
#  conv5_block1_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_0_bn[0][0]',
#                                                                   'conv5_block1_3_bn[0][0]']
#
#  conv5_block1_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block1_add[0][0]']
#
#  conv5_block2_1_conv (Conv2D)   (None, 7, 7, 512)    1049088     ['conv5_block1_out[0][0]']
#
#  conv5_block2_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_1_conv[0][0]']
#  ization)
#
#  conv5_block2_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_1_bn[0][0]']
#  n)
#
#  conv5_block2_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block2_1_relu[0][0]']
#
#  conv5_block2_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block2_2_conv[0][0]']
#  ization)
#
#  conv5_block2_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block2_2_bn[0][0]']
#  n)
#
#  conv5_block2_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block2_2_relu[0][0]']
#
#  conv5_block2_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block2_3_conv[0][0]']
#  ization)
#
#  conv5_block2_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block1_out[0][0]',
#                                                                   'conv5_block2_3_bn[0][0]']
#
#  conv5_block2_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block2_add[0][0]']
#
#  conv5_block3_1_conv (Conv2D)   (None, 7, 7, 512)    1049088     ['conv5_block2_out[0][0]']
#
#  conv5_block3_1_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_1_conv[0][0]']
#  ization)
#
#  conv5_block3_1_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_1_bn[0][0]']
#  n)
#
#  conv5_block3_2_conv (Conv2D)   (None, 7, 7, 512)    2359808     ['conv5_block3_1_relu[0][0]']
#
#  conv5_block3_2_bn (BatchNormal  (None, 7, 7, 512)   2048        ['conv5_block3_2_conv[0][0]']
#  ization)
#
#  conv5_block3_2_relu (Activatio  (None, 7, 7, 512)   0           ['conv5_block3_2_bn[0][0]']
#  n)
#
#  conv5_block3_3_conv (Conv2D)   (None, 7, 7, 2048)   1050624     ['conv5_block3_2_relu[0][0]']
#
#  conv5_block3_3_bn (BatchNormal  (None, 7, 7, 2048)  8192        ['conv5_block3_3_conv[0][0]']
#  ization)
#
#  conv5_block3_add (Add)         (None, 7, 7, 2048)   0           ['conv5_block2_out[0][0]',
#                                                                   'conv5_block3_3_bn[0][0]']
#
#  conv5_block3_out (Activation)  (None, 7, 7, 2048)   0           ['conv5_block3_add[0][0]']
#
#  flatten (Flatten)              (None, 100352)       0           ['conv5_block3_out[0][0]']
#
#  dropout (Dropout)              (None, 100352)       0           ['flatten[0][0]']
#
#  dense (Dense)                  (None, 2)            200706      ['dropout[0][0]']
#
# ==================================================================================================
# Total params: 23,788,418
# Trainable params: 200,706
# Non-trainable params: 23,587,712
# __________________________________________________________________________________________________

# %%
res = model.fit(train_aug.flow(X_train, y_train, batch_size=batch_size),
                    validation_data=(X_test, y_test),
                    validation_steps=len(X_test) / batch_size,
                    steps_per_epoch=len(X_train) / batch_size,
                    epochs=epochs)
# Out:
# Epoch 1/300
# 80/80 [==============================] - 36s 320ms/step - loss: 1.6992 - accuracy: 0.5252 - val_loss: 1.2528 - val_accuracy: 0.5356
# Epoch 2/300
# 80/80 [==============================] - 25s 307ms/step - loss: 1.2701 - accuracy: 0.5667 - val_loss: 0.5795 - val_accuracy: 0.7276
# Epoch 3/300
# 80/80 [==============================] - 25s 307ms/step - loss: 0.8793 - accuracy: 0.6078 - val_loss: 0.5657 - val_accuracy: 0.7523
# Epoch 4/300
# 80/80 [==============================] - 25s 305ms/step - loss: 1.5384 - accuracy: 0.5753 - val_loss: 0.5717 - val_accuracy: 0.7616
# Epoch 5/300
# 80/80 [==============================] - 25s 307ms/step - loss: 1.1661 - accuracy: 0.5873 - val_loss: 1.0630 - val_accuracy: 0.5650
# Epoch 6/300
# 80/80 [==============================] - 25s 307ms/step - loss: 1.1351 - accuracy: 0.6094 - val_loss: 2.3006 - val_accuracy: 0.5093
# Epoch 7/300
# 80/80 [==============================] - 25s 308ms/step - loss: 1.3248 - accuracy: 0.5737 - val_loss: 0.7135 - val_accuracy: 0.7167
# Epoch 8/300
# 80/80 [==============================] - 25s 308ms/step - loss: 1.0138 - accuracy: 0.6369 - val_loss: 1.0741 - val_accuracy: 0.5573
# Epoch 9/300
# 80/80 [==============================] - 25s 306ms/step - loss: 1.0501 - accuracy: 0.6171 - val_loss: 1.0583 - val_accuracy: 0.6099
# Epoch 10/300
# 80/80 [==============================] - 25s 308ms/step - loss: 1.2020 - accuracy: 0.6063 - val_loss: 0.5967 - val_accuracy: 0.7693
# Epoch 11/300
# 80/80 [==============================] - 25s 307ms/step - loss: 1.0268 - accuracy: 0.6462 - val_loss: 0.7763 - val_accuracy: 0.6765
# Epoch 12/300
# 80/80 [==============================] - 25s 309ms/step - loss: 1.2038 - accuracy: 0.6137 - val_loss: 0.7869 - val_accuracy: 0.7198
# Epoch 13/300
# 80/80 [==============================] - 25s 306ms/step - loss: 1.2618 - accuracy: 0.6164 - val_loss: 0.6196 - val_accuracy: 0.7647
# Epoch 14/300
# 80/80 [==============================] - 25s 309ms/step - loss: 1.1376 - accuracy: 0.6280 - val_loss: 0.8781 - val_accuracy: 0.6610
# Epoch 15/300
# 80/80 [==============================] - 25s 305ms/step - loss: 1.1744 - accuracy: 0.6234 - val_loss: 0.6137 - val_accuracy: 0.7678
# Epoch 16/300
# 80/80 [==============================] - 25s 307ms/step - loss: 1.0881 - accuracy: 0.6393 - val_loss: 0.6460 - val_accuracy: 0.7461
# Epoch 17/300
# 80/80 [==============================] - 25s 310ms/step - loss: 1.1521 - accuracy: 0.6381 - val_loss: 0.9948 - val_accuracy: 0.6796
# Epoch 18/300
# 80/80 [==============================] - 25s 308ms/step - loss: 1.2979 - accuracy: 0.6237 - val_loss: 2.5335 - val_accuracy: 0.5139
# Epoch 19/300
# 80/80 [==============================] - 25s 310ms/step - loss: 1.3030 - accuracy: 0.6082 - val_loss: 1.6838 - val_accuracy: 0.5464
# Epoch 20/300
# 80/80 [==============================] - 25s 309ms/step - loss: 1.1212 - accuracy: 0.6439 - val_loss: 0.6065 - val_accuracy: 0.7678
# Epoch 21/300
# 80/80 [==============================] - 25s 308ms/step - loss: 1.2217 - accuracy: 0.6171 - val_loss: 3.0059 - val_accuracy: 0.5031
# Epoch 22/300
# 80/80 [==============================] - 25s 309ms/step - loss: 1.3912 - accuracy: 0.6187 - val_loss: 0.6992 - val_accuracy: 0.7508
# Epoch 23/300
# 80/80 [==============================] - 25s 309ms/step - loss: 1.4233 - accuracy: 0.6090 - val_loss: 0.6448 - val_accuracy: 0.7740
# Epoch 24/300
# 80/80 [==============================] - 25s 309ms/step - loss: 1.2633 - accuracy: 0.6439 - val_loss: 1.1334 - val_accuracy: 0.6192
# Epoch 25/300
# 80/80 [==============================] - 25s 309ms/step - loss: 1.2587 - accuracy: 0.6439 - val_loss: 2.3057 - val_accuracy: 0.5186
# Epoch 26/300
# 80/80 [==============================] - 25s 307ms/step - loss: 1.1724 - accuracy: 0.6408 - val_loss: 0.8338 - val_accuracy: 0.7043
# Epoch 27/300
# 80/80 [==============================] - 25s 311ms/step - loss: 1.3353 - accuracy: 0.6261 - val_loss: 0.5973 - val_accuracy: 0.7864
# Epoch 28/300
# 80/80 [==============================] - 25s 308ms/step - loss: 1.2119 - accuracy: 0.6253 - val_loss: 0.9305 - val_accuracy: 0.6610
# Epoch 29/300
# 80/80 [==============================] - 25s 309ms/step - loss: 1.1373 - accuracy: 0.6400 - val_loss: 0.5969 - val_accuracy: 0.7817
# Epoch 30/300
# 80/80 [==============================] - 25s 306ms/step - loss: 1.2485 - accuracy: 0.6342 - val_loss: 0.6484 - val_accuracy: 0.7663
# Epoch 31/300
# 80/80 [==============================] - 25s 310ms/step - loss: 1.1327 - accuracy: 0.6555 - val_loss: 0.6243 - val_accuracy: 0.7755
# Epoch 32/300
# 80/80 [==============================] - 25s 311ms/step - loss: 1.2353 - accuracy: 0.6354 - val_loss: 1.2016 - val_accuracy: 0.6006
# Epoch 33/300
# 80/80 [==============================] - 25s 311ms/step - loss: 1.1318 - accuracy: 0.6571 - val_loss: 0.5858 - val_accuracy: 0.7724
# Epoch 34/300
# 80/80 [==============================] - 25s 309ms/step - loss: 1.0574 - accuracy: 0.6625 - val_loss: 0.5901 - val_accuracy: 0.7926
# Epoch 35/300
# 80/80 [==============================] - 25s 307ms/step - loss: 1.1183 - accuracy: 0.6435 - val_loss: 0.6169 - val_accuracy: 0.7755
# Epoch 36/300
# 80/80 [==============================] - 25s 309ms/step - loss: 1.1566 - accuracy: 0.6493 - val_loss: 0.5913 - val_accuracy: 0.7833
# Epoch 37/300
# 80/80 [==============================] - 25s 312ms/step - loss: 1.1100 - accuracy: 0.6587 - val_loss: 1.5342 - val_accuracy: 0.5635
# Epoch 38/300
# 80/80 [==============================] - 25s 309ms/step - loss: 1.1801 - accuracy: 0.6373 - val_loss: 0.8360 - val_accuracy: 0.6873
# Epoch 39/300
# 80/80 [==============================] - 25s 310ms/step - loss: 1.1676 - accuracy: 0.6505 - val_loss: 0.6462 - val_accuracy: 0.7724
# Epoch 40/300
# 80/80 [==============================] - 25s 307ms/step - loss: 1.1307 - accuracy: 0.6559 - val_loss: 0.5390 - val_accuracy: 0.7988
# Epoch 41/300
# 80/80 [==============================] - 25s 310ms/step - loss: 1.0713 - accuracy: 0.6652 - val_loss: 2.5081 - val_accuracy: 0.5170
# Epoch 42/300
# 80/80 [==============================] - 25s 310ms/step - loss: 1.0649 - accuracy: 0.6455 - val_loss: 0.5980 - val_accuracy: 0.7740
# Epoch 43/300
# 80/80 [==============================] - 25s 311ms/step - loss: 1.0567 - accuracy: 0.6645 - val_loss: 0.5603 - val_accuracy: 0.7910
# Epoch 44/300
# 80/80 [==============================] - 25s 309ms/step - loss: 1.3411 - accuracy: 0.6338 - val_loss: 0.7820 - val_accuracy: 0.7245
# Epoch 45/300
# 80/80 [==============================] - 25s 310ms/step - loss: 1.2561 - accuracy: 0.6458 - val_loss: 2.0002 - val_accuracy: 0.5372
# Epoch 46/300
# 80/80 [==============================] - 25s 309ms/step - loss: 1.1982 - accuracy: 0.6424 - val_loss: 1.1266 - val_accuracy: 0.6393
# Epoch 47/300
# 80/80 [==============================] - 25s 308ms/step - loss: 1.2617 - accuracy: 0.6478 - val_loss: 1.3437 - val_accuracy: 0.5944
# Epoch 48/300
# 80/80 [==============================] - 25s 310ms/step - loss: 1.3538 - accuracy: 0.6346 - val_loss: 0.5888 - val_accuracy: 0.7895
# Epoch 49/300
# 80/80 [==============================] - 25s 312ms/step - loss: 1.2596 - accuracy: 0.6482 - val_loss: 0.7778 - val_accuracy: 0.7399
# Epoch 50/300
# 80/80 [==============================] - 25s 313ms/step - loss: 1.1510 - accuracy: 0.6633 - val_loss: 0.6955 - val_accuracy: 0.7601
# Epoch 51/300
# 80/80 [==============================] - 25s 312ms/step - loss: 1.2751 - accuracy: 0.6447 - val_loss: 0.8408 - val_accuracy: 0.7322
# Epoch 52/300
# 80/80 [==============================] - 25s 315ms/step - loss: 1.1885 - accuracy: 0.6555 - val_loss: 0.7856 - val_accuracy: 0.7368
# Epoch 53/300
# 80/80 [==============================] - 25s 312ms/step - loss: 1.2366 - accuracy: 0.6493 - val_loss: 0.5883 - val_accuracy: 0.7879
# Epoch 54/300
# 80/80 [==============================] - 25s 310ms/step - loss: 1.0941 - accuracy: 0.6621 - val_loss: 0.6158 - val_accuracy: 0.7879
# Epoch 55/300
# 80/80 [==============================] - 25s 315ms/step - loss: 1.3470 - accuracy: 0.6327 - val_loss: 0.9581 - val_accuracy: 0.6966
# Epoch 56/300
# 80/80 [==============================] - 25s 312ms/step - loss: 1.4015 - accuracy: 0.6528 - val_loss: 0.8939 - val_accuracy: 0.7276
# Epoch 57/300
# 80/80 [==============================] - 25s 311ms/step - loss: 1.2237 - accuracy: 0.6579 - val_loss: 0.6186 - val_accuracy: 0.7740
# Epoch 58/300
# 80/80 [==============================] - 25s 310ms/step - loss: 1.1627 - accuracy: 0.6625 - val_loss: 2.4893 - val_accuracy: 0.5464
# Epoch 59/300
# 80/80 [==============================] - 25s 309ms/step - loss: 1.2981 - accuracy: 0.6447 - val_loss: 0.5772 - val_accuracy: 0.7895
# Epoch 60/300
# 80/80 [==============================] - 25s 313ms/step - loss: 1.1395 - accuracy: 0.6540 - val_loss: 0.6526 - val_accuracy: 0.7864
# Epoch 61/300
# 80/80 [==============================] - 25s 309ms/step - loss: 1.2074 - accuracy: 0.6451 - val_loss: 0.9435 - val_accuracy: 0.7121
# Epoch 62/300
# 80/80 [==============================] - 25s 311ms/step - loss: 1.1218 - accuracy: 0.6649 - val_loss: 0.6172 - val_accuracy: 0.7833
# Epoch 63/300
# 80/80 [==============================] - 25s 308ms/step - loss: 1.0226 - accuracy: 0.6738 - val_loss: 1.0866 - val_accuracy: 0.6718
# Epoch 64/300
# 80/80 [==============================] - 25s 308ms/step - loss: 1.2818 - accuracy: 0.6346 - val_loss: 0.6376 - val_accuracy: 0.7802
# Epoch 65/300
# 80/80 [==============================] - 25s 311ms/step - loss: 1.0466 - accuracy: 0.6664 - val_loss: 0.6516 - val_accuracy: 0.7817
# Epoch 66/300
# 80/80 [==============================] - 25s 307ms/step - loss: 1.0526 - accuracy: 0.6718 - val_loss: 0.5765 - val_accuracy: 0.7864
# Epoch 67/300
# 80/80 [==============================] - 25s 307ms/step - loss: 0.9628 - accuracy: 0.6885 - val_loss: 0.6953 - val_accuracy: 0.7709
# Epoch 68/300
# 80/80 [==============================] - 25s 313ms/step - loss: 1.0952 - accuracy: 0.6699 - val_loss: 0.9752 - val_accuracy: 0.6687
# Epoch 69/300
# 80/80 [==============================] - 25s 310ms/step - loss: 1.2103 - accuracy: 0.6555 - val_loss: 0.6863 - val_accuracy: 0.7802
# Epoch 70/300
# 80/80 [==============================] - 25s 310ms/step - loss: 1.1414 - accuracy: 0.6594 - val_loss: 0.6471 - val_accuracy: 0.7740
# Epoch 71/300
# 80/80 [==============================] - 25s 305ms/step - loss: 1.2247 - accuracy: 0.6579 - val_loss: 0.6569 - val_accuracy: 0.7755
# Epoch 72/300
# 80/80 [==============================] - 25s 314ms/step - loss: 1.1936 - accuracy: 0.6765 - val_loss: 0.6630 - val_accuracy: 0.7678
# Epoch 73/300
# 80/80 [==============================] - 25s 309ms/step - loss: 1.3448 - accuracy: 0.6536 - val_loss: 0.6903 - val_accuracy: 0.7817
# Epoch 74/300
# 80/80 [==============================] - 25s 311ms/step - loss: 1.0935 - accuracy: 0.6722 - val_loss: 1.1397 - val_accuracy: 0.6579
# Epoch 75/300
# 80/80 [==============================] - 25s 311ms/step - loss: 1.1884 - accuracy: 0.6552 - val_loss: 0.5847 - val_accuracy: 0.7988
# Epoch 76/300
# 80/80 [==============================] - 25s 308ms/step - loss: 1.2162 - accuracy: 0.6540 - val_loss: 1.0684 - val_accuracy: 0.6734
# Epoch 77/300
# 80/80 [==============================] - 25s 311ms/step - loss: 1.1774 - accuracy: 0.6563 - val_loss: 0.8787 - val_accuracy: 0.7198
# Epoch 78/300
# 80/80 [==============================] - 25s 310ms/step - loss: 1.0808 - accuracy: 0.6629 - val_loss: 1.0363 - val_accuracy: 0.6594
# Epoch 79/300
# 80/80 [==============================] - 25s 310ms/step - loss: 1.5555 - accuracy: 0.6140 - val_loss: 0.9155 - val_accuracy: 0.7167
# Epoch 80/300
# 80/80 [==============================] - 25s 309ms/step - loss: 1.1197 - accuracy: 0.6614 - val_loss: 0.7351 - val_accuracy: 0.7430
# Epoch 81/300
# 80/80 [==============================] - 25s 310ms/step - loss: 1.3044 - accuracy: 0.6458 - val_loss: 0.7701 - val_accuracy: 0.7399
# Epoch 82/300
# 80/80 [==============================] - 25s 309ms/step - loss: 1.2905 - accuracy: 0.6548 - val_loss: 0.6052 - val_accuracy: 0.7972
# Epoch 83/300
# 80/80 [==============================] - 25s 310ms/step - loss: 1.2023 - accuracy: 0.6587 - val_loss: 0.6245 - val_accuracy: 0.7926
# Epoch 84/300
# 80/80 [==============================] - 25s 310ms/step - loss: 1.1388 - accuracy: 0.6734 - val_loss: 0.5549 - val_accuracy: 0.8173
# Epoch 85/300
# 80/80 [==============================] - 25s 310ms/step - loss: 1.1577 - accuracy: 0.6649 - val_loss: 1.0949 - val_accuracy: 0.6749
# Epoch 86/300
# 80/80 [==============================] - 25s 309ms/step - loss: 1.1742 - accuracy: 0.6493 - val_loss: 1.3363 - val_accuracy: 0.6300
# Epoch 87/300
# 80/80 [==============================] - 25s 314ms/step - loss: 1.1370 - accuracy: 0.6746 - val_loss: 0.8852 - val_accuracy: 0.7167
# Epoch 88/300
# 80/80 [==============================] - 25s 308ms/step - loss: 1.3513 - accuracy: 0.6490 - val_loss: 0.8701 - val_accuracy: 0.7368
# Epoch 89/300
# 80/80 [==============================] - 25s 309ms/step - loss: 1.1306 - accuracy: 0.6691 - val_loss: 0.9544 - val_accuracy: 0.7012
# Epoch 90/300
# 80/80 [==============================] - 25s 310ms/step - loss: 1.2952 - accuracy: 0.6443 - val_loss: 0.5924 - val_accuracy: 0.8019
# Epoch 91/300
# 80/80 [==============================] - 25s 313ms/step - loss: 1.2253 - accuracy: 0.6610 - val_loss: 0.8415 - val_accuracy: 0.7337
# Epoch 92/300
# 80/80 [==============================] - 25s 308ms/step - loss: 1.1838 - accuracy: 0.6618 - val_loss: 0.6246 - val_accuracy: 0.7910
# Epoch 93/300
# 80/80 [==============================] - 25s 315ms/step - loss: 1.5042 - accuracy: 0.6524 - val_loss: 0.6836 - val_accuracy: 0.7848
# Epoch 94/300
# 80/80 [==============================] - 25s 312ms/step - loss: 1.2939 - accuracy: 0.6544 - val_loss: 1.5180 - val_accuracy: 0.5820
# Epoch 95/300
# 80/80 [==============================] - 25s 310ms/step - loss: 1.3423 - accuracy: 0.6555 - val_loss: 0.8106 - val_accuracy: 0.7632
# Epoch 96/300
# 80/80 [==============================] - 25s 313ms/step - loss: 1.1636 - accuracy: 0.6707 - val_loss: 1.2269 - val_accuracy: 0.6563
# Epoch 97/300
# 80/80 [==============================] - 25s 308ms/step - loss: 1.3472 - accuracy: 0.6548 - val_loss: 0.6008 - val_accuracy: 0.7817
# Epoch 98/300
# 80/80 [==============================] - 25s 308ms/step - loss: 1.3405 - accuracy: 0.6552 - val_loss: 0.6837 - val_accuracy: 0.7755
# Epoch 99/300
# 80/80 [==============================] - 25s 309ms/step - loss: 1.1878 - accuracy: 0.6524 - val_loss: 0.6102 - val_accuracy: 0.7957
# Epoch 100/300
# 80/80 [==============================] - 25s 309ms/step - loss: 1.3770 - accuracy: 0.6497 - val_loss: 1.2573 - val_accuracy: 0.6687
# Epoch 101/300
# 80/80 [==============================] - 25s 313ms/step - loss: 1.1693 - accuracy: 0.6753 - val_loss: 0.6585 - val_accuracy: 0.8065
# Epoch 102/300
# 80/80 [==============================] - 25s 308ms/step - loss: 1.3210 - accuracy: 0.6462 - val_loss: 1.9799 - val_accuracy: 0.5557
# Epoch 103/300
# 80/80 [==============================] - 25s 313ms/step - loss: 1.2391 - accuracy: 0.6559 - val_loss: 0.6672 - val_accuracy: 0.7693
# Epoch 104/300
# 80/80 [==============================] - 25s 312ms/step - loss: 1.1320 - accuracy: 0.6645 - val_loss: 0.5769 - val_accuracy: 0.7848
# Epoch 105/300
# 80/80 [==============================] - 25s 309ms/step - loss: 1.1939 - accuracy: 0.6680 - val_loss: 1.4352 - val_accuracy: 0.6192
# Epoch 106/300
# 80/80 [==============================] - 25s 309ms/step - loss: 1.2326 - accuracy: 0.6722 - val_loss: 1.0971 - val_accuracy: 0.6641
# Epoch 107/300
# 80/80 [==============================] - 25s 310ms/step - loss: 1.1889 - accuracy: 0.6571 - val_loss: 0.6312 - val_accuracy: 0.7941
# Epoch 108/300
# 80/80 [==============================] - 25s 309ms/step - loss: 1.3074 - accuracy: 0.6466 - val_loss: 0.7658 - val_accuracy: 0.7523
# Epoch 109/300
# 80/80 [==============================] - 25s 311ms/step - loss: 1.4063 - accuracy: 0.6319 - val_loss: 0.6724 - val_accuracy: 0.7802
# Epoch 110/300
# 80/80 [==============================] - 25s 313ms/step - loss: 1.3522 - accuracy: 0.6400 - val_loss: 0.6801 - val_accuracy: 0.7740
# Epoch 111/300
# 80/80 [==============================] - 25s 312ms/step - loss: 1.1315 - accuracy: 0.6695 - val_loss: 0.6001 - val_accuracy: 0.7957
# Epoch 112/300
# 80/80 [==============================] - 25s 311ms/step - loss: 1.2523 - accuracy: 0.6563 - val_loss: 0.6006 - val_accuracy: 0.7910
# Epoch 113/300
# 80/80 [==============================] - 25s 311ms/step - loss: 1.1437 - accuracy: 0.6746 - val_loss: 0.5655 - val_accuracy: 0.7957
# Epoch 114/300
# 80/80 [==============================] - 25s 307ms/step - loss: 1.1617 - accuracy: 0.6734 - val_loss: 0.6224 - val_accuracy: 0.7755
# Epoch 115/300
# 80/80 [==============================] - 25s 310ms/step - loss: 1.1317 - accuracy: 0.6649 - val_loss: 0.9212 - val_accuracy: 0.7028
# Epoch 116/300
# 80/80 [==============================] - 25s 313ms/step - loss: 1.2925 - accuracy: 0.6528 - val_loss: 0.9433 - val_accuracy: 0.6997
# Epoch 117/300
# 80/80 [==============================] - 25s 309ms/step - loss: 1.1994 - accuracy: 0.6606 - val_loss: 1.3347 - val_accuracy: 0.6316
# Epoch 118/300
# 80/80 [==============================] - 25s 309ms/step - loss: 1.2266 - accuracy: 0.6606 - val_loss: 0.5739 - val_accuracy: 0.8080
# Epoch 119/300
# 80/80 [==============================] - 25s 310ms/step - loss: 1.1696 - accuracy: 0.6711 - val_loss: 0.6019 - val_accuracy: 0.8019
# Epoch 120/300
# 80/80 [==============================] - 25s 311ms/step - loss: 1.2842 - accuracy: 0.6652 - val_loss: 0.5863 - val_accuracy: 0.8003
# Epoch 121/300
# 80/80 [==============================] - 25s 313ms/step - loss: 1.4871 - accuracy: 0.6346 - val_loss: 0.6119 - val_accuracy: 0.7910
# Epoch 122/300
# 80/80 [==============================] - 25s 311ms/step - loss: 1.1497 - accuracy: 0.6839 - val_loss: 1.1349 - val_accuracy: 0.6827
# Epoch 123/300
# 80/80 [==============================] - 25s 311ms/step - loss: 1.2668 - accuracy: 0.6618 - val_loss: 1.2512 - val_accuracy: 0.6749
# Epoch 124/300
# 80/80 [==============================] - 25s 311ms/step - loss: 1.2942 - accuracy: 0.6742 - val_loss: 0.7695 - val_accuracy: 0.7709
# Epoch 125/300
# 80/80 [==============================] - 25s 309ms/step - loss: 1.3352 - accuracy: 0.6606 - val_loss: 0.8010 - val_accuracy: 0.7601
# Epoch 126/300
# 80/80 [==============================] - 25s 311ms/step - loss: 1.3795 - accuracy: 0.6606 - val_loss: 1.1750 - val_accuracy: 0.6471
# Epoch 127/300
# 80/80 [==============================] - 25s 312ms/step - loss: 1.3506 - accuracy: 0.6548 - val_loss: 2.7930 - val_accuracy: 0.5387
# Epoch 128/300
# 80/80 [==============================] - 25s 308ms/step - loss: 1.4407 - accuracy: 0.6587 - val_loss: 0.6887 - val_accuracy: 0.7879
# Epoch 129/300
# 80/80 [==============================] - 25s 313ms/step - loss: 1.1726 - accuracy: 0.6695 - val_loss: 0.7143 - val_accuracy: 0.7663
# Epoch 130/300
# 80/80 [==============================] - 25s 308ms/step - loss: 1.0785 - accuracy: 0.6753 - val_loss: 0.8468 - val_accuracy: 0.7214
# Epoch 131/300
# 80/80 [==============================] - 25s 311ms/step - loss: 1.4486 - accuracy: 0.6443 - val_loss: 2.1683 - val_accuracy: 0.5526
# Epoch 132/300
# 80/80 [==============================] - 25s 312ms/step - loss: 1.5059 - accuracy: 0.6412 - val_loss: 0.7741 - val_accuracy: 0.7833
# Epoch 133/300
# 80/80 [==============================] - 25s 312ms/step - loss: 1.3213 - accuracy: 0.6559 - val_loss: 0.6893 - val_accuracy: 0.7678
# Epoch 134/300
# 80/80 [==============================] - 25s 309ms/step - loss: 1.3170 - accuracy: 0.6676 - val_loss: 0.6657 - val_accuracy: 0.8019
# Epoch 135/300
# 80/80 [==============================] - 25s 314ms/step - loss: 1.1482 - accuracy: 0.6691 - val_loss: 0.8650 - val_accuracy: 0.7167
# Epoch 136/300
# 80/80 [==============================] - 25s 310ms/step - loss: 1.5410 - accuracy: 0.6315 - val_loss: 0.6769 - val_accuracy: 0.7724
# Epoch 137/300
# 80/80 [==============================] - 25s 309ms/step - loss: 1.0367 - accuracy: 0.6986 - val_loss: 0.6776 - val_accuracy: 0.7616
# Epoch 138/300
# 80/80 [==============================] - 25s 311ms/step - loss: 1.2949 - accuracy: 0.6544 - val_loss: 0.7398 - val_accuracy: 0.7678
# Epoch 139/300
# 80/80 [==============================] - 25s 309ms/step - loss: 1.3626 - accuracy: 0.6532 - val_loss: 0.7259 - val_accuracy: 0.7771
# Epoch 140/300
# 80/80 [==============================] - 25s 309ms/step - loss: 1.0493 - accuracy: 0.6846 - val_loss: 1.1808 - val_accuracy: 0.6533
# Epoch 141/300
# 80/80 [==============================] - 25s 316ms/step - loss: 1.2654 - accuracy: 0.6687 - val_loss: 0.7249 - val_accuracy: 0.7740
# Epoch 142/300
# 80/80 [==============================] - 25s 311ms/step - loss: 1.2672 - accuracy: 0.6590 - val_loss: 1.0629 - val_accuracy: 0.6796
# Epoch 143/300
# 80/80 [==============================] - 25s 312ms/step - loss: 1.4053 - accuracy: 0.6590 - val_loss: 0.6452 - val_accuracy: 0.7972
# Epoch 144/300
# 80/80 [==============================] - 25s 312ms/step - loss: 1.2794 - accuracy: 0.6633 - val_loss: 0.6188 - val_accuracy: 0.8050
# Epoch 145/300
# 80/80 [==============================] - 25s 313ms/step - loss: 1.2346 - accuracy: 0.6761 - val_loss: 0.6432 - val_accuracy: 0.7833
# Epoch 146/300
# 80/80 [==============================] - 25s 312ms/step - loss: 1.1484 - accuracy: 0.6738 - val_loss: 0.8380 - val_accuracy: 0.7353
# Epoch 147/300
# 80/80 [==============================] - 25s 312ms/step - loss: 1.1855 - accuracy: 0.6796 - val_loss: 0.6684 - val_accuracy: 0.7879
# Epoch 148/300
# 80/80 [==============================] - 25s 310ms/step - loss: 1.1174 - accuracy: 0.6625 - val_loss: 0.6005 - val_accuracy: 0.7802
# Epoch 149/300
# 80/80 [==============================] - 25s 308ms/step - loss: 1.0445 - accuracy: 0.6843 - val_loss: 1.1802 - val_accuracy: 0.6533
# Epoch 150/300
# 80/80 [==============================] - 25s 307ms/step - loss: 1.0877 - accuracy: 0.6742 - val_loss: 1.1614 - val_accuracy: 0.6749
# Epoch 151/300
# 80/80 [==============================] - 25s 312ms/step - loss: 1.2864 - accuracy: 0.6424 - val_loss: 1.5720 - val_accuracy: 0.6099
# Epoch 152/300
# 80/80 [==============================] - 25s 311ms/step - loss: 1.3705 - accuracy: 0.6501 - val_loss: 0.6859 - val_accuracy: 0.7833
# Epoch 153/300
# 80/80 [==============================] - 25s 310ms/step - loss: 1.0674 - accuracy: 0.6920 - val_loss: 0.8026 - val_accuracy: 0.7678
# Epoch 154/300
# 80/80 [==============================] - 25s 316ms/step - loss: 1.2615 - accuracy: 0.6621 - val_loss: 1.9129 - val_accuracy: 0.5635
# Epoch 155/300
# 80/80 [==============================] - 25s 311ms/step - loss: 1.3476 - accuracy: 0.6614 - val_loss: 0.7418 - val_accuracy: 0.7601
# Epoch 156/300
# 80/80 [==============================] - 25s 309ms/step - loss: 1.1065 - accuracy: 0.6730 - val_loss: 0.6283 - val_accuracy: 0.7910
# Epoch 157/300
# 80/80 [==============================] - 25s 309ms/step - loss: 1.4190 - accuracy: 0.6486 - val_loss: 0.6580 - val_accuracy: 0.7709
# Epoch 158/300
# 80/80 [==============================] - 25s 312ms/step - loss: 1.4560 - accuracy: 0.6478 - val_loss: 0.5905 - val_accuracy: 0.8050
# Epoch 159/300
# 80/80 [==============================] - 25s 310ms/step - loss: 1.1616 - accuracy: 0.6621 - val_loss: 0.5701 - val_accuracy: 0.8065
# Epoch 160/300
# 80/80 [==============================] - 25s 313ms/step - loss: 1.2052 - accuracy: 0.6664 - val_loss: 1.7394 - val_accuracy: 0.6022
# Epoch 161/300
# 80/80 [==============================] - 25s 311ms/step - loss: 1.2252 - accuracy: 0.6668 - val_loss: 0.6056 - val_accuracy: 0.8065
# Epoch 162/300
# 80/80 [==============================] - 25s 309ms/step - loss: 1.2676 - accuracy: 0.6687 - val_loss: 0.6387 - val_accuracy: 0.7972
# Epoch 163/300
# 80/80 [==============================] - 25s 314ms/step - loss: 1.0775 - accuracy: 0.6796 - val_loss: 0.5316 - val_accuracy: 0.8173
# Epoch 164/300
# 80/80 [==============================] - 25s 311ms/step - loss: 1.0870 - accuracy: 0.6792 - val_loss: 0.9115 - val_accuracy: 0.7167
# Epoch 165/300
# 80/80 [==============================] - 25s 311ms/step - loss: 1.1511 - accuracy: 0.6621 - val_loss: 0.6594 - val_accuracy: 0.7755
# Epoch 166/300
# 80/80 [==============================] - 25s 309ms/step - loss: 1.3668 - accuracy: 0.6474 - val_loss: 1.8008 - val_accuracy: 0.5604
# Epoch 167/300
# 80/80 [==============================] - 25s 310ms/step - loss: 1.1706 - accuracy: 0.6819 - val_loss: 0.6008 - val_accuracy: 0.8065
# Epoch 168/300
# 80/80 [==============================] - 25s 311ms/step - loss: 1.2298 - accuracy: 0.6699 - val_loss: 0.6193 - val_accuracy: 0.8158
# Epoch 169/300
# 80/80 [==============================] - 25s 309ms/step - loss: 1.3683 - accuracy: 0.6470 - val_loss: 0.7408 - val_accuracy: 0.7879
# Epoch 170/300
# 80/80 [==============================] - 25s 311ms/step - loss: 1.5487 - accuracy: 0.6447 - val_loss: 2.6750 - val_accuracy: 0.5170
# Epoch 171/300
# 80/80 [==============================] - 25s 311ms/step - loss: 1.4126 - accuracy: 0.6470 - val_loss: 0.7610 - val_accuracy: 0.7477
# Epoch 172/300
# 80/80 [==============================] - 25s 308ms/step - loss: 1.1387 - accuracy: 0.6746 - val_loss: 1.0315 - val_accuracy: 0.6858
# Epoch 173/300
# 80/80 [==============================] - 25s 311ms/step - loss: 1.4135 - accuracy: 0.6594 - val_loss: 0.9233 - val_accuracy: 0.7399
# Epoch 174/300
# 80/80 [==============================] - 25s 313ms/step - loss: 1.3522 - accuracy: 0.6497 - val_loss: 2.5862 - val_accuracy: 0.5248
# Epoch 175/300
# 80/80 [==============================] - 25s 308ms/step - loss: 1.2742 - accuracy: 0.6742 - val_loss: 0.6963 - val_accuracy: 0.7833
# Epoch 176/300
# 80/80 [==============================] - 25s 308ms/step - loss: 1.2259 - accuracy: 0.6571 - val_loss: 0.7792 - val_accuracy: 0.7554
# Epoch 177/300
# 80/80 [==============================] - 25s 310ms/step - loss: 1.0681 - accuracy: 0.6843 - val_loss: 1.6272 - val_accuracy: 0.5836
# Epoch 178/300
# 80/80 [==============================] - 25s 309ms/step - loss: 1.2448 - accuracy: 0.6660 - val_loss: 1.8177 - val_accuracy: 0.5526
# Epoch 179/300
# 80/80 [==============================] - 25s 307ms/step - loss: 2.0109 - accuracy: 0.6144 - val_loss: 0.7325 - val_accuracy: 0.8034
# Epoch 180/300
# 80/80 [==============================] - 25s 314ms/step - loss: 1.2636 - accuracy: 0.6676 - val_loss: 0.6685 - val_accuracy: 0.7941
# Epoch 181/300
# 80/80 [==============================] - 25s 311ms/step - loss: 1.2667 - accuracy: 0.6683 - val_loss: 2.1210 - val_accuracy: 0.5480
# Epoch 182/300
# 80/80 [==============================] - 25s 310ms/step - loss: 1.3949 - accuracy: 0.6455 - val_loss: 0.9204 - val_accuracy: 0.7291
# Epoch 183/300
# 80/80 [==============================] - 25s 311ms/step - loss: 1.1558 - accuracy: 0.6765 - val_loss: 1.2515 - val_accuracy: 0.6471
# Epoch 184/300
# 80/80 [==============================] - 25s 310ms/step - loss: 1.1350 - accuracy: 0.6676 - val_loss: 0.7084 - val_accuracy: 0.7693
# Epoch 185/300
# 80/80 [==============================] - 25s 307ms/step - loss: 1.2901 - accuracy: 0.6641 - val_loss: 1.9633 - val_accuracy: 0.5805
# Epoch 186/300
# 80/80 [==============================] - 25s 306ms/step - loss: 1.1328 - accuracy: 0.6843 - val_loss: 0.6337 - val_accuracy: 0.7926
# Epoch 187/300
# 80/80 [==============================] - 25s 312ms/step - loss: 1.1856 - accuracy: 0.6691 - val_loss: 0.9325 - val_accuracy: 0.7245
# Epoch 188/300
# 80/80 [==============================] - 25s 311ms/step - loss: 1.2567 - accuracy: 0.6606 - val_loss: 0.5976 - val_accuracy: 0.8127
# Epoch 189/300
# 80/80 [==============================] - 25s 312ms/step - loss: 1.1784 - accuracy: 0.6703 - val_loss: 0.6267 - val_accuracy: 0.7972
# Epoch 190/300
# 80/80 [==============================] - 25s 309ms/step - loss: 1.1722 - accuracy: 0.6680 - val_loss: 0.5854 - val_accuracy: 0.8173
# Epoch 191/300
# 80/80 [==============================] - 25s 312ms/step - loss: 1.4038 - accuracy: 0.6567 - val_loss: 0.9781 - val_accuracy: 0.7399
# Epoch 192/300
# 80/80 [==============================] - 25s 310ms/step - loss: 1.1491 - accuracy: 0.6901 - val_loss: 0.7874 - val_accuracy: 0.7539
# Epoch 193/300
# 80/80 [==============================] - 25s 312ms/step - loss: 1.2311 - accuracy: 0.6652 - val_loss: 0.6226 - val_accuracy: 0.8050
# Epoch 194/300
# 80/80 [==============================] - 25s 312ms/step - loss: 1.1136 - accuracy: 0.6870 - val_loss: 0.6597 - val_accuracy: 0.7802
# Epoch 195/300
# 80/80 [==============================] - 25s 307ms/step - loss: 1.2604 - accuracy: 0.6734 - val_loss: 0.7260 - val_accuracy: 0.7740
# Epoch 196/300
# 80/80 [==============================] - 25s 312ms/step - loss: 1.1966 - accuracy: 0.6870 - val_loss: 0.6680 - val_accuracy: 0.7833
# Epoch 197/300
# 80/80 [==============================] - 25s 313ms/step - loss: 1.1618 - accuracy: 0.6718 - val_loss: 0.5701 - val_accuracy: 0.8127
# Epoch 198/300
# 80/80 [==============================] - 25s 307ms/step - loss: 1.4287 - accuracy: 0.6427 - val_loss: 0.6851 - val_accuracy: 0.7693
# Epoch 199/300
# 80/80 [==============================] - 25s 311ms/step - loss: 1.4340 - accuracy: 0.6404 - val_loss: 0.6425 - val_accuracy: 0.8080
# Epoch 200/300
# 80/80 [==============================] - 25s 311ms/step - loss: 1.2062 - accuracy: 0.6687 - val_loss: 0.5722 - val_accuracy: 0.8158
# Epoch 201/300
# 80/80 [==============================] - 25s 310ms/step - loss: 1.3147 - accuracy: 0.6528 - val_loss: 0.8811 - val_accuracy: 0.7446
# Epoch 202/300
# 80/80 [==============================] - 25s 311ms/step - loss: 1.1177 - accuracy: 0.6796 - val_loss: 0.9596 - val_accuracy: 0.7043
# Epoch 203/300
# 80/80 [==============================] - 25s 313ms/step - loss: 1.3540 - accuracy: 0.6524 - val_loss: 1.5589 - val_accuracy: 0.5805
# Epoch 204/300
# 80/80 [==============================] - 25s 313ms/step - loss: 1.1773 - accuracy: 0.6664 - val_loss: 0.6651 - val_accuracy: 0.7740
# Epoch 205/300
# 80/80 [==============================] - 25s 310ms/step - loss: 1.5464 - accuracy: 0.6311 - val_loss: 0.7462 - val_accuracy: 0.7755
# Epoch 206/300
# 80/80 [==============================] - 25s 310ms/step - loss: 1.3142 - accuracy: 0.6652 - val_loss: 1.5756 - val_accuracy: 0.5774
# Epoch 207/300
# 80/80 [==============================] - 25s 313ms/step - loss: 1.1860 - accuracy: 0.6746 - val_loss: 0.8947 - val_accuracy: 0.7214
# Epoch 208/300
# 80/80 [==============================] - 25s 309ms/step - loss: 1.8308 - accuracy: 0.6249 - val_loss: 0.7159 - val_accuracy: 0.7755
# Epoch 209/300
# 80/80 [==============================] - 25s 314ms/step - loss: 1.3888 - accuracy: 0.6555 - val_loss: 0.6894 - val_accuracy: 0.7786
# Epoch 210/300
# 80/80 [==============================] - 25s 311ms/step - loss: 1.1445 - accuracy: 0.6924 - val_loss: 0.5979 - val_accuracy: 0.7895
# Epoch 211/300
# 80/80 [==============================] - 25s 307ms/step - loss: 1.2191 - accuracy: 0.6660 - val_loss: 0.8218 - val_accuracy: 0.7430
# Epoch 212/300
# 80/80 [==============================] - 25s 312ms/step - loss: 1.2654 - accuracy: 0.6594 - val_loss: 1.5057 - val_accuracy: 0.6238
# Epoch 213/300
# 80/80 [==============================] - 25s 312ms/step - loss: 1.1595 - accuracy: 0.6815 - val_loss: 0.5927 - val_accuracy: 0.8003
# Epoch 214/300
# 80/80 [==============================] - 25s 307ms/step - loss: 1.1640 - accuracy: 0.6777 - val_loss: 0.6295 - val_accuracy: 0.7755
# Epoch 215/300
# 80/80 [==============================] - 25s 310ms/step - loss: 1.0910 - accuracy: 0.6877 - val_loss: 0.8116 - val_accuracy: 0.7508
# Epoch 216/300
# 80/80 [==============================] - 25s 309ms/step - loss: 1.2530 - accuracy: 0.6571 - val_loss: 0.9850 - val_accuracy: 0.6950
# Epoch 217/300
# 80/80 [==============================] - 25s 311ms/step - loss: 1.2159 - accuracy: 0.6656 - val_loss: 0.6670 - val_accuracy: 0.7817
# Epoch 218/300
# 80/80 [==============================] - 25s 307ms/step - loss: 1.2207 - accuracy: 0.6722 - val_loss: 0.5727 - val_accuracy: 0.7895
# Epoch 219/300
# 80/80 [==============================] - 25s 315ms/step - loss: 1.1434 - accuracy: 0.6715 - val_loss: 0.5914 - val_accuracy: 0.7663
# Epoch 220/300
# 80/80 [==============================] - 25s 309ms/step - loss: 1.1526 - accuracy: 0.6742 - val_loss: 0.6156 - val_accuracy: 0.7755
# Epoch 221/300
# 80/80 [==============================] - 25s 312ms/step - loss: 1.0909 - accuracy: 0.6916 - val_loss: 0.5698 - val_accuracy: 0.7910
# Epoch 222/300
# 80/80 [==============================] - 25s 308ms/step - loss: 1.2172 - accuracy: 0.6656 - val_loss: 0.5690 - val_accuracy: 0.8111
# Epoch 223/300
# 80/80 [==============================] - 25s 312ms/step - loss: 1.1740 - accuracy: 0.6691 - val_loss: 0.5648 - val_accuracy: 0.7895
# Epoch 224/300
# 80/80 [==============================] - 25s 310ms/step - loss: 1.2410 - accuracy: 0.6664 - val_loss: 0.7008 - val_accuracy: 0.7663
# Epoch 225/300
# 80/80 [==============================] - 25s 311ms/step - loss: 1.2650 - accuracy: 0.6637 - val_loss: 0.5863 - val_accuracy: 0.8080
# Epoch 226/300
# 80/80 [==============================] - 25s 311ms/step - loss: 1.3282 - accuracy: 0.6583 - val_loss: 0.6495 - val_accuracy: 0.7802
# Epoch 227/300
# 80/80 [==============================] - 25s 315ms/step - loss: 1.4296 - accuracy: 0.6490 - val_loss: 0.6905 - val_accuracy: 0.8050
# Epoch 228/300
# 80/80 [==============================] - 25s 314ms/step - loss: 1.4110 - accuracy: 0.6567 - val_loss: 0.5822 - val_accuracy: 0.8220
# Epoch 229/300
# 80/80 [==============================] - 25s 313ms/step - loss: 1.4573 - accuracy: 0.6490 - val_loss: 0.6203 - val_accuracy: 0.7941
# Epoch 230/300
# 80/80 [==============================] - 25s 315ms/step - loss: 1.6650 - accuracy: 0.6389 - val_loss: 1.0821 - val_accuracy: 0.7012
# Epoch 231/300
# 80/80 [==============================] - 25s 311ms/step - loss: 1.4279 - accuracy: 0.6575 - val_loss: 1.1925 - val_accuracy: 0.6889
# Epoch 232/300
# 80/80 [==============================] - 25s 315ms/step - loss: 1.3127 - accuracy: 0.6765 - val_loss: 0.7848 - val_accuracy: 0.7585
# Epoch 233/300
# 80/80 [==============================] - 25s 313ms/step - loss: 1.0864 - accuracy: 0.6990 - val_loss: 2.7038 - val_accuracy: 0.5263
# Epoch 234/300
# 80/80 [==============================] - 25s 314ms/step - loss: 1.3116 - accuracy: 0.6749 - val_loss: 0.6086 - val_accuracy: 0.7941
# Epoch 235/300
# 80/80 [==============================] - 25s 312ms/step - loss: 1.2051 - accuracy: 0.6765 - val_loss: 0.7969 - val_accuracy: 0.7647
# Epoch 236/300
# 80/80 [==============================] - 25s 314ms/step - loss: 1.1503 - accuracy: 0.6885 - val_loss: 2.1566 - val_accuracy: 0.5557
# Epoch 237/300
# 80/80 [==============================] - 25s 311ms/step - loss: 1.2555 - accuracy: 0.6633 - val_loss: 0.9383 - val_accuracy: 0.7245
# Epoch 238/300
# 80/80 [==============================] - 25s 314ms/step - loss: 1.1165 - accuracy: 0.6939 - val_loss: 0.9069 - val_accuracy: 0.7260
# Epoch 239/300
# 80/80 [==============================] - 25s 315ms/step - loss: 1.4590 - accuracy: 0.6447 - val_loss: 0.6649 - val_accuracy: 0.8003
# Epoch 240/300
# 80/80 [==============================] - 25s 313ms/step - loss: 1.1091 - accuracy: 0.6877 - val_loss: 0.6069 - val_accuracy: 0.8034
# Epoch 241/300
# 80/80 [==============================] - 25s 314ms/step - loss: 1.2438 - accuracy: 0.6645 - val_loss: 0.8822 - val_accuracy: 0.7461
# Epoch 242/300
# 80/80 [==============================] - 25s 314ms/step - loss: 1.3987 - accuracy: 0.6652 - val_loss: 0.8166 - val_accuracy: 0.7678
# Epoch 243/300
# 80/80 [==============================] - 25s 313ms/step - loss: 1.4063 - accuracy: 0.6680 - val_loss: 0.6570 - val_accuracy: 0.8019
# Epoch 244/300
# 80/80 [==============================] - 25s 315ms/step - loss: 1.2116 - accuracy: 0.6769 - val_loss: 0.8089 - val_accuracy: 0.7709
# Epoch 245/300
# 80/80 [==============================] - 25s 314ms/step - loss: 1.3589 - accuracy: 0.6571 - val_loss: 0.6595 - val_accuracy: 0.7972
# Epoch 246/300
# 80/80 [==============================] - 25s 310ms/step - loss: 1.2832 - accuracy: 0.6610 - val_loss: 0.8349 - val_accuracy: 0.7399
# Epoch 247/300
# 80/80 [==============================] - 25s 312ms/step - loss: 1.0876 - accuracy: 0.6928 - val_loss: 1.4353 - val_accuracy: 0.6084
# Epoch 248/300
# 80/80 [==============================] - 25s 312ms/step - loss: 1.1682 - accuracy: 0.6823 - val_loss: 1.5611 - val_accuracy: 0.6084
# Epoch 249/300
# 80/80 [==============================] - 25s 313ms/step - loss: 1.2351 - accuracy: 0.6707 - val_loss: 0.6461 - val_accuracy: 0.7879
# Epoch 250/300
# 80/80 [==============================] - 25s 316ms/step - loss: 1.3340 - accuracy: 0.6637 - val_loss: 0.6736 - val_accuracy: 0.7817
# Epoch 251/300
# 80/80 [==============================] - 25s 314ms/step - loss: 1.1242 - accuracy: 0.6730 - val_loss: 1.5035 - val_accuracy: 0.6378
# Epoch 252/300
# 80/80 [==============================] - 25s 311ms/step - loss: 1.3959 - accuracy: 0.6497 - val_loss: 0.6127 - val_accuracy: 0.8158
# Epoch 253/300
# 80/80 [==============================] - 25s 312ms/step - loss: 1.2086 - accuracy: 0.6881 - val_loss: 0.6470 - val_accuracy: 0.8019
# Epoch 254/300
# 80/80 [==============================] - 25s 311ms/step - loss: 1.2158 - accuracy: 0.6711 - val_loss: 0.9398 - val_accuracy: 0.7229
# Epoch 255/300
# 80/80 [==============================] - 26s 316ms/step - loss: 1.5817 - accuracy: 0.6412 - val_loss: 0.7051 - val_accuracy: 0.8003
# Epoch 256/300
# 80/80 [==============================] - 25s 309ms/step - loss: 1.1415 - accuracy: 0.6792 - val_loss: 0.6539 - val_accuracy: 0.8003
# Epoch 257/300
# 80/80 [==============================] - 25s 313ms/step - loss: 1.2434 - accuracy: 0.6718 - val_loss: 1.1029 - val_accuracy: 0.6873
# Epoch 258/300
# 80/80 [==============================] - 25s 312ms/step - loss: 1.2417 - accuracy: 0.6734 - val_loss: 0.7053 - val_accuracy: 0.7771
# Epoch 259/300
# 80/80 [==============================] - 25s 308ms/step - loss: 1.3406 - accuracy: 0.6517 - val_loss: 1.6383 - val_accuracy: 0.6146
# Epoch 260/300
# 80/80 [==============================] - 25s 310ms/step - loss: 1.5878 - accuracy: 0.6377 - val_loss: 0.6839 - val_accuracy: 0.7926
# Epoch 261/300
# 80/80 [==============================] - 25s 314ms/step - loss: 1.2501 - accuracy: 0.6749 - val_loss: 1.1918 - val_accuracy: 0.6780
# Epoch 262/300
# 80/80 [==============================] - 25s 308ms/step - loss: 1.4580 - accuracy: 0.6493 - val_loss: 0.7522 - val_accuracy: 0.7895
# Epoch 263/300
# 80/80 [==============================] - 25s 315ms/step - loss: 1.0813 - accuracy: 0.6963 - val_loss: 0.6682 - val_accuracy: 0.7848
# Epoch 264/300
# 80/80 [==============================] - 25s 312ms/step - loss: 1.1939 - accuracy: 0.6738 - val_loss: 0.6161 - val_accuracy: 0.7879
# Epoch 265/300
# 80/80 [==============================] - 25s 311ms/step - loss: 1.5916 - accuracy: 0.6462 - val_loss: 0.7815 - val_accuracy: 0.7570
# Epoch 266/300
# 80/80 [==============================] - 25s 308ms/step - loss: 1.3449 - accuracy: 0.6625 - val_loss: 0.8402 - val_accuracy: 0.7446
# Epoch 267/300
# 80/80 [==============================] - 25s 310ms/step - loss: 1.1998 - accuracy: 0.6761 - val_loss: 1.2996 - val_accuracy: 0.6533
# Epoch 268/300
# 80/80 [==============================] - 25s 311ms/step - loss: 1.2528 - accuracy: 0.6746 - val_loss: 0.6424 - val_accuracy: 0.7926
# Epoch 269/300
# 80/80 [==============================] - 25s 313ms/step - loss: 1.0802 - accuracy: 0.6808 - val_loss: 0.5991 - val_accuracy: 0.7988
# Epoch 270/300
# 80/80 [==============================] - 25s 313ms/step - loss: 1.1938 - accuracy: 0.6738 - val_loss: 0.6066 - val_accuracy: 0.7972
# Epoch 271/300
# 80/80 [==============================] - 25s 314ms/step - loss: 1.1622 - accuracy: 0.6788 - val_loss: 0.9205 - val_accuracy: 0.7028
# Epoch 272/300
# 80/80 [==============================] - 25s 307ms/step - loss: 1.3391 - accuracy: 0.6637 - val_loss: 1.1383 - val_accuracy: 0.6873
# Epoch 273/300
# 80/80 [==============================] - 25s 312ms/step - loss: 1.0840 - accuracy: 0.6866 - val_loss: 0.8459 - val_accuracy: 0.7307
# Epoch 274/300
# 80/80 [==============================] - 25s 313ms/step - loss: 1.2246 - accuracy: 0.6730 - val_loss: 1.2759 - val_accuracy: 0.6409
# Epoch 275/300
# 80/80 [==============================] - 25s 310ms/step - loss: 1.2157 - accuracy: 0.6594 - val_loss: 0.6118 - val_accuracy: 0.7926
# Epoch 276/300
# 80/80 [==============================] - 25s 311ms/step - loss: 1.1041 - accuracy: 0.6765 - val_loss: 1.1350 - val_accuracy: 0.6641
# Epoch 277/300
# 80/80 [==============================] - 25s 310ms/step - loss: 1.3386 - accuracy: 0.6672 - val_loss: 1.8540 - val_accuracy: 0.5712
# Epoch 278/300
# 80/80 [==============================] - 25s 308ms/step - loss: 1.5093 - accuracy: 0.6490 - val_loss: 0.6788 - val_accuracy: 0.7755
# Epoch 279/300
# 80/80 [==============================] - 25s 309ms/step - loss: 1.2803 - accuracy: 0.6777 - val_loss: 0.6601 - val_accuracy: 0.7864
# Epoch 280/300
# 80/80 [==============================] - 25s 311ms/step - loss: 1.1915 - accuracy: 0.6858 - val_loss: 1.0919 - val_accuracy: 0.6811
# Epoch 281/300
# 80/80 [==============================] - 25s 312ms/step - loss: 1.3450 - accuracy: 0.6614 - val_loss: 0.6872 - val_accuracy: 0.7709
# Epoch 282/300
# 80/80 [==============================] - 25s 314ms/step - loss: 1.2440 - accuracy: 0.6660 - val_loss: 0.8349 - val_accuracy: 0.7368
# Epoch 283/300
# 80/80 [==============================] - 25s 314ms/step - loss: 1.0877 - accuracy: 0.6877 - val_loss: 1.0841 - val_accuracy: 0.6966
# Epoch 284/300
# 80/80 [==============================] - 25s 313ms/step - loss: 1.0926 - accuracy: 0.6800 - val_loss: 1.4860 - val_accuracy: 0.6084
# Epoch 285/300
# 80/80 [==============================] - 25s 309ms/step - loss: 1.3245 - accuracy: 0.6641 - val_loss: 0.6977 - val_accuracy: 0.7848
# Epoch 286/300
# 80/80 [==============================] - 25s 314ms/step - loss: 1.0737 - accuracy: 0.6901 - val_loss: 1.3895 - val_accuracy: 0.6176
# Epoch 287/300
# 80/80 [==============================] - 25s 315ms/step - loss: 1.1174 - accuracy: 0.6815 - val_loss: 0.6098 - val_accuracy: 0.7957
# Epoch 288/300
# 80/80 [==============================] - 25s 312ms/step - loss: 1.1616 - accuracy: 0.6761 - val_loss: 0.9592 - val_accuracy: 0.7121
# Epoch 289/300
# 80/80 [==============================] - 25s 310ms/step - loss: 1.2820 - accuracy: 0.6722 - val_loss: 0.8564 - val_accuracy: 0.7632
# Epoch 290/300
# 80/80 [==============================] - 25s 311ms/step - loss: 1.2591 - accuracy: 0.6493 - val_loss: 0.6775 - val_accuracy: 0.7895
# Epoch 291/300
# 80/80 [==============================] - 25s 309ms/step - loss: 1.3048 - accuracy: 0.6478 - val_loss: 0.9817 - val_accuracy: 0.7028
# Epoch 292/300
# 80/80 [==============================] - 25s 316ms/step - loss: 1.3288 - accuracy: 0.6672 - val_loss: 2.8311 - val_accuracy: 0.5294
# Epoch 293/300
# 80/80 [==============================] - 25s 313ms/step - loss: 1.7982 - accuracy: 0.6241 - val_loss: 0.6991 - val_accuracy: 0.7771
# Epoch 294/300
# 80/80 [==============================] - 25s 310ms/step - loss: 1.4151 - accuracy: 0.6493 - val_loss: 1.1154 - val_accuracy: 0.6981
# Epoch 295/300
# 80/80 [==============================] - 25s 313ms/step - loss: 1.4500 - accuracy: 0.6435 - val_loss: 1.0232 - val_accuracy: 0.6935
# Epoch 296/300
# 80/80 [==============================] - 25s 315ms/step - loss: 1.4018 - accuracy: 0.6649 - val_loss: 0.6439 - val_accuracy: 0.7864
# Epoch 297/300
# 80/80 [==============================] - 25s 315ms/step - loss: 1.8129 - accuracy: 0.6369 - val_loss: 1.1340 - val_accuracy: 0.7043
# Epoch 298/300
# 80/80 [==============================] - 25s 311ms/step - loss: 1.4204 - accuracy: 0.6524 - val_loss: 0.7792 - val_accuracy: 0.7632
# Epoch 299/300
# 80/80 [==============================] - 25s 313ms/step - loss: 1.1410 - accuracy: 0.6761 - val_loss: 0.7319 - val_accuracy: 0.7786
# Epoch 300/300
# 80/80 [==============================] - 25s 308ms/step - loss: 1.1768 - accuracy: 0.6711 - val_loss: 0.6371 - val_accuracy: 0.7895

# %%
# Save Model and Weights
model.save('/content/drive/MyDrive/Colab Notebooks/CTCov/CLAHE/ResNet50/res_ct.h5')
model.save_weights('/content/drive/MyDrive/Colab Notebooks/CTCov/CLAHE/ResNet50/res_weights_ct.hdf5')
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/engine/functional.py:1410: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   layer_config = serialize_layer_fn(layer)

# %%
y_pred = model.predict(X_test, batch_size=batch_size)

# %%
prediction=y_pred[0:10]
for index, probability in enumerate(prediction):
  if probability[1] > 0.5:
        plt.title('%.2f' % (probability[1]*100) + '% COVID')
  else:
        plt.title('%.2f' % ((1-probability[1])*100) + '% NonCOVID')
  plt.imshow(X_test[index])
  plt.show()

# %%
# Convert to Binary classes
y_pred_bin = np.argmax(y_pred, axis=1)
y_test_bin = np.argmax(y_test, axis=1)

# %%
from sklearn.metrics import classification_report
report = classification_report(y_test_bin, y_pred_bin, output_dict=True)
print(report)
# Out:
# {'0': {'precision': 0.8194444444444444, 'recall': 0.7375, 'f1-score': 0.7763157894736842, 'support': 320}, '1': {'precision': 0.7653631284916201, 'recall': 0.8404907975460123, 'f1-score': 0.8011695906432748, 'support': 326}, 'accuracy': 0.7894736842105263, 'macro avg': {'precision': 0.7924037864680322, 'recall': 0.7889953987730062, 'f1-score': 0.7887426900584795, 'support': 646}, 'weighted avg': {'precision': 0.7921526348459603, 'recall': 0.7894736842105263, 'f1-score': 0.7888581101877501, 'support': 646}}

# %%
import pandas as pd
report_df = pd.DataFrame(report).transpose()
report_df
# Out:
#               precision    recall  f1-score     support
# 0              0.819444  0.737500  0.776316  320.000000
# 1              0.765363  0.840491  0.801170  326.000000
# accuracy       0.789474  0.789474  0.789474    0.789474
# macro avg      0.792404  0.788995  0.788743  646.000000
# weighted avg   0.792153  0.789474  0.788858  646.000000

# %%
# or save to csv: 
report_csv_file = '/content/drive/MyDrive/Colab Notebooks/CTCov/CLAHE/ResNet50/res_class_report.csv'
with open(report_csv_file, mode='w') as f:
    report_df.to_csv(f)

# %%
test_report = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/CTCov/CLAHE/ResNet50/res_class_report.csv')
test_report
# Out:
#      Unnamed: 0  precision    recall  f1-score     support
# 0             0   0.819444  0.737500  0.776316  320.000000
# 1             1   0.765363  0.840491  0.801170  326.000000
# 2      accuracy   0.789474  0.789474  0.789474    0.789474
# 3     macro avg   0.792404  0.788995  0.788743  646.000000
# 4  weighted avg   0.792153  0.789474  0.788858  646.000000

# %%
plt.plot(res.history['accuracy'])
plt.plot(res.history['val_accuracy'])

plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')

plt.legend(['Training', 'Testing'])
plt.savefig('/content/drive/MyDrive/Colab Notebooks/CTCov/CLAHE/ResNet50/res_ct_accuracy.png')
plt.show()

# %%
plt.plot(res.history['loss'])
plt.plot(res.history['val_loss'])

plt.title('Model Loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')

plt.legend(['Training', 'Testing'])
plt.savefig('/content/drive/MyDrive/Colab Notebooks/CTCov/CLAHE/ResNet50/res_ct_loss.png')
plt.show()

# %%
def plot_confusion_matrix(normalize):
  classes = ['COVID','NonCOVID']
  tick_marks = [0.5,1.5]
  cn = confusion_matrix(y_test_bin, y_pred_bin,normalize=normalize)
  sns.heatmap(cn,cmap='plasma',annot=True)
  plt.xticks(tick_marks, classes)
  plt.yticks(tick_marks, classes)
  plt.title('Confusion Matrix')
  plt.ylabel('True label')
  plt.xlabel('Predicted label')
  if normalize != 'true':
    plt.savefig("/content/drive/MyDrive/Colab Notebooks/CTCov/CLAHE/ResNet50/res_conf_matrix_not_norm.png")
  else:
    plt.savefig("/content/drive/MyDrive/Colab Notebooks/CTCov/CLAHE/ResNet50/res_conf_matrix_norm.png")
  plt.show()

print('Confusion Matrix without Normalization')
plot_confusion_matrix(normalize=None)
# print('Confusion Matrix with Normalized Values')
plot_confusion_matrix(normalize='true')
# Out:
# Confusion Matrix without Normalization

# %%
import pandas as pd

# convert the history.history dict to a pandas DataFrame:     
hist_df = pd.DataFrame(res.history)

# %%
hist_df.head()
# Out:
#        loss  accuracy  val_loss  val_accuracy
# 0  1.699190  0.525213  1.252845      0.535604
# 1  1.270124  0.566718  0.579520      0.727554
# 2  0.879343  0.607836  0.565743      0.752322
# 3  1.538450  0.575252  0.571723      0.761610
# 4  1.166130  0.587277  1.062994      0.565015

# %%
# save to json:  
hist_json_file = '/content/drive/MyDrive/Colab Notebooks/CTCov/CLAHE/ResNet50/res_history.json' 
with open(hist_json_file, mode='w') as f:
    hist_df.to_json(f)

# or save to csv: 
hist_csv_file = '/content/drive/MyDrive/Colab Notebooks/CTCov/CLAHE/ResNet50/res_history.csv'
with open(hist_csv_file, mode='w') as f:
    hist_df.to_csv(f)

# %%
test_df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/CTCov/CLAHE/ResNet50/res_history.csv')
test_df.head()
# Out:
#    Unnamed: 0      loss  accuracy  val_loss  val_accuracy
# 0           0  1.699190  0.525213  1.252845      0.535604
# 1           1  1.270124  0.566718  0.579520      0.727554
# 2           2  0.879343  0.607836  0.565743      0.752322
# 3           3  1.538450  0.575252  0.571723      0.761610
# 4           4  1.166130  0.587277  1.062994      0.565015
