# %% [markdown]
# Covid 19 CT scan Image classification with VGG19 pretrained model.
#
# Datasets: 2 public datasets stored in the folders CT_DATA (CT_COVID and CT_NonCovid) and SARS-COV-2-DATA.
#
# DATA-Split folder : initially used to split data from CT-DATA, but will not be used here in the final.

# %%
from builtins import range, input

from tensorflow.keras.layers import Input, Lambda, Dense, Flatten, AveragePooling2D, Dropout
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from sklearn.metrics import confusion_matrix, roc_curve
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

import os
import cv2
from glob import glob

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from tensorflow.keras.utils import to_categorical

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
cov_path = "/content/drive/MyDrive/Colab Notebooks/CTCov/CT_Data/CT_COVID/"
norm_path = "/content/drive/MyDrive/Colab Notebooks/CTCov/CT_Data/CT_NonCOVID/"

# %%
IMAGE_SIZE=[224,224]
epochs = 300
batch_size=32
#define paths
covid_path = '/content/drive/MyDrive/Colab Notebooks/CTCov/SARS-COV-2-Data/COVID'
noncovid_path = '/content/drive/MyDrive/Colab Notebooks/CTCov/SARS-COV-2-Data/NON-COVID'

# Use glob to grab images from path .jpg or jpeg
cov_files = glob(cov_path + '/*')
norm_files = glob(norm_path + '/*')

covid_files = glob(covid_path + '/*')
noncovid_files = glob(noncovid_path + '/*')

# %%
# Fetch Images and Class Labels from Files
cov_labels = []
norm_labels = []

cov_images=[]
norm_images=[]

for i in range(len(cov_files)):
  image = cv2.imread(cov_files[i]) # read file 
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # arrange format as per keras
  image = cv2.resize(image,(224,224)) # resize as per model
  cov_images.append(image) # append image
  cov_labels.append('CT_COVID') #append class label
  
for i in range(len(norm_files)):
  image = cv2.imread(norm_files[i])
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
  image = cv2.resize(image,(224,224))
  norm_images.append(image)
  norm_labels.append('CT_NonCOVID')

# %%
# Fetch Images and Class Labels from Files
covid_labels = []
noncovid_labels = []

covid_images=[]
noncovid_images=[]

for i in range(len(covid_files)):
  image = cv2.imread(covid_files[i]) # read file 
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # arrange format as per keras
  image = cv2.resize(image,(224,224)) # resize as per model
  covid_images.append(image) # append image
  covid_labels.append('CT_COVID') #append class label
  
for i in range(len(noncovid_files)):
  image = cv2.imread(noncovid_files[i])
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
  image = cv2.resize(image,(224,224))
  noncovid_images.append(image)
  noncovid_labels.append('CT_NonCOVID')

# %%
plt.imshow(covid_images[10])

# %%
covid_labels[10]
# Out:
# 'CT_COVID'

# %%
cov_img_all = np.concatenate((covid_images, cov_images), axis=0)
norm_img_all = np.concatenate((noncovid_images, norm_images),axis=0)

# %%
covid_labels = np.concatenate((covid_labels, cov_labels), axis=0)
noncovid_labels = np.concatenate((noncovid_labels, norm_labels),axis=0)

# %%
len(cov_img_all)
# Out:
# 1598

# %%
covid_images = np.array(cov_img_all)/255
noncovid_images = np.array(norm_img_all)/255

# %%
# Split into training and testing sets for both types of images
covid_x_train, covid_x_test, covid_y_train, covid_y_test = train_test_split(
    covid_images, covid_labels, test_size=0.2)
noncovid_x_train, noncovid_x_test, noncovid_y_train, noncovid_y_test = train_test_split(
    noncovid_images, noncovid_labels, test_size=0.2)

# Merge sets for both types of images
X_train = np.concatenate((noncovid_x_train, covid_x_train), axis=0)
X_test = np.concatenate((noncovid_x_test, covid_x_test), axis=0)
y_train = np.concatenate((noncovid_y_train, covid_y_train), axis=0)
y_test = np.concatenate((noncovid_y_test, covid_y_test), axis=0)

# Make labels into categories - either 0 or 1, for our model
y_train = LabelBinarizer().fit_transform(y_train)
y_train = to_categorical(y_train)

y_test = LabelBinarizer().fit_transform(y_test)
y_test = to_categorical(y_test)

# %% [markdown]
# # ResNet50 model

# %%
from sklearn.model_selection import KFold

kfold = KFold(n_splits=3, shuffle=True)
inputs = np.concatenate((X_train, X_test), axis=0)
targets = np.concatenate((y_train, y_test), axis=0)

# %%
# Building Model
acc_per_fold = []
loss_per_fold = []
fold_no = 1


for train, test in kfold.split(inputs, targets):

  resnet = ResNet50(weights="imagenet", include_top=False,
    input_tensor=Input(shape=(224, 224, 3)))

  outputs = resnet.output
  outputs = Flatten(name="flatten")(outputs)
  outputs = Dropout(0.5)(outputs)
  outputs = Dense(2, activation="softmax")(outputs)

  model = Model(inputs=resnet.input, outputs=outputs)

  for layer in resnet.layers:
      layer.trainable = False

  model.compile(
          loss='binary_crossentropy', 
          optimizer='nadam', 
          metrics=['accuracy']
  )

  train_aug = ImageDataGenerator(
      rotation_range=20,
      width_shift_range=0.2,
      height_shift_range=0.2,
      horizontal_flip=True
  )

  # Generate a print
  print('------------------------------------------------------------------------')
  print(f'Training for fold {fold_no} ...')
  model.fit(train_aug.flow(inputs[train], targets[train], batch_size=batch_size),
                    verbose=1,
                    epochs=100)
  
  # Generate generalization metrics
  scores = model.evaluate(inputs[test], targets[test], verbose=0)
  print(f'Score for fold {fold_no}: {model.metrics_names[0]} of {scores[0]}; {model.metrics_names[1]} of {scores[1]*100}%')
  acc_per_fold.append(scores[1] * 100)
  loss_per_fold.append(scores[0])

  # Increase fold number
  fold_no = fold_no + 1

# == Provide average scores ==
print('------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(acc_per_fold)):
  print('------------------------------------------------------------------------')
  print(f'> Fold {i+1} - Loss: {loss_per_fold[i]} - Accuracy: {acc_per_fold[i]}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(acc_per_fold)} (+- {np.std(acc_per_fold)})')
print(f'> Loss: {np.mean(loss_per_fold)}')
print('------------------------------------------------------------------------')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94773248/94765736 [==============================] - 4s 0us/step
# 94781440/94765736 [==============================] - 4s 0us/step
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Epoch 1/100
# 68/68 [==============================] - 33s 299ms/step - loss: 1.6543 - accuracy: 0.5123
# Epoch 2/100
# 68/68 [==============================] - 21s 306ms/step - loss: 1.5673 - accuracy: 0.5026
# Epoch 3/100
# 68/68 [==============================] - 21s 301ms/step - loss: 1.4952 - accuracy: 0.5272
# Epoch 4/100
# 68/68 [==============================] - 21s 302ms/step - loss: 1.4191 - accuracy: 0.5375
# Epoch 5/100
# 68/68 [==============================] - 21s 302ms/step - loss: 1.5132 - accuracy: 0.5361
# Epoch 6/100
# 68/68 [==============================] - 21s 301ms/step - loss: 1.3392 - accuracy: 0.5468
# Epoch 7/100
# 68/68 [==============================] - 20s 295ms/step - loss: 1.5775 - accuracy: 0.5188
# Epoch 8/100
# 68/68 [==============================] - 20s 297ms/step - loss: 1.3090 - accuracy: 0.5565
# Epoch 9/100
# 68/68 [==============================] - 20s 299ms/step - loss: 1.3199 - accuracy: 0.5989
# Epoch 10/100
# 68/68 [==============================] - 21s 301ms/step - loss: 1.4336 - accuracy: 0.5477
# Epoch 11/100
# 68/68 [==============================] - 21s 301ms/step - loss: 1.1830 - accuracy: 0.5765
# Epoch 12/100
# 68/68 [==============================] - 21s 303ms/step - loss: 1.3614 - accuracy: 0.5379
# Epoch 13/100
# 68/68 [==============================] - 21s 301ms/step - loss: 1.3682 - accuracy: 0.5626
# Epoch 14/100
# 68/68 [==============================] - 20s 300ms/step - loss: 1.3551 - accuracy: 0.5607
# Epoch 15/100
# 68/68 [==============================] - 21s 303ms/step - loss: 1.3789 - accuracy: 0.5510
# Epoch 16/100
# 68/68 [==============================] - 21s 300ms/step - loss: 1.2825 - accuracy: 0.5514
# Epoch 17/100
# 68/68 [==============================] - 20s 299ms/step - loss: 1.1763 - accuracy: 0.5714
# Epoch 18/100
# 68/68 [==============================] - 20s 295ms/step - loss: 1.4296 - accuracy: 0.5365
# Epoch 19/100
# 68/68 [==============================] - 20s 296ms/step - loss: 1.2589 - accuracy: 0.5649
# Epoch 20/100
# 68/68 [==============================] - 20s 296ms/step - loss: 1.2750 - accuracy: 0.5742
# Epoch 21/100
# 68/68 [==============================] - 20s 298ms/step - loss: 1.0914 - accuracy: 0.5919
# Epoch 22/100
# 68/68 [==============================] - 20s 299ms/step - loss: 1.2435 - accuracy: 0.5635
# Epoch 23/100
# 68/68 [==============================] - 20s 294ms/step - loss: 1.1665 - accuracy: 0.5770
# Epoch 24/100
# 68/68 [==============================] - 20s 295ms/step - loss: 1.2992 - accuracy: 0.5621
# Epoch 25/100
# 68/68 [==============================] - 20s 297ms/step - loss: 1.2212 - accuracy: 0.5775
# Epoch 26/100
# 68/68 [==============================] - 20s 298ms/step - loss: 1.1475 - accuracy: 0.5798
# Epoch 27/100
# 68/68 [==============================] - 20s 296ms/step - loss: 1.2263 - accuracy: 0.5682
# Epoch 28/100
# 68/68 [==============================] - 20s 297ms/step - loss: 1.1078 - accuracy: 0.5886
# Epoch 29/100
# 68/68 [==============================] - 20s 296ms/step - loss: 1.1508 - accuracy: 0.5728
# Epoch 30/100
# 68/68 [==============================] - 20s 297ms/step - loss: 1.0175 - accuracy: 0.6049
# Epoch 31/100
# 68/68 [==============================] - 20s 294ms/step - loss: 1.2273 - accuracy: 0.5770
# Epoch 32/100
# 68/68 [==============================] - 20s 298ms/step - loss: 1.0863 - accuracy: 0.5993
# Epoch 33/100
# 68/68 [==============================] - 20s 299ms/step - loss: 1.1586 - accuracy: 0.5798
# Epoch 34/100
# 68/68 [==============================] - 20s 297ms/step - loss: 1.1260 - accuracy: 0.5789
# Epoch 35/100
# 68/68 [==============================] - 20s 299ms/step - loss: 1.2244 - accuracy: 0.5700
# Epoch 36/100
# 68/68 [==============================] - 20s 297ms/step - loss: 1.1070 - accuracy: 0.5854
# Epoch 37/100
# 68/68 [==============================] - 20s 297ms/step - loss: 1.0030 - accuracy: 0.6152
# Epoch 38/100
# 68/68 [==============================] - 20s 299ms/step - loss: 1.2529 - accuracy: 0.5654
# Epoch 39/100
# 68/68 [==============================] - 20s 299ms/step - loss: 1.0280 - accuracy: 0.6073
# Epoch 40/100
# 68/68 [==============================] - 20s 296ms/step - loss: 1.0117 - accuracy: 0.6161
# Epoch 41/100
# 68/68 [==============================] - 20s 295ms/step - loss: 1.0335 - accuracy: 0.6105
# Epoch 42/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.9675 - accuracy: 0.6170
# Epoch 43/100
# 68/68 [==============================] - 20s 298ms/step - loss: 1.0777 - accuracy: 0.5919
# Epoch 44/100
# 68/68 [==============================] - 20s 299ms/step - loss: 1.0495 - accuracy: 0.6049
# Epoch 45/100
# 68/68 [==============================] - 20s 298ms/step - loss: 1.0383 - accuracy: 0.6082
# Epoch 46/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.9755 - accuracy: 0.6091
# Epoch 47/100
# 68/68 [==============================] - 20s 299ms/step - loss: 1.1524 - accuracy: 0.5872
# Epoch 48/100
# 68/68 [==============================] - 20s 298ms/step - loss: 1.0633 - accuracy: 0.5872
# Epoch 49/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.9304 - accuracy: 0.6133
# Epoch 50/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.9416 - accuracy: 0.6291
# Epoch 51/100
# 68/68 [==============================] - 20s 298ms/step - loss: 1.0339 - accuracy: 0.6114
# Epoch 52/100
# 68/68 [==============================] - 20s 296ms/step - loss: 1.0360 - accuracy: 0.5980
# Epoch 53/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.9176 - accuracy: 0.6277
# Epoch 54/100
# 68/68 [==============================] - 20s 297ms/step - loss: 1.1022 - accuracy: 0.5961
# Epoch 55/100
# 68/68 [==============================] - 20s 295ms/step - loss: 1.1243 - accuracy: 0.6021
# Epoch 56/100
# 68/68 [==============================] - 20s 297ms/step - loss: 1.0963 - accuracy: 0.5891
# Epoch 57/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.9829 - accuracy: 0.6208
# Epoch 58/100
# 68/68 [==============================] - 20s 299ms/step - loss: 1.0378 - accuracy: 0.6007
# Epoch 59/100
# 68/68 [==============================] - 21s 302ms/step - loss: 0.9652 - accuracy: 0.6180
# Epoch 60/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.9874 - accuracy: 0.6138
# Epoch 61/100
# 68/68 [==============================] - 20s 296ms/step - loss: 1.0187 - accuracy: 0.6026
# Epoch 62/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.9090 - accuracy: 0.6277
# Epoch 63/100
# 68/68 [==============================] - 20s 296ms/step - loss: 1.0423 - accuracy: 0.6026
# Epoch 64/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.9315 - accuracy: 0.6235
# Epoch 65/100
# 68/68 [==============================] - 20s 299ms/step - loss: 1.0291 - accuracy: 0.6128
# Epoch 66/100
# 68/68 [==============================] - 20s 293ms/step - loss: 0.9675 - accuracy: 0.6133
# Epoch 67/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.9697 - accuracy: 0.6249
# Epoch 68/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.9944 - accuracy: 0.6203
# Epoch 69/100
# 68/68 [==============================] - 20s 297ms/step - loss: 1.0669 - accuracy: 0.5938
# Epoch 70/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.8782 - accuracy: 0.6277
# Epoch 71/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.9977 - accuracy: 0.6208
# Epoch 72/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.9541 - accuracy: 0.6282
# Epoch 73/100
# 68/68 [==============================] - 20s 297ms/step - loss: 1.0092 - accuracy: 0.5993
# Epoch 74/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.9303 - accuracy: 0.6254
# Epoch 75/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.9044 - accuracy: 0.6403
# Epoch 76/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.9170 - accuracy: 0.6310
# Epoch 77/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.8879 - accuracy: 0.6231
# Epoch 78/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.9584 - accuracy: 0.6124
# Epoch 79/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.9574 - accuracy: 0.6105
# Epoch 80/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.9698 - accuracy: 0.6110
# Epoch 81/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.8765 - accuracy: 0.6454
# Epoch 82/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.9866 - accuracy: 0.6166
# Epoch 83/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.9468 - accuracy: 0.6235
# Epoch 84/100
# 68/68 [==============================] - 20s 293ms/step - loss: 0.9135 - accuracy: 0.6394
# Epoch 85/100
# 68/68 [==============================] - 20s 295ms/step - loss: 1.0222 - accuracy: 0.6161
# Epoch 86/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.9529 - accuracy: 0.6138
# Epoch 87/100
# 68/68 [==============================] - 20s 292ms/step - loss: 0.9829 - accuracy: 0.6128
# Epoch 88/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.9831 - accuracy: 0.6212
# Epoch 89/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.9788 - accuracy: 0.6184
# Epoch 90/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.8714 - accuracy: 0.6356
# Epoch 91/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.9387 - accuracy: 0.6245
# Epoch 92/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.8970 - accuracy: 0.6254
# Epoch 93/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.9588 - accuracy: 0.6189
# Epoch 94/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.9001 - accuracy: 0.6329
# Epoch 95/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.8949 - accuracy: 0.6333
# Epoch 96/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.9716 - accuracy: 0.6119
# Epoch 97/100
# 68/68 [==============================] - 21s 300ms/step - loss: 0.8140 - accuracy: 0.6496
# Epoch 98/100
# 68/68 [==============================] - 20s 300ms/step - loss: 0.9060 - accuracy: 0.6468
# Epoch 99/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.9467 - accuracy: 0.6263
# Epoch 100/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.9161 - accuracy: 0.6347
# Score for fold 1: loss of 0.5750570893287659; accuracy of 74.32557940483093%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Epoch 1/100
# 68/68 [==============================] - 23s 296ms/step - loss: 1.6758 - accuracy: 0.5114
# Epoch 2/100
# 68/68 [==============================] - 20s 297ms/step - loss: 1.6189 - accuracy: 0.5202
# Epoch 3/100
# 68/68 [==============================] - 20s 297ms/step - loss: 1.5251 - accuracy: 0.5230
# Epoch 4/100
# 68/68 [==============================] - 20s 298ms/step - loss: 1.4557 - accuracy: 0.5188
# Epoch 5/100
# 68/68 [==============================] - 20s 297ms/step - loss: 1.4028 - accuracy: 0.5291
# Epoch 6/100
# 68/68 [==============================] - 20s 296ms/step - loss: 1.5693 - accuracy: 0.5179
# Epoch 7/100
# 68/68 [==============================] - 20s 298ms/step - loss: 1.3506 - accuracy: 0.5412
# Epoch 8/100
# 68/68 [==============================] - 20s 296ms/step - loss: 1.2911 - accuracy: 0.5528
# Epoch 9/100
# 68/68 [==============================] - 20s 295ms/step - loss: 1.3920 - accuracy: 0.5370
# Epoch 10/100
# 68/68 [==============================] - 20s 298ms/step - loss: 1.4526 - accuracy: 0.5398
# Epoch 11/100
# 68/68 [==============================] - 20s 297ms/step - loss: 1.4111 - accuracy: 0.5416
# Epoch 12/100
# 68/68 [==============================] - 20s 299ms/step - loss: 1.1941 - accuracy: 0.5733
# Epoch 13/100
# 68/68 [==============================] - 20s 297ms/step - loss: 1.1113 - accuracy: 0.6054
# Epoch 14/100
# 68/68 [==============================] - 20s 295ms/step - loss: 1.1510 - accuracy: 0.5733
# Epoch 15/100
# 68/68 [==============================] - 20s 299ms/step - loss: 1.2703 - accuracy: 0.5654
# Epoch 16/100
# 68/68 [==============================] - 20s 294ms/step - loss: 1.3560 - accuracy: 0.5519
# Epoch 17/100
# 68/68 [==============================] - 20s 295ms/step - loss: 1.3009 - accuracy: 0.5593
# Epoch 18/100
# 68/68 [==============================] - 20s 296ms/step - loss: 1.2018 - accuracy: 0.5770
# Epoch 19/100
# 68/68 [==============================] - 20s 295ms/step - loss: 1.2941 - accuracy: 0.5561
# Epoch 20/100
# 68/68 [==============================] - 20s 299ms/step - loss: 1.2042 - accuracy: 0.5747
# Epoch 21/100
# 68/68 [==============================] - 20s 297ms/step - loss: 1.1395 - accuracy: 0.5859
# Epoch 22/100
# 68/68 [==============================] - 20s 295ms/step - loss: 1.1714 - accuracy: 0.5798
# Epoch 23/100
# 68/68 [==============================] - 20s 296ms/step - loss: 1.0830 - accuracy: 0.5975
# Epoch 24/100
# 68/68 [==============================] - 21s 304ms/step - loss: 1.2998 - accuracy: 0.5640
# Epoch 25/100
# 68/68 [==============================] - 20s 298ms/step - loss: 1.0961 - accuracy: 0.5952
# Epoch 26/100
# 68/68 [==============================] - 20s 299ms/step - loss: 1.0194 - accuracy: 0.6059
# Epoch 27/100
# 68/68 [==============================] - 20s 296ms/step - loss: 1.1254 - accuracy: 0.5938
# Epoch 28/100
# 68/68 [==============================] - 20s 303ms/step - loss: 1.1735 - accuracy: 0.5882
# Epoch 29/100
# 68/68 [==============================] - 20s 296ms/step - loss: 1.0440 - accuracy: 0.6003
# Epoch 30/100
# 68/68 [==============================] - 20s 297ms/step - loss: 1.1531 - accuracy: 0.5970
# Epoch 31/100
# 68/68 [==============================] - 20s 297ms/step - loss: 1.0449 - accuracy: 0.6017
# Epoch 32/100
# 68/68 [==============================] - 20s 299ms/step - loss: 1.2731 - accuracy: 0.5696
# Epoch 33/100
# 68/68 [==============================] - 20s 297ms/step - loss: 1.0536 - accuracy: 0.5928
# Epoch 34/100
# 68/68 [==============================] - 20s 296ms/step - loss: 1.0745 - accuracy: 0.6045
# Epoch 35/100
# 68/68 [==============================] - 20s 295ms/step - loss: 1.0061 - accuracy: 0.6221
# Epoch 36/100
# 68/68 [==============================] - 20s 297ms/step - loss: 1.0574 - accuracy: 0.6147
# Epoch 37/100
# 68/68 [==============================] - 20s 295ms/step - loss: 1.1545 - accuracy: 0.5919
# Epoch 38/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.9904 - accuracy: 0.6277
# Epoch 39/100
# 68/68 [==============================] - 20s 296ms/step - loss: 1.0519 - accuracy: 0.6031
# Epoch 40/100
# 68/68 [==============================] - 20s 299ms/step - loss: 1.0667 - accuracy: 0.6138
# Epoch 41/100
# 68/68 [==============================] - 20s 299ms/step - loss: 1.0207 - accuracy: 0.6217
# Epoch 42/100
# 68/68 [==============================] - 20s 297ms/step - loss: 1.1028 - accuracy: 0.5910
# Epoch 43/100
# 68/68 [==============================] - 20s 297ms/step - loss: 1.0444 - accuracy: 0.6184
# Epoch 44/100
# 68/68 [==============================] - 21s 300ms/step - loss: 1.1079 - accuracy: 0.6031
# Epoch 45/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.9776 - accuracy: 0.6412
# Epoch 46/100
# 68/68 [==============================] - 20s 293ms/step - loss: 0.9679 - accuracy: 0.6301
# Epoch 47/100
# 68/68 [==============================] - 20s 295ms/step - loss: 1.0713 - accuracy: 0.6035
# Epoch 48/100
# 68/68 [==============================] - 20s 297ms/step - loss: 1.0819 - accuracy: 0.6012
# Epoch 49/100
# 68/68 [==============================] - 20s 299ms/step - loss: 1.0459 - accuracy: 0.6003
# Epoch 50/100
# 68/68 [==============================] - 20s 296ms/step - loss: 1.0139 - accuracy: 0.6110
# Epoch 51/100
# 68/68 [==============================] - 20s 298ms/step - loss: 1.0219 - accuracy: 0.6235
# Epoch 52/100
# 68/68 [==============================] - 20s 298ms/step - loss: 1.1226 - accuracy: 0.5966
# Epoch 53/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.9849 - accuracy: 0.6166
# Epoch 54/100
# 68/68 [==============================] - 20s 295ms/step - loss: 1.1514 - accuracy: 0.5779
# Epoch 55/100
# 68/68 [==============================] - 20s 297ms/step - loss: 1.0640 - accuracy: 0.6035
# Epoch 56/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.8911 - accuracy: 0.6329
# Epoch 57/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.9792 - accuracy: 0.6203
# Epoch 58/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.9240 - accuracy: 0.6291
# Epoch 59/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.9923 - accuracy: 0.6166
# Epoch 60/100
# 68/68 [==============================] - 20s 295ms/step - loss: 1.0265 - accuracy: 0.6119
# Epoch 61/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.9565 - accuracy: 0.6147
# Epoch 62/100
# 68/68 [==============================] - 20s 300ms/step - loss: 0.9668 - accuracy: 0.6263
# Epoch 63/100
# 68/68 [==============================] - 21s 301ms/step - loss: 1.1417 - accuracy: 0.5933
# Epoch 64/100
# 68/68 [==============================] - 21s 301ms/step - loss: 0.9841 - accuracy: 0.6096
# Epoch 65/100
# 68/68 [==============================] - 20s 300ms/step - loss: 0.9816 - accuracy: 0.6133
# Epoch 66/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.9459 - accuracy: 0.6329
# Epoch 67/100
# 68/68 [==============================] - 20s 296ms/step - loss: 1.0201 - accuracy: 0.6198
# Epoch 68/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.8841 - accuracy: 0.6403
# Epoch 69/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.8331 - accuracy: 0.6543
# Epoch 70/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.9825 - accuracy: 0.6338
# Epoch 71/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.9405 - accuracy: 0.6417
# Epoch 72/100
# 68/68 [==============================] - 21s 301ms/step - loss: 0.9195 - accuracy: 0.6338
# Epoch 73/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.8822 - accuracy: 0.6370
# Epoch 74/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.9394 - accuracy: 0.6324
# Epoch 75/100
# 68/68 [==============================] - 21s 301ms/step - loss: 0.9896 - accuracy: 0.6226
# Epoch 76/100
# 68/68 [==============================] - 21s 300ms/step - loss: 0.9199 - accuracy: 0.6189
# Epoch 77/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.8966 - accuracy: 0.6301
# Epoch 78/100
# 68/68 [==============================] - 21s 301ms/step - loss: 0.9759 - accuracy: 0.6263
# Epoch 79/100
# 68/68 [==============================] - 21s 305ms/step - loss: 0.9451 - accuracy: 0.6249
# Epoch 80/100
# 68/68 [==============================] - 20s 300ms/step - loss: 0.8991 - accuracy: 0.6315
# Epoch 81/100
# 68/68 [==============================] - 20s 300ms/step - loss: 0.8574 - accuracy: 0.6384
# Epoch 82/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.9288 - accuracy: 0.6217
# Epoch 83/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.8680 - accuracy: 0.6417
# Epoch 84/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.9038 - accuracy: 0.6329
# Epoch 85/100
# 68/68 [==============================] - 20s 300ms/step - loss: 0.9011 - accuracy: 0.6273
# Epoch 86/100
# 68/68 [==============================] - 20s 300ms/step - loss: 0.8773 - accuracy: 0.6431
# Epoch 87/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.8822 - accuracy: 0.6426
# Epoch 88/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.8748 - accuracy: 0.6543
# Epoch 89/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.9584 - accuracy: 0.6180
# Epoch 90/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.9107 - accuracy: 0.6254
# Epoch 91/100
# 68/68 [==============================] - 21s 300ms/step - loss: 0.9233 - accuracy: 0.6259
# Epoch 92/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.9041 - accuracy: 0.6263
# Epoch 93/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.9242 - accuracy: 0.6226
# Epoch 94/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.9887 - accuracy: 0.6208
# Epoch 95/100
# 68/68 [==============================] - 20s 300ms/step - loss: 0.9197 - accuracy: 0.6287
# Epoch 96/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.8415 - accuracy: 0.6431
# Epoch 97/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.8556 - accuracy: 0.6440
# Epoch 98/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.9338 - accuracy: 0.6301
# Epoch 99/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.8918 - accuracy: 0.6375
# Epoch 100/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.8977 - accuracy: 0.6491
# Score for fold 2: loss of 0.7858182787895203; accuracy of 65.95348715782166%
# ------------------------------------------------------------------------
# Training for fold 3 ...

# %%
import pandas as pd
metrics = pd.DataFrame(acc_per_fold)
metrics = metrics.rename(columns={0:'accuracy'})
loss_df = pd.DataFrame(loss_per_fold)

# %%
metrics.head()

# %%
metrics_df = metrics.join(loss_df.rename(columns={0:'loss'}))

# %%
metrics_df.head()

# %%
# report_csv_file = '/content/drive/MyDrive/Colab Notebooks/CTCov/Fold/ResNet50/res_class_report.csv'
# with open(report_csv_file, mode='w') as f:
#     metrics_df.to_csv(f)
