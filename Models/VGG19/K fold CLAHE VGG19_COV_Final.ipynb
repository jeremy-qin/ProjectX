# %% [markdown]
# Covid 19 CT scan Image classification with VGG19 pretrained model.
#
# Datasets: 2 public datasets stored in the folders CT_DATA (CT_COVID and CT_NonCovid) and SARS-COV-2-DATA.
# https://www.kaggle.com/plameneduardo/sarscov2-ctscan-dataset
#
# https://github.com/UCSD-AI4H/COVID-CT
#
# DATA-Split folder : initially used to split data from CT-DATA, but will not be used here in the final.

# %%
from builtins import range, input

from tensorflow.keras.layers import Input, Lambda, Dense, Flatten, AveragePooling2D, Dropout
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from sklearn.metrics import confusion_matrix, roc_curve
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

import os
import cv2
from glob import glob

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from tensorflow.keras.utils import to_categorical

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
cov_path = "/content/drive/MyDrive/Colab Notebooks/CTCov/CT_Data/CT_COVID/"
norm_path = "/content/drive/MyDrive/Colab Notebooks/CTCov/CT_Data/CT_NonCOVID/"

# %%
IMAGE_SIZE=[224,224]
epochs = 300
batch_size=32
#define paths
covid_path = '/content/drive/MyDrive/Colab Notebooks/CTCov/SARS-COV-2-Data/COVID'
noncovid_path = '/content/drive/MyDrive/Colab Notebooks/CTCov/SARS-COV-2-Data/NON-COVID'

# Use glob to grab images from path .jpg or jpeg
cov_files = glob(cov_path + '/*')
norm_files = glob(norm_path + '/*')

covid_files = glob(covid_path + '/*')
noncovid_files = glob(noncovid_path + '/*')

# %%
# Fetch Images and Class Labels from Files
cov_labels = []
norm_labels = []

cov_images=[]
norm_images=[]

for i in range(len(cov_files)):
  image = cv2.imread(cov_files[i]) # read file 
  image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) # arrange format as per keras
  image = cv2.resize(image,(224,224)) # resize as per model
  cov_images.append(image) # append image
  cov_labels.append('CT_COVID') #append class label
  
for i in range(len(norm_files)):
  image = cv2.imread(norm_files[i])
  image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
  image = cv2.resize(image,(224,224))
  norm_images.append(image)
  norm_labels.append('CT_NonCOVID')

# %%
plt.imshow(cov_images[10], cmap='gray')

# %%
# Fetch Images and Class Labels from Files
covid_labels = []
noncovid_labels = []

covid_images=[]
noncovid_images=[]

for i in range(len(covid_files)):
  image = cv2.imread(covid_files[i]) # read file 
  image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) # arrange format as per keras
  image = cv2.resize(image,(224,224)) # resize as per model
  covid_images.append(image) # append image
  covid_labels.append('CT_COVID') #append class label
  
for i in range(len(noncovid_files)):
  image = cv2.imread(noncovid_files[i])
  image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
  image = cv2.resize(image,(224,224))
  noncovid_images.append(image)
  noncovid_labels.append('CT_NonCOVID')

# %%
plt.imshow(covid_images[10], cmap='gray')

# %%
noncovid_labels[10]
# Out:
# 'CT_NonCOVID'

# %%
cov_img_all = np.concatenate((covid_images, cov_images), axis=0)
norm_img_all = np.concatenate((noncovid_images, norm_images),axis=0)

# %%
covid_labels = np.concatenate((covid_labels, cov_labels), axis=0)
noncovid_labels = np.concatenate((noncovid_labels, norm_labels),axis=0)

# %%
len(cov_img_all)
# Out:
# 1598

# %% [markdown]
# # Adaptive Histogram Equalization

# %%
clahe = cv2.createCLAHE(clipLimit=4.0)

# %%
clahe_cov_img = [clahe.apply(img) for img in cov_img_all]
clahe_norm_img = [clahe.apply(img) for img in norm_img_all]

# %%
plt.imshow(clahe_cov_img[100], cmap='gray')

# %%
plt.imshow(cov_img_all[100], cmap='gray')

# %%
rgb_cov = [cv2.cvtColor(img, cv2.COLOR_BGR2RGB) for img in clahe_cov_img]

# %%
rgb_norm = [cv2.cvtColor(img, cv2.COLOR_BGR2RGB) for img in clahe_norm_img]

# %%
covid_images = np.array(rgb_cov)/255
noncovid_images = np.array(rgb_norm)/255

# %%
plt.imshow(covid_images[10])

# %%
# Split into training and testing sets for both types of images
covid_x_train, covid_x_test, covid_y_train, covid_y_test = train_test_split(
    covid_images, covid_labels, test_size=0.2)
noncovid_x_train, noncovid_x_test, noncovid_y_train, noncovid_y_test = train_test_split(
    noncovid_images, noncovid_labels, test_size=0.2)

# Merge sets for both types of images
X_train = np.concatenate((noncovid_x_train, covid_x_train), axis=0)
X_test = np.concatenate((noncovid_x_test, covid_x_test), axis=0)
y_train = np.concatenate((noncovid_y_train, covid_y_train), axis=0)
y_test = np.concatenate((noncovid_y_test, covid_y_test), axis=0)

# Make labels into categories - either 0 or 1, for our model
y_train = LabelBinarizer().fit_transform(y_train)
y_train = to_categorical(y_train)

y_test = LabelBinarizer().fit_transform(y_test)
y_test = to_categorical(y_test)

# %% [markdown]
# # VGG model

# %%
from sklearn.model_selection import KFold

kfold = KFold(n_splits=3, shuffle=True)
inputs = np.concatenate((X_train, X_test), axis=0)
targets = np.concatenate((y_train, y_test), axis=0)

# %%
from tensorflow.keras.applications import VGG19

# Building Model
acc_per_fold = []
loss_per_fold = []
fold_no = 1


for train, test in kfold.split(inputs, targets):

  vggModel = VGG19(weights="imagenet", include_top=False,
      input_tensor=Input(shape=(224, 224, 3)))
  
  outputs = vggModel.output
  outputs = Flatten(name="flatten")(outputs)
  outputs = Dropout(0.5)(outputs)
  outputs = Dense(2, activation="softmax")(outputs)

  model = Model(inputs=vggModel.input, outputs=outputs)

  for layer in vggModel.layers:
      layer.trainable = False

  model.compile(
          loss='categorical_crossentropy', 
          optimizer='adam', 
          metrics=['accuracy']
  )

  train_aug = ImageDataGenerator(
      rotation_range=20,
      width_shift_range=0.2,
      height_shift_range=0.2,
      horizontal_flip=True
  )

  # Generate a print
  print('------------------------------------------------------------------------')
  print(f'Training for fold {fold_no} ...')
  model.fit(train_aug.flow(inputs[train], targets[train], batch_size=batch_size),
                    verbose=1,
                    epochs=100)
  
  # Generate generalization metrics
  scores = model.evaluate(inputs[test], targets[test], verbose=0)
  print(f'Score for fold {fold_no}: {model.metrics_names[0]} of {scores[0]}; {model.metrics_names[1]} of {scores[1]*100}%')
  acc_per_fold.append(scores[1] * 100)
  loss_per_fold.append(scores[0])

  # Increase fold number
  fold_no = fold_no + 1

# == Provide average scores ==
print('------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(acc_per_fold)):
  print('------------------------------------------------------------------------')
  print(f'> Fold {i+1} - Loss: {loss_per_fold[i]} - Accuracy: {acc_per_fold[i]}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(acc_per_fold)} (+- {np.std(acc_per_fold)})')
print(f'> Loss: {np.mean(loss_per_fold)}')
print('------------------------------------------------------------------------')
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg19/vgg19_weights_tf_dim_ordering_tf_kernels_notop.h5
# 80142336/80134624 [==============================] - 0s 0us/step
# 80150528/80134624 [==============================] - 0s 0us/step
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Epoch 1/100
# 68/68 [==============================] - 32s 300ms/step - loss: 0.8228 - accuracy: 0.6282
# Epoch 2/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.7550 - accuracy: 0.6664
# Epoch 3/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.7478 - accuracy: 0.6915
# Epoch 4/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.5984 - accuracy: 0.7534
# Epoch 5/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.5843 - accuracy: 0.7422
# Epoch 6/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.6317 - accuracy: 0.7292
# Epoch 7/100
# 68/68 [==============================] - 20s 292ms/step - loss: 0.5812 - accuracy: 0.7520
# Epoch 8/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.6201 - accuracy: 0.7501
# Epoch 9/100
# 68/68 [==============================] - 20s 300ms/step - loss: 0.5924 - accuracy: 0.7520
# Epoch 10/100
# 68/68 [==============================] - 21s 302ms/step - loss: 0.5826 - accuracy: 0.7655
# Epoch 11/100
# 68/68 [==============================] - 21s 301ms/step - loss: 0.6090 - accuracy: 0.7608
# Epoch 12/100
# 68/68 [==============================] - 21s 301ms/step - loss: 0.6611 - accuracy: 0.7487
# Epoch 13/100
# 68/68 [==============================] - 20s 300ms/step - loss: 0.6504 - accuracy: 0.7655
# Epoch 14/100
# 68/68 [==============================] - 21s 301ms/step - loss: 0.6495 - accuracy: 0.7608
# Epoch 15/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.5966 - accuracy: 0.7720
# Epoch 16/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.5988 - accuracy: 0.7813
# Epoch 17/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.6313 - accuracy: 0.7687
# Epoch 18/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.5718 - accuracy: 0.7771
# Epoch 19/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.5788 - accuracy: 0.7701
# Epoch 20/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.6082 - accuracy: 0.7697
# Epoch 21/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.5468 - accuracy: 0.7957
# Epoch 22/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.6376 - accuracy: 0.7720
# Epoch 23/100
# 68/68 [==============================] - 20s 291ms/step - loss: 0.6515 - accuracy: 0.7738
# Epoch 24/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.6154 - accuracy: 0.7683
# Epoch 25/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.6743 - accuracy: 0.7627
# Epoch 26/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.6276 - accuracy: 0.7799
# Epoch 27/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.6722 - accuracy: 0.7664
# Epoch 28/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.6197 - accuracy: 0.7771
# Epoch 29/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.6239 - accuracy: 0.7897
# Epoch 30/100
# 68/68 [==============================] - 20s 293ms/step - loss: 0.6216 - accuracy: 0.7762
# Epoch 31/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.6272 - accuracy: 0.7752
# Epoch 32/100
# 68/68 [==============================] - 20s 293ms/step - loss: 0.5728 - accuracy: 0.7915
# Epoch 33/100
# 68/68 [==============================] - 20s 292ms/step - loss: 0.6654 - accuracy: 0.7692
# Epoch 34/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.6677 - accuracy: 0.7706
# Epoch 35/100
# 68/68 [==============================] - 20s 292ms/step - loss: 0.6601 - accuracy: 0.7780
# Epoch 36/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.6107 - accuracy: 0.7953
# Epoch 37/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.6443 - accuracy: 0.7813
# Epoch 38/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.6636 - accuracy: 0.7827
# Epoch 39/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.6487 - accuracy: 0.7697
# Epoch 40/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.6402 - accuracy: 0.7901
# Epoch 41/100
# 68/68 [==============================] - 20s 293ms/step - loss: 0.6237 - accuracy: 0.7920
# Epoch 42/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.6711 - accuracy: 0.7743
# Epoch 43/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.6564 - accuracy: 0.7859
# Epoch 44/100
# 68/68 [==============================] - 20s 293ms/step - loss: 0.6221 - accuracy: 0.7897
# Epoch 45/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.6483 - accuracy: 0.7892
# Epoch 46/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.6025 - accuracy: 0.8046
# Epoch 47/100
# 68/68 [==============================] - 20s 293ms/step - loss: 0.5962 - accuracy: 0.7939
# Epoch 48/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.6820 - accuracy: 0.7846
# Epoch 49/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.6263 - accuracy: 0.7939
# Epoch 50/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.6371 - accuracy: 0.7925
# Epoch 51/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.6859 - accuracy: 0.7832
# Epoch 52/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.6112 - accuracy: 0.8022
# Epoch 53/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.6531 - accuracy: 0.7808
# Epoch 54/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.5931 - accuracy: 0.7985
# Epoch 55/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.6481 - accuracy: 0.7971
# Epoch 56/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.6537 - accuracy: 0.7915
# Epoch 57/100
# 68/68 [==============================] - 20s 292ms/step - loss: 0.6617 - accuracy: 0.7953
# Epoch 58/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.6833 - accuracy: 0.7859
# Epoch 59/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.7521 - accuracy: 0.7715
# Epoch 60/100
# 68/68 [==============================] - 20s 292ms/step - loss: 0.6991 - accuracy: 0.7836
# Epoch 61/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.7038 - accuracy: 0.7743
# Epoch 62/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.6514 - accuracy: 0.7915
# Epoch 63/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.6255 - accuracy: 0.8004
# Epoch 64/100
# 68/68 [==============================] - 20s 291ms/step - loss: 0.6428 - accuracy: 0.7929
# Epoch 65/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.5609 - accuracy: 0.8199
# Epoch 66/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.6412 - accuracy: 0.7915
# Epoch 67/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.7254 - accuracy: 0.7794
# Epoch 68/100
# 68/68 [==============================] - 20s 300ms/step - loss: 0.6893 - accuracy: 0.7948
# Epoch 69/100
# 68/68 [==============================] - 20s 293ms/step - loss: 0.7278 - accuracy: 0.7883
# Epoch 70/100
# 68/68 [==============================] - 20s 293ms/step - loss: 0.6432 - accuracy: 0.8097
# Epoch 71/100
# 68/68 [==============================] - 20s 292ms/step - loss: 0.7070 - accuracy: 0.7818
# Epoch 72/100
# 68/68 [==============================] - 20s 292ms/step - loss: 0.6808 - accuracy: 0.7939
# Epoch 73/100
# 68/68 [==============================] - 20s 292ms/step - loss: 0.7289 - accuracy: 0.7813
# Epoch 74/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.7926 - accuracy: 0.7706
# Epoch 75/100
# 68/68 [==============================] - 20s 292ms/step - loss: 0.7040 - accuracy: 0.7994
# Epoch 76/100
# 68/68 [==============================] - 20s 293ms/step - loss: 0.8019 - accuracy: 0.7762
# Epoch 77/100
# 68/68 [==============================] - 20s 293ms/step - loss: 0.6564 - accuracy: 0.8050
# Epoch 78/100
# 68/68 [==============================] - 20s 293ms/step - loss: 0.6145 - accuracy: 0.8036
# Epoch 79/100
# 68/68 [==============================] - 20s 293ms/step - loss: 0.6467 - accuracy: 0.8046
# Epoch 80/100
# 68/68 [==============================] - 20s 291ms/step - loss: 0.6603 - accuracy: 0.7794
# Epoch 81/100
# 68/68 [==============================] - 20s 292ms/step - loss: 0.6336 - accuracy: 0.8008
# Epoch 82/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.6229 - accuracy: 0.8087
# Epoch 83/100
# 68/68 [==============================] - 20s 293ms/step - loss: 0.7454 - accuracy: 0.7762
# Epoch 84/100
# 68/68 [==============================] - 20s 292ms/step - loss: 0.6512 - accuracy: 0.8078
# Epoch 85/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.6207 - accuracy: 0.8087
# Epoch 86/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.6053 - accuracy: 0.8050
# Epoch 87/100
# 68/68 [==============================] - 20s 293ms/step - loss: 0.7057 - accuracy: 0.7887
# Epoch 88/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.6186 - accuracy: 0.8055
# Epoch 89/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.6944 - accuracy: 0.7836
# Epoch 90/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.6129 - accuracy: 0.8115
# Epoch 91/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.7260 - accuracy: 0.7836
# Epoch 92/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.6903 - accuracy: 0.7980
# Epoch 93/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.6444 - accuracy: 0.8055
# Epoch 94/100
# 68/68 [==============================] - 20s 293ms/step - loss: 0.6780 - accuracy: 0.7925
# Epoch 95/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.6605 - accuracy: 0.7962
# Epoch 96/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.6131 - accuracy: 0.8125
# Epoch 97/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.6978 - accuracy: 0.8013
# Epoch 98/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.6651 - accuracy: 0.8046
# Epoch 99/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.6349 - accuracy: 0.8004
# Epoch 100/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.6176 - accuracy: 0.8115
# Score for fold 1: loss of 0.4973698556423187; accuracy of 84.74418520927429%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Epoch 1/100
# 68/68 [==============================] - 21s 301ms/step - loss: 0.9171 - accuracy: 0.6096
# Epoch 2/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.6699 - accuracy: 0.6826
# Epoch 3/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.6487 - accuracy: 0.6994
# Epoch 4/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.6313 - accuracy: 0.7306
# Epoch 5/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.6246 - accuracy: 0.7217
# Epoch 6/100
# 68/68 [==============================] - 21s 301ms/step - loss: 0.6044 - accuracy: 0.7478
# Epoch 7/100
# 68/68 [==============================] - 21s 302ms/step - loss: 0.6364 - accuracy: 0.7562
# Epoch 8/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.6676 - accuracy: 0.7362
# Epoch 9/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.6208 - accuracy: 0.7497
# Epoch 10/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.6235 - accuracy: 0.7636
# Epoch 11/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.6395 - accuracy: 0.7562
# Epoch 12/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.6571 - accuracy: 0.7576
# Epoch 13/100
# 68/68 [==============================] - 20s 300ms/step - loss: 0.7470 - accuracy: 0.7408
# Epoch 14/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.6350 - accuracy: 0.7590
# Epoch 15/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.6366 - accuracy: 0.7692
# Epoch 16/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.5924 - accuracy: 0.7734
# Epoch 17/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.5640 - accuracy: 0.7794
# Epoch 18/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.6243 - accuracy: 0.7608
# Epoch 19/100
# 68/68 [==============================] - 21s 301ms/step - loss: 0.5661 - accuracy: 0.7743
# Epoch 20/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.5825 - accuracy: 0.7738
# Epoch 21/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.6257 - accuracy: 0.7617
# Epoch 22/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.6377 - accuracy: 0.7548
# Epoch 23/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.5795 - accuracy: 0.7906
# Epoch 24/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.6137 - accuracy: 0.7752
# Epoch 25/100
# 68/68 [==============================] - 20s 300ms/step - loss: 0.6024 - accuracy: 0.7757
# Epoch 26/100
# 68/68 [==============================] - 20s 300ms/step - loss: 0.5687 - accuracy: 0.7832
# Epoch 27/100
# 68/68 [==============================] - 20s 300ms/step - loss: 0.6718 - accuracy: 0.7520
# Epoch 28/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.6417 - accuracy: 0.7738
# Epoch 29/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.6132 - accuracy: 0.7822
# Epoch 30/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.6501 - accuracy: 0.7869
# Epoch 31/100
# 68/68 [==============================] - 20s 301ms/step - loss: 0.6364 - accuracy: 0.7808
# Epoch 32/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.6933 - accuracy: 0.7720
# Epoch 33/100
# 68/68 [==============================] - 21s 303ms/step - loss: 0.7910 - accuracy: 0.7543
# Epoch 34/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.6919 - accuracy: 0.7729
# Epoch 35/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.6137 - accuracy: 0.7827
# Epoch 36/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.6209 - accuracy: 0.7818
# Epoch 37/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.6718 - accuracy: 0.7673
# Epoch 38/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.7644 - accuracy: 0.7515
# Epoch 39/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.7076 - accuracy: 0.7757
# Epoch 40/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.7384 - accuracy: 0.7622
# Epoch 41/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.6815 - accuracy: 0.7780
# Epoch 42/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.6395 - accuracy: 0.7980
# Epoch 43/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.5965 - accuracy: 0.8018
# Epoch 44/100
# 68/68 [==============================] - 20s 293ms/step - loss: 0.5957 - accuracy: 0.7920
# Epoch 45/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.6098 - accuracy: 0.7873
# Epoch 46/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.6547 - accuracy: 0.7669
# Epoch 47/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.6253 - accuracy: 0.7850
# Epoch 48/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.7345 - accuracy: 0.7594
# Epoch 49/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.6899 - accuracy: 0.7794
# Epoch 50/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.6146 - accuracy: 0.7990
# Epoch 51/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.6382 - accuracy: 0.7929
# Epoch 52/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.6692 - accuracy: 0.7785
# Epoch 53/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.6898 - accuracy: 0.7794
# Epoch 54/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.5867 - accuracy: 0.8069
# Epoch 55/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.6787 - accuracy: 0.7864
# Epoch 56/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.6526 - accuracy: 0.7892
# Epoch 57/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.6339 - accuracy: 0.7859
# Epoch 58/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.7767 - accuracy: 0.7669
# Epoch 59/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.7179 - accuracy: 0.7715
# Epoch 60/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.6842 - accuracy: 0.7911
# Epoch 61/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.7601 - accuracy: 0.7715
# Epoch 62/100
# 68/68 [==============================] - 20s 300ms/step - loss: 0.6839 - accuracy: 0.7915
# Epoch 63/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.6131 - accuracy: 0.7980
# Epoch 64/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.6461 - accuracy: 0.7920
# Epoch 65/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.6817 - accuracy: 0.7836
# Epoch 66/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.6703 - accuracy: 0.7920
# Epoch 67/100
# 68/68 [==============================] - 20s 293ms/step - loss: 0.5945 - accuracy: 0.8013
# Epoch 68/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.6561 - accuracy: 0.7906
# Epoch 69/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.6774 - accuracy: 0.7892
# Epoch 70/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.6784 - accuracy: 0.7929
# Epoch 71/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.7490 - accuracy: 0.7804
# Epoch 72/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.6789 - accuracy: 0.7873
# Epoch 73/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.6752 - accuracy: 0.7948
# Epoch 74/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.6768 - accuracy: 0.7901
# Epoch 75/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.7260 - accuracy: 0.7808
# Epoch 76/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.6177 - accuracy: 0.7985
# Epoch 77/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.6874 - accuracy: 0.7883
# Epoch 78/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.7671 - accuracy: 0.7785
# Epoch 79/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.6855 - accuracy: 0.7939
# Epoch 80/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.7378 - accuracy: 0.7636
# Epoch 81/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.6967 - accuracy: 0.7846
# Epoch 82/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.6540 - accuracy: 0.7850
# Epoch 83/100
# 68/68 [==============================] - 20s 293ms/step - loss: 0.6633 - accuracy: 0.7915
# Epoch 84/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.7117 - accuracy: 0.7869
# Epoch 85/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.6615 - accuracy: 0.7957
# Epoch 86/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.6388 - accuracy: 0.7985
# Epoch 87/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.6201 - accuracy: 0.8004
# Epoch 88/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.6531 - accuracy: 0.8083
# Epoch 89/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.6516 - accuracy: 0.7953
# Epoch 90/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.7932 - accuracy: 0.7771
# Epoch 91/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.7428 - accuracy: 0.7887
# Epoch 92/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.7204 - accuracy: 0.7804
# Epoch 93/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.6615 - accuracy: 0.8022
# Epoch 94/100
# 68/68 [==============================] - 20s 300ms/step - loss: 0.6510 - accuracy: 0.8083
# Epoch 95/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.6668 - accuracy: 0.7925
# Epoch 96/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.6745 - accuracy: 0.7966
# Epoch 97/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.8754 - accuracy: 0.7627
# Epoch 98/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.8219 - accuracy: 0.7822
# Epoch 99/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.6393 - accuracy: 0.8046
# Epoch 100/100
# 68/68 [==============================] - 20s 301ms/step - loss: 0.6612 - accuracy: 0.8064
# Score for fold 2: loss of 0.48268941044807434; accuracy of 83.90697836875916%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Epoch 1/100
# 68/68 [==============================] - 21s 305ms/step - loss: 0.9798 - accuracy: 0.5963
# Epoch 2/100
# 68/68 [==============================] - 20s 300ms/step - loss: 0.6084 - accuracy: 0.7126
# Epoch 3/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.5961 - accuracy: 0.7307
# Epoch 4/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.6719 - accuracy: 0.7149
# Epoch 5/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.7600 - accuracy: 0.7019
# Epoch 6/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.6192 - accuracy: 0.7386
# Epoch 7/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.5601 - accuracy: 0.7619
# Epoch 8/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.6693 - accuracy: 0.7479
# Epoch 9/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.6166 - accuracy: 0.7540
# Epoch 10/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.6095 - accuracy: 0.7642
# Epoch 11/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.6638 - accuracy: 0.7530
# Epoch 12/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.5941 - accuracy: 0.7642
# Epoch 13/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.6149 - accuracy: 0.7758
# Epoch 14/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.6141 - accuracy: 0.7674
# Epoch 15/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.5876 - accuracy: 0.7800
# Epoch 16/100
# 68/68 [==============================] - 20s 300ms/step - loss: 0.6079 - accuracy: 0.7767
# Epoch 17/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.5519 - accuracy: 0.7893
# Epoch 18/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.5570 - accuracy: 0.7851
# Epoch 19/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.6220 - accuracy: 0.7767
# Epoch 20/100
# 68/68 [==============================] - 20s 300ms/step - loss: 0.5813 - accuracy: 0.7767
# Epoch 21/100
# 68/68 [==============================] - 20s 300ms/step - loss: 0.5530 - accuracy: 0.7856
# Epoch 22/100
# 68/68 [==============================] - 20s 301ms/step - loss: 0.5871 - accuracy: 0.7721
# Epoch 23/100
# 68/68 [==============================] - 21s 301ms/step - loss: 0.5394 - accuracy: 0.7851
# Epoch 24/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.5367 - accuracy: 0.7972
# Epoch 25/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.5683 - accuracy: 0.7893
# Epoch 26/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.5780 - accuracy: 0.7898
# Epoch 27/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.5785 - accuracy: 0.7963
# Epoch 28/100
# 68/68 [==============================] - 21s 301ms/step - loss: 0.6343 - accuracy: 0.7712
# Epoch 29/100
# 68/68 [==============================] - 20s 300ms/step - loss: 0.5812 - accuracy: 0.7898
# Epoch 30/100
# 68/68 [==============================] - 21s 302ms/step - loss: 0.6168 - accuracy: 0.7823
# Epoch 31/100
# 68/68 [==============================] - 21s 302ms/step - loss: 0.6729 - accuracy: 0.7670
# Epoch 32/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.5235 - accuracy: 0.8037
# Epoch 33/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.5983 - accuracy: 0.7856
# Epoch 34/100
# 68/68 [==============================] - 21s 301ms/step - loss: 0.6276 - accuracy: 0.7865
# Epoch 35/100
# 68/68 [==============================] - 20s 300ms/step - loss: 0.6996 - accuracy: 0.7702
# Epoch 36/100
# 68/68 [==============================] - 21s 302ms/step - loss: 0.6653 - accuracy: 0.7753
# Epoch 37/100
# 68/68 [==============================] - 21s 301ms/step - loss: 0.7934 - accuracy: 0.7474
# Epoch 38/100
# 68/68 [==============================] - 21s 303ms/step - loss: 0.6527 - accuracy: 0.7935
# Epoch 39/100
# 68/68 [==============================] - 21s 303ms/step - loss: 0.6588 - accuracy: 0.7851
# Epoch 40/100
# 68/68 [==============================] - 21s 302ms/step - loss: 0.7280 - accuracy: 0.7688
# Epoch 41/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.6196 - accuracy: 0.8023
# Epoch 42/100
# 68/68 [==============================] - 21s 302ms/step - loss: 0.6352 - accuracy: 0.7888
# Epoch 43/100
# 68/68 [==============================] - 21s 301ms/step - loss: 0.6033 - accuracy: 0.8000
# Epoch 44/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.5475 - accuracy: 0.8098
# Epoch 45/100
# 68/68 [==============================] - 21s 302ms/step - loss: 0.6225 - accuracy: 0.8014
# Epoch 46/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.5406 - accuracy: 0.8084
# Epoch 47/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.6583 - accuracy: 0.7893
# Epoch 48/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.5631 - accuracy: 0.8033
# Epoch 49/100
# 68/68 [==============================] - 20s 299ms/step - loss: 0.6078 - accuracy: 0.7916
# Epoch 50/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.6397 - accuracy: 0.7893
# Epoch 51/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.5361 - accuracy: 0.8135
# Epoch 52/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.5694 - accuracy: 0.8056
# Epoch 53/100
# 68/68 [==============================] - 21s 301ms/step - loss: 0.6330 - accuracy: 0.7791
# Epoch 54/100
# 68/68 [==============================] - 20s 300ms/step - loss: 0.5853 - accuracy: 0.8005
# Epoch 55/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.6259 - accuracy: 0.8000
# Epoch 56/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.6300 - accuracy: 0.7879
# Epoch 57/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.6159 - accuracy: 0.7986
# Epoch 58/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.7188 - accuracy: 0.7749
# Epoch 59/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.6258 - accuracy: 0.7879
# Epoch 60/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.6875 - accuracy: 0.7912
# Epoch 61/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.6964 - accuracy: 0.7916
# Epoch 62/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.5905 - accuracy: 0.8070
# Epoch 63/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.5945 - accuracy: 0.8130
# Epoch 64/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.6028 - accuracy: 0.8102
# Epoch 65/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.6400 - accuracy: 0.7991
# Epoch 66/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.6424 - accuracy: 0.7981
# Epoch 67/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.6015 - accuracy: 0.8014
# Epoch 68/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.6014 - accuracy: 0.8112
# Epoch 69/100
# 68/68 [==============================] - 20s 293ms/step - loss: 0.7194 - accuracy: 0.7777
# Epoch 70/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.6119 - accuracy: 0.8153
# Epoch 71/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.6616 - accuracy: 0.7963
# Epoch 72/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.6102 - accuracy: 0.8033
# Epoch 73/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.7135 - accuracy: 0.7912
# Epoch 74/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.6433 - accuracy: 0.8037
# Epoch 75/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.5972 - accuracy: 0.8074
# Epoch 76/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.6424 - accuracy: 0.8051
# Epoch 77/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.6135 - accuracy: 0.8079
# Epoch 78/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.6099 - accuracy: 0.8191
# Epoch 79/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.6505 - accuracy: 0.8009
# Epoch 80/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.5916 - accuracy: 0.8135
# Epoch 81/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.6102 - accuracy: 0.8079
# Epoch 82/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.5954 - accuracy: 0.8223
# Epoch 83/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.6244 - accuracy: 0.8149
# Epoch 84/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.7262 - accuracy: 0.7888
# Epoch 85/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.6436 - accuracy: 0.8037
# Epoch 86/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.7026 - accuracy: 0.7828
# Epoch 87/100
# 68/68 [==============================] - 20s 301ms/step - loss: 0.6928 - accuracy: 0.8126
# Epoch 88/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.7114 - accuracy: 0.7963
# Epoch 89/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.6466 - accuracy: 0.8116
# Epoch 90/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.6537 - accuracy: 0.8084
# Epoch 91/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.6475 - accuracy: 0.8000
# Epoch 92/100
# 68/68 [==============================] - 20s 293ms/step - loss: 0.6289 - accuracy: 0.8019
# Epoch 93/100
# 68/68 [==============================] - 20s 298ms/step - loss: 0.6633 - accuracy: 0.8051
# Epoch 94/100
# 68/68 [==============================] - 20s 300ms/step - loss: 0.6386 - accuracy: 0.7977
# Epoch 95/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.6071 - accuracy: 0.8065
# Epoch 96/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.6488 - accuracy: 0.8051
# Epoch 97/100
# 68/68 [==============================] - 20s 296ms/step - loss: 0.5990 - accuracy: 0.8205
# Epoch 98/100
# 68/68 [==============================] - 20s 294ms/step - loss: 0.6885 - accuracy: 0.7884
# Epoch 99/100
# 68/68 [==============================] - 20s 297ms/step - loss: 0.6545 - accuracy: 0.8126
# Epoch 100/100
# 68/68 [==============================] - 20s 295ms/step - loss: 0.6515 - accuracy: 0.7986
# Score for fold 3: loss of 0.6033589839935303; accuracy of 81.93668723106384%
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 0.4973698556423187 - Accuracy: 84.74418520927429%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 0.48268941044807434 - Accuracy: 83.90697836875916%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 0.6033589839935303 - Accuracy: 81.93668723106384%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 83.52928360303243 (+- 1.1768605769750196)
# > Loss: 0.5278060833613077
# ------------------------------------------------------------------------

# %%
import pandas as pd
metrics = pd.DataFrame(acc_per_fold)
metrics = metrics.rename(columns={0:'accuracy'})
loss_df = pd.DataFrame(loss_per_fold)

# %%
metrics.head()
# Out:
#     accuracy
# 0  84.744185
# 1  83.906978
# 2  81.936687

# %%
metrics_df = metrics.join(loss_df.rename(columns={0:'loss'}))

# %%
metrics_df.head()
# Out:
#     accuracy      loss
# 0  84.744185  0.497370
# 1  83.906978  0.482689
# 2  81.936687  0.603359

# %%
report_csv_file = '/content/drive/MyDrive/Colab Notebooks/CTCov/Fold/VGG19/vgg_clahe_class_report.csv'
with open(report_csv_file, mode='w') as f:
    metrics_df.to_csv(f)
