# %% [markdown]
# Covid 19 CT scan Image classification with VGG19 pretrained model.
#
# Datasets: 2 public datasets stored in the folders CT_DATA (CT_COVID and CT_NonCovid) and SARS-COV-2-DATA.
# https://www.kaggle.com/plameneduardo/sarscov2-ctscan-dataset
#
# https://github.com/UCSD-AI4H/COVID-CT
#
# DATA-Split folder : initially used to split data from CT-DATA, but will not be used here in the final.

# %%
from builtins import range, input

from tensorflow.keras.layers import Input, Lambda, Dense, Flatten, AveragePooling2D, Dropout
from tensorflow.keras.models import Model, load_model
from tensorflow.keras.applications.resnet50 import ResNet50
from tensorflow.keras.applications.resnet50 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from sklearn.metrics import confusion_matrix, roc_curve
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

import os
import cv2
from glob import glob

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelBinarizer
from tensorflow.keras.utils import to_categorical

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %%
cov_path = "/content/drive/MyDrive/Colab Notebooks/CTCov/CT_Data/CT_COVID/"
norm_path = "/content/drive/MyDrive/Colab Notebooks/CTCov/CT_Data/CT_NonCOVID/"

# %%
IMAGE_SIZE=[224,224]
epochs = 300
batch_size=32
#define paths
covid_path = '/content/drive/MyDrive/Colab Notebooks/CTCov/SARS-COV-2-Data/COVID'
noncovid_path = '/content/drive/MyDrive/Colab Notebooks/CTCov/SARS-COV-2-Data/NON-COVID'

# Use glob to grab images from path .jpg or jpeg
cov_files = glob(cov_path + '/*')
norm_files = glob(norm_path + '/*')

covid_files = glob(covid_path + '/*')
noncovid_files = glob(noncovid_path + '/*')

# %%
# Fetch Images and Class Labels from Files
cov_labels = []
norm_labels = []

cov_images=[]
norm_images=[]

for i in range(len(cov_files)):
  image = cv2.imread(cov_files[i]) # read file 
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # arrange format as per keras
  image = cv2.resize(image,(224,224)) # resize as per model
  cov_images.append(image) # append image
  cov_labels.append('CT_COVID') #append class label
  
for i in range(len(norm_files)):
  image = cv2.imread(norm_files[i])
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
  image = cv2.resize(image,(224,224))
  norm_images.append(image)
  norm_labels.append('CT_NonCOVID')

# %%
# Fetch Images and Class Labels from Files
covid_labels = []
noncovid_labels = []

covid_images=[]
noncovid_images=[]

for i in range(len(covid_files)):
  image = cv2.imread(covid_files[i]) # read file 
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB) # arrange format as per keras
  image = cv2.resize(image,(224,224)) # resize as per model
  covid_images.append(image) # append image
  covid_labels.append('CT_COVID') #append class label
  
for i in range(len(noncovid_files)):
  image = cv2.imread(noncovid_files[i])
  image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
  image = cv2.resize(image,(224,224))
  noncovid_images.append(image)
  noncovid_labels.append('CT_NonCOVID')

# %%
covid_images = np.concatenate((covid_images, cov_images), axis=0)
noncovid_images = np.concatenate((noncovid_images, norm_images),axis=0)

# %%
covid_labels = np.concatenate((covid_labels, cov_labels), axis=0)
noncovid_labels = np.concatenate((noncovid_labels, norm_labels),axis=0)

# %% [markdown]
# #Median Blur

# %%
covid_images = [cv2.medianBlur(img, 5) for img in covid_images]

# %%
noncovid_images = [cv2.medianBlur(img, 5) for img in noncovid_images]

# %% [markdown]
# Normalize

# %%
covid_images = np.array(covid_images)/255
noncovid_images = np.array(noncovid_images)/255

# %%
# Split into training and testing sets for both types of images
covid_x_train, covid_x_test, covid_y_train, covid_y_test = train_test_split(
    covid_images, covid_labels, test_size=0.2)
noncovid_x_train, noncovid_x_test, noncovid_y_train, noncovid_y_test = train_test_split(
    noncovid_images, noncovid_labels, test_size=0.2)

# Merge sets for both types of images
X_train = np.concatenate((noncovid_x_train, covid_x_train), axis=0)
X_test = np.concatenate((noncovid_x_test, covid_x_test), axis=0)
y_train = np.concatenate((noncovid_y_train, covid_y_train), axis=0)
y_test = np.concatenate((noncovid_y_test, covid_y_test), axis=0)

# Make labels into categories - either 0 or 1, for our model
y_train = LabelBinarizer().fit_transform(y_train)
y_train = to_categorical(y_train)

y_test = LabelBinarizer().fit_transform(y_test)
y_test = to_categorical(y_test)

# %% [markdown]
# # DenseNet model

# %%
from tensorflow.keras.applications import DenseNet121

from sklearn.model_selection import KFold

kfold = KFold(n_splits=3, shuffle=True)
inputs = np.concatenate((X_train, X_test), axis=0)
targets = np.concatenate((y_train, y_test), axis=0)

# Building Model
acc_per_fold = []
loss_per_fold = []
fold_no = 1

densenet = DenseNet121(weights="imagenet", include_top=False,
  input_tensor=Input(shape=(224, 224, 3)))

for layer in densenet.layers:
      layer.trainable = False

train_aug = ImageDataGenerator(
      rotation_range=20,
      width_shift_range=0.2,
      height_shift_range=0.2,
      horizontal_flip=True
  )

for train, test in kfold.split(inputs, targets):

  outputs = densenet.output
  outputs = Flatten(name="flatten")(outputs)
  outputs = Dropout(0.5)(outputs)
  outputs = Dense(2, activation="softmax")(outputs)

  model = Model(inputs=densenet.input, outputs=outputs)


  model.compile(
          loss='categorical_crossentropy', 
          optimizer='adam', 
          metrics=['accuracy']
  )

  

  # Generate a print
  print('------------------------------------------------------------------------')
  print(f'Training for fold {fold_no} ...')
  model.fit(train_aug.flow(inputs[train], targets[train], batch_size=batch_size),
                    verbose=1,
                    epochs=100)
  
  # Generate generalization metrics
  scores = model.evaluate(inputs[test], targets[test], verbose=0)
  print(f'Score for fold {fold_no}: {model.metrics_names[0]} of {scores[0]}; {model.metrics_names[1]} of {scores[1]*100}%')
  acc_per_fold.append(scores[1] * 100)
  loss_per_fold.append(scores[0])

  # Increase fold number
  fold_no = fold_no + 1

# == Provide average scores ==
print('------------------------------------------------------------------------')
print('Score per fold')
for i in range(0, len(acc_per_fold)):
  print('------------------------------------------------------------------------')
  print(f'> Fold {i+1} - Loss: {loss_per_fold[i]} - Accuracy: {acc_per_fold[i]}%')
print('------------------------------------------------------------------------')
print('Average scores for all folds:')
print(f'> Accuracy: {np.mean(acc_per_fold)} (+- {np.std(acc_per_fold)})')
print(f'> Loss: {np.mean(loss_per_fold)}')
print('------------------------------------------------------------------------')
# Out:
# ------------------------------------------------------------------------
# Training for fold 1 ...
# Epoch 1/100
# 68/68 [==============================] - 26s 283ms/step - loss: 2.4742 - accuracy: 0.6217
# Epoch 2/100
# 68/68 [==============================] - 20s 287ms/step - loss: 1.7516 - accuracy: 0.7027
# Epoch 3/100
# 68/68 [==============================] - 19s 290ms/step - loss: 1.6575 - accuracy: 0.7171
# Epoch 4/100
# 68/68 [==============================] - 20s 286ms/step - loss: 1.5156 - accuracy: 0.7427
# Epoch 5/100
# 68/68 [==============================] - 20s 289ms/step - loss: 1.7177 - accuracy: 0.7217
# Epoch 6/100
# 68/68 [==============================] - 19s 286ms/step - loss: 1.8378 - accuracy: 0.7408
# Epoch 7/100
# 68/68 [==============================] - 20s 287ms/step - loss: 1.6987 - accuracy: 0.7483
# Epoch 8/100
# 68/68 [==============================] - 20s 287ms/step - loss: 1.7858 - accuracy: 0.7487
# Epoch 9/100
# 68/68 [==============================] - 20s 287ms/step - loss: 1.5934 - accuracy: 0.7678
# Epoch 10/100
# 68/68 [==============================] - 20s 294ms/step - loss: 1.9415 - accuracy: 0.7515
# Epoch 11/100
# 68/68 [==============================] - 20s 295ms/step - loss: 2.1195 - accuracy: 0.7515
# Epoch 12/100
# 68/68 [==============================] - 20s 294ms/step - loss: 2.2285 - accuracy: 0.7669
# Epoch 13/100
# 68/68 [==============================] - 20s 296ms/step - loss: 1.9695 - accuracy: 0.7543
# Epoch 14/100
# 68/68 [==============================] - 20s 294ms/step - loss: 2.1903 - accuracy: 0.7548
# Epoch 15/100
# 68/68 [==============================] - 20s 291ms/step - loss: 2.1172 - accuracy: 0.7673
# Epoch 16/100
# 68/68 [==============================] - 20s 288ms/step - loss: 2.2897 - accuracy: 0.7617
# Epoch 17/100
# 68/68 [==============================] - 20s 289ms/step - loss: 2.2020 - accuracy: 0.7664
# Epoch 18/100
# 68/68 [==============================] - 20s 289ms/step - loss: 2.1301 - accuracy: 0.7725
# Epoch 19/100
# 68/68 [==============================] - 20s 288ms/step - loss: 2.2592 - accuracy: 0.7841
# Epoch 20/100
# 68/68 [==============================] - 20s 289ms/step - loss: 2.2480 - accuracy: 0.7752
# Epoch 21/100
# 68/68 [==============================] - 20s 287ms/step - loss: 2.4594 - accuracy: 0.7771
# Epoch 22/100
# 68/68 [==============================] - 20s 288ms/step - loss: 2.2338 - accuracy: 0.7804
# Epoch 23/100
# 68/68 [==============================] - 20s 286ms/step - loss: 2.3124 - accuracy: 0.7808
# Epoch 24/100
# 68/68 [==============================] - 20s 287ms/step - loss: 2.4682 - accuracy: 0.7683
# Epoch 25/100
# 68/68 [==============================] - 20s 288ms/step - loss: 2.3358 - accuracy: 0.7934
# Epoch 26/100
# 68/68 [==============================] - 20s 289ms/step - loss: 2.5251 - accuracy: 0.7641
# Epoch 27/100
# 68/68 [==============================] - 20s 287ms/step - loss: 2.2641 - accuracy: 0.7892
# Epoch 28/100
# 68/68 [==============================] - 20s 289ms/step - loss: 2.5119 - accuracy: 0.7818
# Epoch 29/100
# 68/68 [==============================] - 20s 290ms/step - loss: 2.1547 - accuracy: 0.8036
# Epoch 30/100
# 68/68 [==============================] - 20s 289ms/step - loss: 2.3598 - accuracy: 0.7878
# Epoch 31/100
# 68/68 [==============================] - 20s 286ms/step - loss: 3.2378 - accuracy: 0.7469
# Epoch 32/100
# 68/68 [==============================] - 20s 288ms/step - loss: 2.3426 - accuracy: 0.7915
# Epoch 33/100
# 68/68 [==============================] - 20s 288ms/step - loss: 2.7392 - accuracy: 0.7794
# Epoch 34/100
# 68/68 [==============================] - 20s 290ms/step - loss: 2.4007 - accuracy: 0.7887
# Epoch 35/100
# 68/68 [==============================] - 20s 288ms/step - loss: 2.4850 - accuracy: 0.7892
# Epoch 36/100
# 68/68 [==============================] - 20s 286ms/step - loss: 2.7819 - accuracy: 0.7692
# Epoch 37/100
# 68/68 [==============================] - 20s 289ms/step - loss: 2.3291 - accuracy: 0.7971
# Epoch 38/100
# 68/68 [==============================] - 20s 289ms/step - loss: 2.5465 - accuracy: 0.7841
# Epoch 39/100
# 68/68 [==============================] - 20s 287ms/step - loss: 2.3330 - accuracy: 0.8013
# Epoch 40/100
# 68/68 [==============================] - 20s 288ms/step - loss: 2.7737 - accuracy: 0.7785
# Epoch 41/100
# 68/68 [==============================] - 20s 289ms/step - loss: 2.5806 - accuracy: 0.7887
# Epoch 42/100
# 68/68 [==============================] - 20s 288ms/step - loss: 2.8895 - accuracy: 0.7776
# Epoch 43/100
# 68/68 [==============================] - 20s 289ms/step - loss: 2.6132 - accuracy: 0.7911
# Epoch 44/100
# 68/68 [==============================] - 20s 287ms/step - loss: 2.2677 - accuracy: 0.7934
# Epoch 45/100
# 68/68 [==============================] - 20s 288ms/step - loss: 2.3687 - accuracy: 0.7925
# Epoch 46/100
# 68/68 [==============================] - 20s 290ms/step - loss: 3.2826 - accuracy: 0.7645
# Epoch 47/100
# 68/68 [==============================] - 20s 289ms/step - loss: 2.6247 - accuracy: 0.7953
# Epoch 48/100
# 68/68 [==============================] - 20s 287ms/step - loss: 2.7883 - accuracy: 0.7953
# Epoch 49/100
# 68/68 [==============================] - 20s 287ms/step - loss: 3.1903 - accuracy: 0.7706
# Epoch 50/100
# 68/68 [==============================] - 20s 289ms/step - loss: 2.6264 - accuracy: 0.8013
# Epoch 51/100
# 68/68 [==============================] - 20s 287ms/step - loss: 2.7479 - accuracy: 0.7906
# Epoch 52/100
# 68/68 [==============================] - 20s 287ms/step - loss: 2.7564 - accuracy: 0.7925
# Epoch 53/100
# 68/68 [==============================] - 20s 289ms/step - loss: 2.7162 - accuracy: 0.7832
# Epoch 54/100
# 68/68 [==============================] - 20s 288ms/step - loss: 2.5993 - accuracy: 0.8036
# Epoch 55/100
# 68/68 [==============================] - 20s 287ms/step - loss: 3.2584 - accuracy: 0.7683
# Epoch 56/100
# 68/68 [==============================] - 20s 289ms/step - loss: 2.4465 - accuracy: 0.8129
# Epoch 57/100
# 68/68 [==============================] - 20s 289ms/step - loss: 2.8990 - accuracy: 0.7906
# Epoch 58/100
# 68/68 [==============================] - 20s 290ms/step - loss: 2.9621 - accuracy: 0.7790
# Epoch 59/100
# 68/68 [==============================] - 20s 292ms/step - loss: 2.5630 - accuracy: 0.8074
# Epoch 60/100
# 68/68 [==============================] - 20s 301ms/step - loss: 2.9556 - accuracy: 0.7934
# Epoch 61/100
# 68/68 [==============================] - 20s 295ms/step - loss: 2.7774 - accuracy: 0.7962
# Epoch 62/100
# 68/68 [==============================] - 20s 289ms/step - loss: 2.7909 - accuracy: 0.7906
# Epoch 63/100
# 68/68 [==============================] - 20s 288ms/step - loss: 2.6627 - accuracy: 0.8022
# Epoch 64/100
# 68/68 [==============================] - 20s 287ms/step - loss: 2.3512 - accuracy: 0.8087
# Epoch 65/100
# 68/68 [==============================] - 20s 287ms/step - loss: 2.8660 - accuracy: 0.7906
# Epoch 66/100
# 68/68 [==============================] - 19s 286ms/step - loss: 2.4814 - accuracy: 0.7985
# Epoch 67/100
# 68/68 [==============================] - 20s 288ms/step - loss: 2.7535 - accuracy: 0.8036
# Epoch 68/100
# 68/68 [==============================] - 20s 286ms/step - loss: 2.4571 - accuracy: 0.8153
# Epoch 69/100
# 68/68 [==============================] - 20s 288ms/step - loss: 2.8290 - accuracy: 0.7999
# Epoch 70/100
# 68/68 [==============================] - 20s 289ms/step - loss: 2.4368 - accuracy: 0.8115
# Epoch 71/100
# 68/68 [==============================] - 20s 288ms/step - loss: 2.8137 - accuracy: 0.7990
# Epoch 72/100
# 68/68 [==============================] - 20s 289ms/step - loss: 3.0120 - accuracy: 0.7925
# Epoch 73/100
# 68/68 [==============================] - 20s 287ms/step - loss: 2.9541 - accuracy: 0.7925
# Epoch 74/100
# 68/68 [==============================] - 20s 288ms/step - loss: 2.7156 - accuracy: 0.8115
# Epoch 75/100
# 68/68 [==============================] - 20s 288ms/step - loss: 2.8794 - accuracy: 0.7980
# Epoch 76/100
# 68/68 [==============================] - 20s 289ms/step - loss: 2.8203 - accuracy: 0.8041
# Epoch 77/100
# 68/68 [==============================] - 20s 287ms/step - loss: 3.0322 - accuracy: 0.7943
# Epoch 78/100
# 68/68 [==============================] - 20s 287ms/step - loss: 2.9333 - accuracy: 0.8036
# Epoch 79/100
# 68/68 [==============================] - 20s 289ms/step - loss: 2.6575 - accuracy: 0.8111
# Epoch 80/100
# 68/68 [==============================] - 20s 287ms/step - loss: 2.9211 - accuracy: 0.7990
# Epoch 81/100
# 68/68 [==============================] - 20s 288ms/step - loss: 2.9909 - accuracy: 0.7985
# Epoch 82/100
# 68/68 [==============================] - 20s 287ms/step - loss: 3.1170 - accuracy: 0.7878
# Epoch 83/100
# 68/68 [==============================] - 20s 289ms/step - loss: 3.7357 - accuracy: 0.7762
# Epoch 84/100
# 68/68 [==============================] - 20s 286ms/step - loss: 2.6475 - accuracy: 0.8097
# Epoch 85/100
# 68/68 [==============================] - 20s 287ms/step - loss: 3.1200 - accuracy: 0.7887
# Epoch 86/100
# 68/68 [==============================] - 20s 288ms/step - loss: 2.9468 - accuracy: 0.8074
# Epoch 87/100
# 68/68 [==============================] - 20s 287ms/step - loss: 2.6332 - accuracy: 0.8153
# Epoch 88/100
# 68/68 [==============================] - 19s 286ms/step - loss: 2.9876 - accuracy: 0.7971
# Epoch 89/100
# 68/68 [==============================] - 20s 286ms/step - loss: 2.8429 - accuracy: 0.8064
# Epoch 90/100
# 68/68 [==============================] - 20s 287ms/step - loss: 3.1892 - accuracy: 0.8041
# Epoch 91/100
# 68/68 [==============================] - 20s 289ms/step - loss: 3.2255 - accuracy: 0.8004
# Epoch 92/100
# 68/68 [==============================] - 20s 289ms/step - loss: 2.7744 - accuracy: 0.8008
# Epoch 93/100
# 68/68 [==============================] - 19s 286ms/step - loss: 3.0535 - accuracy: 0.8018
# Epoch 94/100
# 68/68 [==============================] - 20s 288ms/step - loss: 3.4122 - accuracy: 0.7887
# Epoch 95/100
# 68/68 [==============================] - 20s 289ms/step - loss: 3.2778 - accuracy: 0.7915
# Epoch 96/100
# 68/68 [==============================] - 20s 289ms/step - loss: 2.9766 - accuracy: 0.7920
# Epoch 97/100
# 68/68 [==============================] - 20s 289ms/step - loss: 3.0592 - accuracy: 0.7999
# Epoch 98/100
# 68/68 [==============================] - 20s 288ms/step - loss: 2.9650 - accuracy: 0.8092
# Epoch 99/100
# 68/68 [==============================] - 20s 287ms/step - loss: 3.0416 - accuracy: 0.7980
# Epoch 100/100
# 68/68 [==============================] - 20s 288ms/step - loss: 3.0126 - accuracy: 0.8050
# Score for fold 1: loss of 3.693222999572754; accuracy of 77.11628079414368%
# ------------------------------------------------------------------------
# Training for fold 2 ...
# Epoch 1/100
# 68/68 [==============================] - 25s 293ms/step - loss: 2.7936 - accuracy: 0.6096
# Epoch 2/100
# 68/68 [==============================] - 20s 294ms/step - loss: 1.7385 - accuracy: 0.6668
# Epoch 3/100
# 68/68 [==============================] - 20s 295ms/step - loss: 1.6567 - accuracy: 0.7175
# Epoch 4/100
# 68/68 [==============================] - 20s 292ms/step - loss: 1.5781 - accuracy: 0.7278
# Epoch 5/100
# 68/68 [==============================] - 20s 291ms/step - loss: 1.7509 - accuracy: 0.7324
# Epoch 6/100
# 68/68 [==============================] - 20s 291ms/step - loss: 2.0162 - accuracy: 0.7194
# Epoch 7/100
# 68/68 [==============================] - 20s 294ms/step - loss: 2.2391 - accuracy: 0.7255
# Epoch 8/100
# 68/68 [==============================] - 20s 294ms/step - loss: 1.8017 - accuracy: 0.7455
# Epoch 9/100
# 68/68 [==============================] - 20s 293ms/step - loss: 1.6824 - accuracy: 0.7510
# Epoch 10/100
# 68/68 [==============================] - 20s 293ms/step - loss: 2.1971 - accuracy: 0.7469
# Epoch 11/100
# 68/68 [==============================] - 20s 293ms/step - loss: 2.4964 - accuracy: 0.7166
# Epoch 12/100
# 68/68 [==============================] - 20s 293ms/step - loss: 2.1503 - accuracy: 0.7455
# Epoch 13/100
# 68/68 [==============================] - 20s 293ms/step - loss: 2.0698 - accuracy: 0.7515
# Epoch 14/100
# 68/68 [==============================] - 20s 291ms/step - loss: 1.9635 - accuracy: 0.7683
# Epoch 15/100
# 68/68 [==============================] - 20s 294ms/step - loss: 2.0913 - accuracy: 0.7604
# Epoch 16/100
# 68/68 [==============================] - 20s 293ms/step - loss: 2.0019 - accuracy: 0.7687
# Epoch 17/100
# 68/68 [==============================] - 20s 292ms/step - loss: 2.2096 - accuracy: 0.7608
# Epoch 18/100
# 68/68 [==============================] - 20s 294ms/step - loss: 2.7494 - accuracy: 0.7394
# Epoch 19/100
# 68/68 [==============================] - 20s 293ms/step - loss: 2.7921 - accuracy: 0.7324
# Epoch 20/100
# 68/68 [==============================] - 20s 292ms/step - loss: 2.5809 - accuracy: 0.7580
# Epoch 21/100
# 68/68 [==============================] - 20s 295ms/step - loss: 2.3448 - accuracy: 0.7683
# Epoch 22/100
# 68/68 [==============================] - 20s 292ms/step - loss: 2.4675 - accuracy: 0.7683
# Epoch 23/100
# 68/68 [==============================] - 20s 292ms/step - loss: 2.2610 - accuracy: 0.7766
# Epoch 24/100
# 68/68 [==============================] - 20s 290ms/step - loss: 2.3679 - accuracy: 0.7725
# Epoch 25/100
# 68/68 [==============================] - 20s 290ms/step - loss: 3.1023 - accuracy: 0.7445
# Epoch 26/100
# 68/68 [==============================] - 20s 292ms/step - loss: 2.1167 - accuracy: 0.7939
# Epoch 27/100
# 68/68 [==============================] - 20s 291ms/step - loss: 2.3390 - accuracy: 0.7748
# Epoch 28/100
# 68/68 [==============================] - 20s 289ms/step - loss: 2.3695 - accuracy: 0.7659
# Epoch 29/100
# 68/68 [==============================] - 20s 290ms/step - loss: 2.5906 - accuracy: 0.7506
# Epoch 30/100
# 68/68 [==============================] - 20s 290ms/step - loss: 2.5790 - accuracy: 0.7673
# Epoch 31/100
# 68/68 [==============================] - 20s 291ms/step - loss: 2.3821 - accuracy: 0.7725
# Epoch 32/100
# 68/68 [==============================] - 20s 291ms/step - loss: 2.3972 - accuracy: 0.7818
# Epoch 33/100
# 68/68 [==============================] - 20s 291ms/step - loss: 2.7671 - accuracy: 0.7659
# Epoch 34/100
# 68/68 [==============================] - 20s 290ms/step - loss: 2.6470 - accuracy: 0.7692
# Epoch 35/100
# 68/68 [==============================] - 20s 290ms/step - loss: 2.7308 - accuracy: 0.7659
# Epoch 36/100
# 68/68 [==============================] - 20s 291ms/step - loss: 2.4887 - accuracy: 0.7683
# Epoch 37/100
# 68/68 [==============================] - 20s 291ms/step - loss: 2.7815 - accuracy: 0.7627
# Epoch 38/100
# 68/68 [==============================] - 20s 292ms/step - loss: 2.4889 - accuracy: 0.7766
# Epoch 39/100
# 68/68 [==============================] - 20s 291ms/step - loss: 3.3157 - accuracy: 0.7520
# Epoch 40/100
# 68/68 [==============================] - 20s 291ms/step - loss: 2.4780 - accuracy: 0.7897
# Epoch 41/100
# 68/68 [==============================] - 20s 292ms/step - loss: 2.4960 - accuracy: 0.7832
# Epoch 42/100
# 68/68 [==============================] - 20s 289ms/step - loss: 2.3880 - accuracy: 0.7813
# Epoch 43/100
# 68/68 [==============================] - 20s 291ms/step - loss: 2.4430 - accuracy: 0.7934
# Epoch 44/100
# 68/68 [==============================] - 20s 291ms/step - loss: 2.6592 - accuracy: 0.7720
# Epoch 45/100
# 68/68 [==============================] - 20s 289ms/step - loss: 3.0096 - accuracy: 0.7766
# Epoch 46/100
# 68/68 [==============================] - 20s 291ms/step - loss: 2.8414 - accuracy: 0.7766
# Epoch 47/100
# 68/68 [==============================] - 20s 292ms/step - loss: 2.5175 - accuracy: 0.7864
# Epoch 48/100
# 68/68 [==============================] - 20s 291ms/step - loss: 2.7815 - accuracy: 0.7799
# Epoch 49/100
# 68/68 [==============================] - 20s 290ms/step - loss: 2.4839 - accuracy: 0.7771
# Epoch 50/100
# 68/68 [==============================] - 20s 294ms/step - loss: 2.7827 - accuracy: 0.7697
# Epoch 51/100
# 68/68 [==============================] - 20s 291ms/step - loss: 2.7632 - accuracy: 0.7822
# Epoch 52/100
# 68/68 [==============================] - 20s 293ms/step - loss: 2.8217 - accuracy: 0.7743
# Epoch 53/100
# 68/68 [==============================] - 20s 291ms/step - loss: 2.5620 - accuracy: 0.7864
# Epoch 54/100
# 68/68 [==============================] - 20s 291ms/step - loss: 2.7184 - accuracy: 0.7925
# Epoch 55/100
# 68/68 [==============================] - 20s 292ms/step - loss: 2.7981 - accuracy: 0.7976
# Epoch 56/100
# 68/68 [==============================] - 20s 290ms/step - loss: 2.6085 - accuracy: 0.7934
# Epoch 57/100
# 68/68 [==============================] - 20s 297ms/step - loss: 2.6183 - accuracy: 0.7976
# Epoch 58/100
# 68/68 [==============================] - 20s 290ms/step - loss: 2.7100 - accuracy: 0.7878
# Epoch 59/100
# 68/68 [==============================] - 20s 292ms/step - loss: 2.4925 - accuracy: 0.7892
# Epoch 60/100
# 68/68 [==============================] - 20s 293ms/step - loss: 2.6569 - accuracy: 0.7780
# Epoch 61/100
# 68/68 [==============================] - 20s 294ms/step - loss: 2.8836 - accuracy: 0.7776
# Epoch 62/100
# 68/68 [==============================] - 20s 290ms/step - loss: 2.8651 - accuracy: 0.7771
# Epoch 63/100
# 68/68 [==============================] - 20s 292ms/step - loss: 3.1538 - accuracy: 0.7678
# Epoch 64/100
# 68/68 [==============================] - 20s 292ms/step - loss: 2.9259 - accuracy: 0.7855
# Epoch 65/100
# 68/68 [==============================] - 20s 294ms/step - loss: 2.7242 - accuracy: 0.7832
# Epoch 66/100
# 68/68 [==============================] - 20s 293ms/step - loss: 2.9696 - accuracy: 0.7925
# Epoch 67/100
# 68/68 [==============================] - 20s 291ms/step - loss: 2.8342 - accuracy: 0.7934
# Epoch 68/100
# 68/68 [==============================] - 20s 294ms/step - loss: 2.8420 - accuracy: 0.7859
# Epoch 69/100
# 68/68 [==============================] - 20s 292ms/step - loss: 2.9017 - accuracy: 0.7850
# Epoch 70/100
# 68/68 [==============================] - 20s 295ms/step - loss: 2.5102 - accuracy: 0.8004
# Epoch 71/100
# 68/68 [==============================] - 20s 291ms/step - loss: 2.9457 - accuracy: 0.7953
# Epoch 72/100
# 68/68 [==============================] - 20s 291ms/step - loss: 2.9749 - accuracy: 0.7883
# Epoch 73/100
# 68/68 [==============================] - 20s 291ms/step - loss: 3.4785 - accuracy: 0.7720
# Epoch 74/100
# 68/68 [==============================] - 20s 291ms/step - loss: 3.2258 - accuracy: 0.7813
# Epoch 75/100
# 68/68 [==============================] - 20s 292ms/step - loss: 3.2922 - accuracy: 0.7869
# Epoch 76/100
# 68/68 [==============================] - 20s 291ms/step - loss: 2.6443 - accuracy: 0.7892
# Epoch 77/100
# 68/68 [==============================] - 20s 291ms/step - loss: 2.7657 - accuracy: 0.7920
# Epoch 78/100
# 68/68 [==============================] - 20s 292ms/step - loss: 2.8348 - accuracy: 0.7939
# Epoch 79/100
# 68/68 [==============================] - 20s 291ms/step - loss: 3.2722 - accuracy: 0.7720
# Epoch 80/100
# 68/68 [==============================] - 20s 293ms/step - loss: 2.7090 - accuracy: 0.7911
# Epoch 81/100
# 68/68 [==============================] - 20s 293ms/step - loss: 2.7305 - accuracy: 0.8004
# Epoch 82/100
# 68/68 [==============================] - 20s 293ms/step - loss: 3.1810 - accuracy: 0.7645
# Epoch 83/100
# 68/68 [==============================] - 20s 292ms/step - loss: 3.0076 - accuracy: 0.8032
# Epoch 84/100
# 68/68 [==============================] - 20s 292ms/step - loss: 2.7480 - accuracy: 0.7957
# Epoch 85/100
# 68/68 [==============================] - 20s 292ms/step - loss: 2.8488 - accuracy: 0.8018
# Epoch 86/100
# 68/68 [==============================] - 20s 291ms/step - loss: 2.8874 - accuracy: 0.7859
# Epoch 87/100
# 68/68 [==============================] - 20s 290ms/step - loss: 2.9835 - accuracy: 0.7887
# Epoch 88/100
# 68/68 [==============================] - 20s 292ms/step - loss: 3.0116 - accuracy: 0.8008
# Epoch 89/100
# 68/68 [==============================] - 20s 290ms/step - loss: 3.1718 - accuracy: 0.7785
# Epoch 90/100
# 68/68 [==============================] - 20s 290ms/step - loss: 3.2414 - accuracy: 0.7859
# Epoch 91/100
# 68/68 [==============================] - 20s 291ms/step - loss: 2.7382 - accuracy: 0.7943
# Epoch 92/100
# 68/68 [==============================] - 20s 291ms/step - loss: 3.3975 - accuracy: 0.7711
# Epoch 93/100
# 68/68 [==============================] - 20s 293ms/step - loss: 3.1155 - accuracy: 0.7943
# Epoch 94/100
# 68/68 [==============================] - 20s 288ms/step - loss: 3.0986 - accuracy: 0.7808
# Epoch 95/100
# 68/68 [==============================] - 20s 292ms/step - loss: 3.0380 - accuracy: 0.7901
# Epoch 96/100
# 68/68 [==============================] - 20s 291ms/step - loss: 3.1749 - accuracy: 0.7934
# Epoch 97/100
# 68/68 [==============================] - 20s 290ms/step - loss: 3.6372 - accuracy: 0.7836
# Epoch 98/100
# 68/68 [==============================] - 20s 291ms/step - loss: 3.2076 - accuracy: 0.7906
# Epoch 99/100
# 68/68 [==============================] - 20s 292ms/step - loss: 3.9123 - accuracy: 0.7636
# Epoch 100/100
# 68/68 [==============================] - 20s 294ms/step - loss: 3.0780 - accuracy: 0.8027
# Score for fold 2: loss of 1.4946905374526978; accuracy of 87.72093057632446%
# ------------------------------------------------------------------------
# Training for fold 3 ...
# Epoch 1/100
# 68/68 [==============================] - 25s 292ms/step - loss: 2.9903 - accuracy: 0.6195
# Epoch 2/100
# 68/68 [==============================] - 20s 291ms/step - loss: 1.5891 - accuracy: 0.6991
# Epoch 3/100
# 68/68 [==============================] - 20s 288ms/step - loss: 1.2909 - accuracy: 0.7321
# Epoch 4/100
# 68/68 [==============================] - 20s 292ms/step - loss: 1.5822 - accuracy: 0.7223
# Epoch 5/100
# 68/68 [==============================] - 20s 293ms/step - loss: 1.6500 - accuracy: 0.7437
# Epoch 6/100
# 68/68 [==============================] - 20s 289ms/step - loss: 1.6438 - accuracy: 0.7544
# Epoch 7/100
# 68/68 [==============================] - 20s 294ms/step - loss: 1.9483 - accuracy: 0.7326
# Epoch 8/100
# 68/68 [==============================] - 20s 293ms/step - loss: 2.5556 - accuracy: 0.7265
# Epoch 9/100
# 68/68 [==============================] - 20s 292ms/step - loss: 1.7963 - accuracy: 0.7609
# Epoch 10/100
# 68/68 [==============================] - 20s 290ms/step - loss: 1.8841 - accuracy: 0.7516
# Epoch 11/100
# 68/68 [==============================] - 20s 293ms/step - loss: 1.9908 - accuracy: 0.7563
# Epoch 12/100
# 68/68 [==============================] - 20s 290ms/step - loss: 1.9241 - accuracy: 0.7735
# Epoch 13/100
# 68/68 [==============================] - 20s 289ms/step - loss: 2.9695 - accuracy: 0.7381
# Epoch 14/100
# 68/68 [==============================] - 20s 292ms/step - loss: 1.8719 - accuracy: 0.7805
# Epoch 15/100
# 68/68 [==============================] - 20s 294ms/step - loss: 1.9114 - accuracy: 0.7753
# Epoch 16/100
# 68/68 [==============================] - 20s 293ms/step - loss: 2.0687 - accuracy: 0.7749
# Epoch 17/100
# 68/68 [==============================] - 20s 291ms/step - loss: 1.9518 - accuracy: 0.7767
# Epoch 18/100
# 68/68 [==============================] - 20s 289ms/step - loss: 2.2164 - accuracy: 0.7656
# Epoch 19/100
# 68/68 [==============================] - 20s 291ms/step - loss: 1.9340 - accuracy: 0.7851
# Epoch 20/100
# 68/68 [==============================] - 20s 292ms/step - loss: 2.1974 - accuracy: 0.7795
# Epoch 21/100
# 68/68 [==============================] - 20s 291ms/step - loss: 2.2794 - accuracy: 0.7744
# Epoch 22/100
# 68/68 [==============================] - 20s 294ms/step - loss: 2.2683 - accuracy: 0.7735
# Epoch 23/100
# 68/68 [==============================] - 20s 292ms/step - loss: 2.3030 - accuracy: 0.7800
# Epoch 24/100
# 68/68 [==============================] - 20s 292ms/step - loss: 2.3241 - accuracy: 0.7712
# Epoch 25/100
# 68/68 [==============================] - 20s 294ms/step - loss: 2.1110 - accuracy: 0.7847
# Epoch 26/100
# 68/68 [==============================] - 20s 290ms/step - loss: 2.2788 - accuracy: 0.7749
# Epoch 27/100
# 68/68 [==============================] - 20s 291ms/step - loss: 2.1823 - accuracy: 0.7767
# Epoch 28/100
# 68/68 [==============================] - 20s 292ms/step - loss: 2.5244 - accuracy: 0.7781
# Epoch 29/100
# 68/68 [==============================] - 20s 293ms/step - loss: 2.0072 - accuracy: 0.7926
# Epoch 30/100
# 68/68 [==============================] - 20s 290ms/step - loss: 2.3958 - accuracy: 0.7865
# Epoch 31/100
# 68/68 [==============================] - 20s 293ms/step - loss: 2.3097 - accuracy: 0.7907
# Epoch 32/100
# 68/68 [==============================] - 20s 292ms/step - loss: 2.2942 - accuracy: 0.7744
# Epoch 33/100
# 68/68 [==============================] - 20s 292ms/step - loss: 2.3120 - accuracy: 0.7874
# Epoch 34/100
# 68/68 [==============================] - 20s 293ms/step - loss: 2.5357 - accuracy: 0.7926
# Epoch 35/100
# 68/68 [==============================] - 20s 296ms/step - loss: 2.2975 - accuracy: 0.7963
# Epoch 36/100
# 68/68 [==============================] - 20s 293ms/step - loss: 2.3826 - accuracy: 0.7953
# Epoch 37/100
# 68/68 [==============================] - 20s 291ms/step - loss: 2.7887 - accuracy: 0.7749
# Epoch 38/100
# 68/68 [==============================] - 20s 290ms/step - loss: 2.3081 - accuracy: 0.7995
# Epoch 39/100
# 68/68 [==============================] - 20s 293ms/step - loss: 2.7294 - accuracy: 0.7651
# Epoch 40/100
# 68/68 [==============================] - 20s 291ms/step - loss: 2.5409 - accuracy: 0.7902
# Epoch 41/100
# 68/68 [==============================] - 20s 293ms/step - loss: 2.8000 - accuracy: 0.7744
# Epoch 42/100
# 68/68 [==============================] - 20s 295ms/step - loss: 2.6336 - accuracy: 0.7879
# Epoch 43/100
# 68/68 [==============================] - 20s 293ms/step - loss: 2.6781 - accuracy: 0.7660
# Epoch 44/100
# 68/68 [==============================] - 20s 294ms/step - loss: 2.6066 - accuracy: 0.7851
# Epoch 45/100
# 68/68 [==============================] - 20s 292ms/step - loss: 2.4037 - accuracy: 0.8019
# Epoch 46/100
# 68/68 [==============================] - 20s 291ms/step - loss: 2.7195 - accuracy: 0.7856
# Epoch 47/100
# 68/68 [==============================] - 20s 290ms/step - loss: 2.5748 - accuracy: 0.7981
# Epoch 48/100
# 68/68 [==============================] - 20s 290ms/step - loss: 3.0310 - accuracy: 0.7772
# Epoch 49/100
# 68/68 [==============================] - 20s 289ms/step - loss: 2.6145 - accuracy: 0.7842
# Epoch 50/100
# 68/68 [==============================] - 20s 291ms/step - loss: 2.7831 - accuracy: 0.7958
# Epoch 51/100
# 68/68 [==============================] - 20s 290ms/step - loss: 2.7355 - accuracy: 0.7902
# Epoch 52/100
# 68/68 [==============================] - 20s 291ms/step - loss: 2.5961 - accuracy: 0.7935
# Epoch 53/100
# 68/68 [==============================] - 20s 290ms/step - loss: 2.8269 - accuracy: 0.7944
# Epoch 54/100
# 68/68 [==============================] - 20s 290ms/step - loss: 2.7450 - accuracy: 0.7837
# Epoch 55/100
# 68/68 [==============================] - 20s 291ms/step - loss: 2.5165 - accuracy: 0.8084
# Epoch 56/100
# 68/68 [==============================] - 20s 290ms/step - loss: 2.5686 - accuracy: 0.8144
# Epoch 57/100
# 68/68 [==============================] - 20s 292ms/step - loss: 2.7870 - accuracy: 0.7884
# Epoch 58/100
# 68/68 [==============================] - 20s 293ms/step - loss: 2.3777 - accuracy: 0.7986
# Epoch 59/100
# 68/68 [==============================] - 20s 292ms/step - loss: 2.8002 - accuracy: 0.7944
# Epoch 60/100
# 68/68 [==============================] - 20s 290ms/step - loss: 2.3886 - accuracy: 0.8135
# Epoch 61/100
# 68/68 [==============================] - 20s 291ms/step - loss: 2.7462 - accuracy: 0.8009
# Epoch 62/100
# 68/68 [==============================] - 20s 292ms/step - loss: 3.1468 - accuracy: 0.7860
# Epoch 63/100
# 68/68 [==============================] - 20s 290ms/step - loss: 2.9584 - accuracy: 0.7833
# Epoch 64/100
# 68/68 [==============================] - 20s 295ms/step - loss: 2.6888 - accuracy: 0.8000
# Epoch 65/100
# 68/68 [==============================] - 20s 291ms/step - loss: 2.7969 - accuracy: 0.7921
# Epoch 66/100
# 68/68 [==============================] - 20s 294ms/step - loss: 2.8080 - accuracy: 0.7958
# Epoch 67/100
# 68/68 [==============================] - 20s 291ms/step - loss: 2.9973 - accuracy: 0.7967
# Epoch 68/100
# 68/68 [==============================] - 20s 294ms/step - loss: 2.5253 - accuracy: 0.8126
# Epoch 69/100
# 68/68 [==============================] - 20s 290ms/step - loss: 2.4538 - accuracy: 0.8177
# Epoch 70/100
# 68/68 [==============================] - 20s 295ms/step - loss: 3.3577 - accuracy: 0.7749
# Epoch 71/100
# 68/68 [==============================] - 20s 294ms/step - loss: 2.9210 - accuracy: 0.7995
# Epoch 72/100
# 68/68 [==============================] - 20s 291ms/step - loss: 2.6365 - accuracy: 0.7972
# Epoch 73/100
# 68/68 [==============================] - 20s 291ms/step - loss: 3.0943 - accuracy: 0.7823
# Epoch 74/100
# 68/68 [==============================] - 20s 291ms/step - loss: 2.9125 - accuracy: 0.7902
# Epoch 75/100
# 68/68 [==============================] - 20s 291ms/step - loss: 2.9702 - accuracy: 0.7898
# Epoch 76/100
# 68/68 [==============================] - 20s 292ms/step - loss: 2.9126 - accuracy: 0.8074
# Epoch 77/100
# 68/68 [==============================] - 20s 292ms/step - loss: 2.6922 - accuracy: 0.8144
# Epoch 78/100
# 68/68 [==============================] - 20s 291ms/step - loss: 3.2489 - accuracy: 0.7898
# Epoch 79/100
# 68/68 [==============================] - 20s 292ms/step - loss: 2.8727 - accuracy: 0.8158
# Epoch 80/100
# 68/68 [==============================] - 20s 293ms/step - loss: 2.8701 - accuracy: 0.7953
# Epoch 81/100
# 68/68 [==============================] - 20s 292ms/step - loss: 2.4556 - accuracy: 0.8112
# Epoch 82/100
# 68/68 [==============================] - 20s 291ms/step - loss: 2.9568 - accuracy: 0.8144
# Epoch 83/100
# 68/68 [==============================] - 20s 292ms/step - loss: 2.9420 - accuracy: 0.8014
# Epoch 84/100
# 68/68 [==============================] - 20s 291ms/step - loss: 3.2075 - accuracy: 0.7865
# Epoch 85/100
# 68/68 [==============================] - 20s 291ms/step - loss: 2.9783 - accuracy: 0.8065
# Epoch 86/100
# 68/68 [==============================] - 20s 291ms/step - loss: 3.2467 - accuracy: 0.7958
# Epoch 87/100
# 68/68 [==============================] - 20s 292ms/step - loss: 2.8051 - accuracy: 0.8028
# Epoch 88/100
# 68/68 [==============================] - 20s 291ms/step - loss: 3.6378 - accuracy: 0.7958
# Epoch 89/100
# 68/68 [==============================] - 20s 292ms/step - loss: 2.8715 - accuracy: 0.7958
# Epoch 90/100
# 68/68 [==============================] - 20s 292ms/step - loss: 2.6777 - accuracy: 0.8126
# Epoch 91/100
# 68/68 [==============================] - 20s 294ms/step - loss: 3.1452 - accuracy: 0.7963
# Epoch 92/100
# 68/68 [==============================] - 20s 292ms/step - loss: 2.8840 - accuracy: 0.8056
# Epoch 93/100
# 68/68 [==============================] - 20s 292ms/step - loss: 3.0154 - accuracy: 0.8065
# Epoch 94/100
# 68/68 [==============================] - 20s 291ms/step - loss: 2.7544 - accuracy: 0.8009
# Epoch 95/100
# 68/68 [==============================] - 20s 299ms/step - loss: 2.7977 - accuracy: 0.8047
# Epoch 96/100
# 68/68 [==============================] - 20s 296ms/step - loss: 2.6990 - accuracy: 0.8158
# Epoch 97/100
# 68/68 [==============================] - 20s 291ms/step - loss: 2.9282 - accuracy: 0.8014
# Epoch 98/100
# 68/68 [==============================] - 20s 293ms/step - loss: 2.8462 - accuracy: 0.8088
# Epoch 99/100
# 68/68 [==============================] - 20s 289ms/step - loss: 2.7473 - accuracy: 0.8135
# Epoch 100/100
# 68/68 [==============================] - 20s 290ms/step - loss: 2.6021 - accuracy: 0.8167
# Score for fold 3: loss of 2.485330104827881; accuracy of 82.21601247787476%
# ------------------------------------------------------------------------
# Score per fold
# ------------------------------------------------------------------------
# > Fold 1 - Loss: 3.693222999572754 - Accuracy: 77.11628079414368%
# ------------------------------------------------------------------------
# > Fold 2 - Loss: 1.4946905374526978 - Accuracy: 87.72093057632446%
# ------------------------------------------------------------------------
# > Fold 3 - Loss: 2.485330104827881 - Accuracy: 82.21601247787476%
# ------------------------------------------------------------------------
# Average scores for all folds:
# > Accuracy: 82.3510746161143 (+- 4.330383400005602)
# > Loss: 2.5577478806177774
# ------------------------------------------------------------------------

# %%
import pandas as pd
metrics = pd.DataFrame(acc_per_fold)
metrics = metrics.rename(columns={0:'accuracy'})
loss_df = pd.DataFrame(loss_per_fold)

# %%
metrics.head()
# Out:
#     accuracy
# 0  77.116281
# 1  87.720931
# 2  82.216012

# %%
metrics_df = metrics.join(loss_df.rename(columns={0:'loss'}))

# %%
metrics_df.head()
# Out:
#     accuracy      loss
# 0  77.116281  3.693223
# 1  87.720931  1.494691
# 2  82.216012  2.485330

# %%
report_csv_file = '/content/drive/MyDrive/Colab Notebooks/CTCov/Fold/DenseNet121/densenet_med_blur_class_report.csv'
with open(report_csv_file, mode='w') as f:
    metrics_df.to_csv(f)
